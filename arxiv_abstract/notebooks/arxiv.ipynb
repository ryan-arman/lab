# %%
# Import utility functions
from utils import (
    evaluate_summary,
    evaluate_summaries_batch,
    display_text,
    display_message,
    load_conversations,
    client,
    JUDGE_SYSTEM_INSTRUCTION,
    JUDGE_PROMPT_TEMPLATE_WITH_REQUEST_AND_RESPONSE
)

# %% [markdown]
# # Examine data

# %%
# train_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train.jsonl"
train_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_filtered_10k.jsonl"
val_path =   "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_val_filtered_10k.jsonl"
test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_test_filtered_10k.jsonl"
# train_distilled_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_abstract_train_gpt5mini_think2.jsonl"
train_conversations = load_conversations(train_path)
val_conversations = load_conversations(val_path)
test_conversations = load_conversations(test_path)
# train_distilled_conversations = load_conversations(train_distilled_path)

# %%
test_conversations[0]
# Out:
# [{'role': 'user',
#   'content': 'as a common quantum phenomenon , the tunneling through a potential barrier plays a very important role in the microscopic world and has been studied extensively since the birth of quantum mechanics . \n one of the earliest applications of quantum tunneling is the explanation of @xmath0 decays in atomic nuclei . \n the quantum tunneling effect governs also many other nuclear processes such as fission and fusion . \n in particular , a lot of new features are revealed in sub - barrier fusion reactions which are closely connected with the tunneling phenomena  @xcite .    for most of the potential barriers , the penetrability can not be calculated analytically  @xcite . among those potentials for which analytical solutions can be obtained , \n the parabolic potential  @xcite is the mostly used in the study of nuclear fusion . by approximating the coulomb barrier to a parabola \n , wong derived an analytic expression for the fusion cross section  @xcite which is widely adopted today in the study of heavy ion reactions ( see , e.g. , recent refs . \n the parabolic approximation works remarkably well both for the penetrability and for the fusion cross section at energies around or above the coulomb barrier  @xcite . \n apparently the parabolic approximation breaks down at energies much smaller than the barrier height due to the long - range coulomb interaction . \n one may calculate the penetration probability numerically by using the path integral method or the wkb approximation . \n however , it is highly desirable to have an analytical expression for the barrier penetrability when one introduces an energy - dependent one - dimensional potential barrier  @xcite or barrier distribution functions  @xcite .    in the present work \n , we derived a new barrier penetration formula based on the wkb approximation . \n the influence of the long coulomb tail in the barrier potential is taken into accout properly . \n therefore this formula is especially applicable to the barrier penetration with penetration energy much lower than the coulomb barrier .    as a first attempt and a test study \n , we apply this new formula to evaluate @xmath0 decay half - lives of atomic nuclei . for the @xmath0 decay , \n the penetrability is usually calculated with the wkb approach  @xcite , in other words , integrating numerically the wave number within two turning points at which the interaction potential is equal to the @xmath1-value of the @xmath0 decay . \n we will show that the present analytical formula reproduces the experimental results very well , especially for spherical nuclei . \n the paper is organized as follows . in sec . \n [ sec : formalism ] we present the new barrier penetration formula . \n the validity of the new formula is investigated and its application to @xmath0 decays are given in sec . \n [ sec : results ] . finally in sec . \n [ sec : summary ] we summarize our work . in the appendix , \n the detailed derivation of the new penetration formula is given . \n when the penetration energy is well below the coulomb barrier , the barrier penetrability formula derived from the wkb approximation reads , @xmath2 ,   \\label{eq : wkb}\\ ] ] where the potential usually consists of three parts , the nuclear , the coulomb , and the centrifugal potentials , @xmath3 @xmath4 and @xmath5 are the inner and outer turning points determined by the relation @xmath6 .    by approximating @xmath7 to a parabola with the height @xmath8 and the width @xmath9 , eq . \n ( [ eq : wkb ] ) is reduced as @xmath10 ,   \\label{eq : hw}\\ ] ] which has been widely used in the study of heavy ion reactions .    because of the long - range coulomb interaction , the coulomb barrier given in eq . \n ( [ eq : potential ] ) has a long tail and is asymmetric . \n thus for the penetration well below the barrier , the parabolic approximation is not valid . \n we may divide the potential barrier into two parts at the barrier position @xmath11 . \n the first part  ...
#  {'role': 'assistant',
#   'content': 'starting from the wkb approximation , a new barrier penetration formula is proposed for potential barriers containing a long - range coulomb interaction . \n this formula is especially proper for the barrier penetration with penetration energy much lower than the coulomb barrier . \n the penetrabilities calculated from the new formula agree well with the results from the wkb method . as a first attempt , \n this new formula is used to evaluate @xmath0 decay half - lives of atomic nuclei and a good agreement with the experiment is obtained .'}]

# %% [markdown]
# # Judge

# %%
# Test the helper function on the first message
# First, let's examine train_conversations[0]

conv = train_conversations[6]
print("="*80)
print(f"Number of messages: {len(conv)}")
print(f"Message roles: {[msg['role'] for msg in conv]}")
print("\n" + "="*80)
print("USER MESSAGE (the paper content):")
print("="*80)
# display_message(train_conversations[0], role='user')
# print("\n" + "="*80)
print("ASSISTANT MESSAGE (the summary being evaluated):")
print("="*80)
display_message(conv, role='assistant')

print("\n" + "="*80)
print("JUDGE EVALUATION:")
print("="*80)
result, evaluation_prompt = evaluate_summary(conv, model="gpt-5")

print(f"Judgment: {result['judgment']}")
print(f"\nExplanation:\n{result['explanation']}")
# Out:
# ================================================================================
# Number of messages: 2
# Message roles: ['user', 'assistant']
#
# ================================================================================
# USER MESSAGE (the paper content):
# ================================================================================
# ASSISTANT MESSAGE (the summary being evaluated):
# ================================================================================
# ================================================================================
# Role: ASSISTANT
# Characters: 1,721 | Words: 315 | Lines: 8
# ================================================================================
# <pre style="white-space: pre-wrap; word-wrap: break-word; font-family: monospace; background-color: #f5f5f5; color: #000000; padding: 10px; border-radius: 5px; line-height: 1.5;">this paper investigates , using prior shape models and the concept of ball scale
# ( b - scale ) , ways of automatically recognizing objects in 3d images without
# performing elaborate searches or optimization .
#  that is , the goal is to place the model in a single shot close to the right
# pose ( position , orientation , and scale ) in a given image so that the model
# boundaries fall in the close vicinity of object boundaries in the image .
#  this is achieved via the following set of key ideas : ( a ) a semi - automatic
# way of constructing a multi - object shape model assembly .
#  ( b ) a novel strategy of encoding , via b - scale , the pose relationship
# between objects in the training images and their intensity patterns captured in
# b - scale images . ( c )
#  a hierarchical mechanism of positioning the model , in a one - shot way , in a
# given image from a knowledge of the learnt pose relationship and the b - scale
# image of the given image to be segmented .
#  the evaluation results on a set of 20 routine clinical abdominal female and
# male ct data sets indicate the following : ( 1 ) incorporating a large number of
# objects improves the recognition accuracy dramatically .
#  ( 2 ) the recognition algorithm can be thought as a hierarchical framework such
# that quick replacement of the model assembly is defined as coarse recognition
# and delineation itself is known as finest recognition .
#  ( 3 ) scale yields useful information about the relationship between the model
# assembly and any given image such that the recognition results in a placement of
# the model close to the actual pose without doing any elaborate searches or
# optimization . ( 4 ) effective object recognition can make delineation most
# accurate .</pre>
# ================================================================================
# JUDGE EVALUATION:
# ================================================================================
# Judgment: No
#
# Explanation:
# Faithfulness (60/100):
# - The summary largely reflects the paper’s topic (object recognition to aid segmentation via b-scale and shape models) and the hierarchical recognition idea. However, it introduces a specific evaluation detail not present in the provided text: “a set of 20 routine clinical abdominal female and male CT data sets.” The number 20 is not supported by the text (which uses variables for the number of subjects and mentions only that data are routine PET/CT-derived CT scans).
# - It also paraphrases a reported finding as “recognition accuracy” improving with more objects, whereas the paper explicitly states “specificity” increases; this is a subtle but meaningful shift in the reported metric.
# - It slightly overstates the conclusion with “make delineation most accurate,” which is stronger than the paper’s framing that efficient recognition enables successful delineation.
#
# Coverage (85/100):
# - The summary states the main problem (automatic object recognition to assist segmentation), the core method (model assembly, b-scale encoding of pose relationships, hierarchical/one-shot placement), and at least one main finding (more objects improve recognition; b-scale captures useful information).
# - It omits some specific components described in the paper, such as the intensity-weighted b-scale variant, the PCA-based pose system and transformation, and the optional refinement using the skin boundary, but overall covers the essential aspects adequately for a brief summary.
#
# Clarity (90/100):
# - Sentences are grammatical and understandable. Technical terms (b-scale, model assembly, hierarchical recognition) are used appropriately and in context. The meaning is clear to a technically literate reader.
#
# Conciseness (90/100):
# - The summary is focused, avoids filler, and includes only relevant information. Length is appropriate for an abstract-style summary.
#
# Coherence (90/100):
# - The summary follows a logical structure (goal → method → key ideas → findings) and flows smoothly without contradictions.
#
# Overall (77/100)

# %% [markdown]
# ## Eval original abstracts

# %%
# Batch evaluation for the first 10 conversations

original_results, original_errors = evaluate_summaries_batch(
    test_conversations,
    model="gpt-5",
    temperature=1.0,
    max_workers=1000,  # Adjust based on your API rate limits
    show_progress=True
)

# Display results
print("\n" + "="*80)
print("BATCH EVALUATION RESULTS")
print("="*80)

for idx, result, prompt in original_results:
    print(f"\nConversation {idx}:")
    print(f"  Judgment: {result['judgment']}")
    # Optionally show a snippet of the explanation
    explanation_preview = result['explanation'][:200] + "..." if len(result['explanation']) > 200 else result['explanation']
    print(f"  Explanation preview: {explanation_preview}")

if original_errors:
    print(f"\nErrors encountered: {len(original_errors)}")
    for idx, error in original_errors:
        print(f"  Conversation {idx}: {error}")

# Summary statistics
judgments = [result['judgment'] for _, result, _ in original_results]
yes_count = judgments.count('Yes')
no_count = judgments.count('No')
unknown_count = judgments.count('Unknown')

print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Total evaluated: {len(original_results)}")
print(f"Yes: {yes_count} ({yes_count/len(original_results)*100:.1f}%)")
print(f"No: {no_count} ({no_count/len(original_results)*100:.1f}%)")
print(f"Unknown: {unknown_count} ({unknown_count/len(original_results)*100:.1f}%)")
# Out:
# Evaluating 1000 conversations with 1000 workers...
#   Completed 1/1000
#   Completed 2/1000
#   Completed 3/1000
#   Completed 4/1000
#   Completed 5/1000
#   Completed 6/1000
#   Completed 7/1000
#   Completed 8/1000
#   Completed 9/1000
#   Completed 10/1000
#   Completed 11/1000
#   Completed 12/1000
#   Completed 13/1000
#   Completed 14/1000
#   Completed 15/1000
#   Completed 16/1000
#   Completed 17/1000
#   Completed 18/1000
#   Completed 19/1000
#   Completed 20/1000
#   Completed 21/1000
#   Completed 22/1000
#   Completed 23/1000
#   Completed 24/1000
#   Completed 25/1000
#   Completed 26/1000
#   Completed 27/1000
#   Completed 582/1000
#   Completed 583/1000
#   Completed 584/1000
#   Completed 585/1000
#   Completed 586/1000
#   Completed 587/1000
#   Completed 588/1000
#   Completed 589/1000
#   Completed 590/1000
#   Completed 591/1000
#   Completed 592/1000
#   Completed 593/1000
#   Completed 594/1000
#   Completed 595/1000
#   Completed 596/1000
#   Completed 597/1000
#   Completed 598/1000
#   Completed 599/1000
#   Completed 600/1000
#   Completed 601/1000
#   Completed 602/1000
#   Completed 603/1000
#   Completed 604/1000
#   Completed 605/1000
#   Completed 606/1000
#   Completed 607/1000
#   Completed 608/1000
#   Completed 609/1000
#   Completed 610/1000
#   Completed 611/1000
#   Completed 612/1000
#   Completed 613/1000
#   Completed 614/1000
#   Completed 615/1000
#   Completed 616/1000
#   Completed 617/1000
#   Completed 618/1000
#   Completed 619/1000
#   Completed 620/1000
#   Completed 621/1000
#   Completed 622/1000
#   Completed 623/1000
#   Completed 624/1000
#   Completed 625/1000
#   Completed 626/1000
#   Completed 627/1000
#   Completed 628/1000
#   Completed 629/1000
#   Completed 630/1000
#   Completed 631/1000
#   Completed 632/1000
#   Completed 633/1000
#   Completed 634/1000
#   Completed 635/1000
#   Completed 636/1000
#   Completed 637/1000
#   Completed 638/1000
#   Completed 639/1000
#   Completed 640/1000
#   Completed 641/1000
#   Completed 642/1000
#   Completed 643/1000
#   Completed 644/1000
#   Completed 645/1000
#   Completed 646/1000
#   Completed 647/1000
#   Completed 648/1000
#   Completed 649/1000
#   Completed 650/1000
#   Completed 651/1000
#   Completed 652/1000
#   Completed 653/1000
#   Completed 654/1000
#   Completed 655/1000
#   Completed 656/1000
#   Completed 657/1000
#   Completed 658/1000
#   Completed 659/1000
#   Completed 660/1000
#   Completed 661/1000
#   Completed 662/1000
#   Completed 663/1000
#   Completed 664/1000
#   Completed 665/1000
#   Completed 666/1000
#   Completed 667/1000
#   Completed 668/1000
#   Completed 669/1000
#   Completed 670/1000
#   Completed 671/1000
#   Completed 672/1000
#   Completed 673/1000
#   Completed 674/1000
#   Completed 675/1000
#   Completed 676/1000
#   Completed 677/1000
#   Completed 678/1000
#   Completed 679/1000
#   Completed 680/1000
#   Completed 681/1000
#   Completed 682/1000
#   Completed 683/1000
#   Completed 684/1000
#   Completed 685/1000
#   Completed 686/1000
#   Completed 687/1000
#   Completed 688/1000
#   Completed 689/1000
#   Completed 690/1000
#   Completed 691/1000
#   Completed 692/1000
#   Completed 693/1000
#   Completed 694/1000
#   Completed 695/1000
#   Completed 696/1000
#   Completed 697/1000
#   Completed 698/1000
#   Completed 699/1000
#   Completed 700/1000
#   Completed 701/1000
#   Completed 702/1000
#   Completed 703/1000
#   Completed 704/1000
#   Completed 705/1000
#   Completed 706/1000
#   Completed 707/1000
#   Completed 708/1000
#   Completed 709/1000
#   Completed 710/1000
#   Completed 711/1000
#   Completed 712/1000
#   Completed 713/1000
#   Completed 714/1000
#   Completed 715/1000
#   Completed 716/1000
#   Completed 717/1000
#   Completed 718/1000
#   Completed 719/1000
#   Completed 720/1000
#   Completed 859/1000
#   Completed 860/1000
#   Completed 861/1000
#   Completed 862/1000
#   Completed 863/1000
#   Completed 864/1000
#   Completed 865/1000
#   Completed 866/1000
#   Completed 867/1000
#   Completed 868/1000
#   Completed 869/1000
#   Completed 870/1000
#   Completed 871/1000
#   Completed 872/1000
#   Completed 873/1000
#   Completed 874/1000
#   Completed 875/1000
#   Completed 876/1000
#   Completed 877/1000
#   Completed 878/1000
#   Completed 879/1000
#   Completed 880/1000
#   Completed 881/1000
#   Completed 882/1000
#   Completed 883/1000
#   Completed 884/1000
#   Completed 885/1000
#   Completed 886/1000
#   Completed 887/1000
#   Completed 888/1000
#   Completed 889/1000
#   Completed 890/1000
#   Completed 891/1000
#   Completed 892/1000
#   Completed 893/1000
#   Completed 894/1000
#   Completed 895/1000
#   Completed 896/1000
#   Completed 897/1000
#   Completed 898/1000
#   Completed 899/1000
#   Completed 900/1000
#   Completed 901/1000
#   Completed 902/1000
#   Completed 903/1000
#   Completed 904/1000
#   Completed 905/1000
#   Completed 906/1000
#   Completed 907/1000
#   Completed 908/1000
#   Completed 909/1000
#   Completed 910/1000
#   Completed 911/1000
#   Completed 912/1000
#   Completed 913/1000
#   Completed 914/1000
#   Completed 915/1000
#   Completed 916/1000
#   Completed 917/1000
#   Completed 918/1000
#   Completed 919/1000
#   Completed 920/1000
#   Completed 921/1000
#   Completed 922/1000
#   Completed 923/1000
#   Completed 924/1000
#   Completed 925/1000
#   Completed 926/1000
#   Completed 927/1000
#   Completed 928/1000
#   Completed 929/1000
#   Completed 930/1000
#   Completed 931/1000
#   Completed 932/1000
#   Completed 933/1000
#   Completed 934/1000
#   Completed 935/1000
#   Completed 936/1000
#   Completed 937/1000
#   Completed 938/1000
#   Completed 939/1000
#   Completed 940/1000
#   Completed 941/1000
#   Completed 942/1000
#   Completed 943/1000
#   Completed 944/1000
#   Completed 945/1000
#   Completed 946/1000
#   Completed 947/1000
#   Completed 948/1000
#   Completed 949/1000
#   Completed 950/1000
#   Completed 951/1000
#   Completed 952/1000
#   Completed 953/1000
#   Completed 954/1000
#   Completed 955/1000
#   Completed 956/1000
#   Completed 957/1000
#   Completed 958/1000
#   Completed 959/1000
#   Completed 960/1000
#   Completed 961/1000
#   Completed 962/1000
#   Completed 963/1000
#   Completed 964/1000
#   Completed 965/1000
#   Completed 966/1000
#   Completed 967/1000
#   Completed 968/1000
#   Completed 969/1000
#   Completed 970/1000
#   Completed 971/1000
#   Completed 972/1000
#   Completed 973/1000
#   Completed 974/1000
#   Completed 975/1000
#   Completed 976/1000
#   Completed 977/1000
#   Completed 978/1000
#   Completed 979/1000
#   Completed 980/1000
#   Completed 981/1000
#   Completed 982/1000
#   Completed 983/1000
#   Completed 984/1000
#   Completed 985/1000
#   Completed 986/1000
#   Completed 987/1000
#   Completed 988/1000
#   Completed 989/1000
#   Completed 990/1000
#   Completed 991/1000
#   Completed 992/1000
#   Completed 993/1000
#   Completed 994/1000
#   Completed 995/1000
#   Completed 996/1000
#   Completed 997/1000
#   Completed 998/1000
#   Completed 999/1000
#   Completed 1000/1000
#
# ✓ Completed: 1000 successful, 0 errors
#
# ================================================================================
# BATCH EVALUATION RESULTS
# ================================================================================
#
# Conversation 0:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core content: a new WKB-based barrier penetration formula that properly accounts for the long-range Coulomb tail, its applicability...
#
# Conversation 1:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it focuses on adapted nested force-gradient integrators within HMC, the Schwinger model as the testbed, derivation of the ...
#
# Conversation 2:
#   Judgment: No
#   Explanation preview: Faithfulness (88/100):
# - The core claims match the paper: it presents new methods for deriving functional equations for Feynman integrals, applies them to one- and two-loop cases, and uses these equat...
#
# Conversation 3:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 92
# - The summary accurately reflects the paper’s focus on hierarchical Hough-transform-based searches for continuous gravitational waves, the comparison between the “sky Hough” a...
#
# Conversation 4:
#   Judgment: Yes
#   Explanation preview: Faithfulness (accuracy to the paper): 95/100
# - The summary accurately reflects the paper’s focus: using pre-explosion imaging (space-based optical and ground-based IR with LGS-AO) to identify or const...
#
# Conversation 5:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and scope: SSAs in back-to-back dijet azimuthal correlations in pp collisions at RHIC.
# - It correctly notes the role of initi...
#
# Conversation 6:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and main contributions: large deviations for quantities in Kingman’s coalescent tied to two well-known laws of large numbers ...
#
# Conversation 7:
#   Judgment: No
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately states that the paper studies the strong subadditivity inequality (SSI) for a tripartite system using a four-particle entangled state, and that the setu...
#
# Conversation 8:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that PBH abundance limits constrain the small-scale primordial power spectrum, that standard Stewart–L...
#
# Conversation 9:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces several factual details not supported by the provided paper text: that SOFIA is a 2.5-meter airborne infrared telescope, mounted on a Boeing 747SP, and ...
#
# Conversation 10:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 97
# - The summary accurately reflects the paper’s content: it identifies the problem (cooperative dipole-dipole effects on fluorescence/quantum jumps), the systems studied (3-leve...
#
# Conversation 11:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on one-loop vertex corrections in an R-symmetric (MR) extension of the MSSM and their impact on the observable denoted @xmath...
#
# Conversation 12:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary includes claims not supported by the provided paper text, such as statements about the time complexity relationships of squaring, division, reciprocal, GCD, and re...
#
# Conversation 13:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly notes that HiRes reported preliminary monocular spectra from both sites, that the results are consistent with...
#
# Conversation 14:
#   Judgment: No
#   Explanation preview: Faithfulness (75/100):
# - Mostly accurate: it correctly states that microlensing is sensitive to planets around common (M-dwarf) stars, is well-suited to detect Jovian-mass planets at several AU, probe...
#
# Conversation 15:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic and findings. It correctly states that the authors re-analyze 18 masers with a probabilistic model allowing a nonzero mean of...
#
# Conversation 16:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it reports a polarized-beam measurement of the isoscalar double-pionic fusion reaction (@xmath0), performed with WASA at C...
#
# Conversation 17:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core claims: introducing 4-body real-space Jastrow factors designed for wave function stenciling; removing ionic configurations to ...
#
# Conversation 18:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately states the observational finding: a scarcity of very metal-poor stars in Milky Way dSphs despite low average metallicities.
# - It correctly describes the...
#
# Conversation 19:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s key content. It correctly states that semi-infinite non-Hermitian systems made of a finite non-Hermitian cluster attached to a semi...
#
# Conversation 20:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it states that the work derives the Vogel–Fulcher–Tammann (VFT) law for bulk polymer glasses, bases the derivation on the ...
#
# Conversation 21:
#   Judgment: Yes
#   Explanation preview: - Faithfulness (90/100): The summary accurately reflects the paper’s content. It correctly states that the paper summarizes results on the emergence of general relativity (GR) from tensor models with ...
#
# Conversation 22:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45)
# - The summary introduces claims not supported by the provided text, notably: “two types of models have this property: scalar fields with unconventional kinetic term and models...
#
# Conversation 23:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Mostly accurate: The summary correctly states that the paper uses an EFT based on HQSS, HFS, and HADS; fits counter-terms (LECs) using the heavy meson–antimeson sector; interp...
#
# Conversation 24:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it states that truncated Fourier, Gauss, Kummer, and exponential sums can be used for factorization, that factors yield un...
#
# Conversation 25:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on universal PAC learning over all computable classifiers, the infinite VC dimension implication, the use of adaptive sample ...
#
# Conversation 26:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it describes the targets (DM Tau, LkCa 15, TW Hya; L1551 IRS 5 and HL Tau), the instrumentation (ALMA Band 8 qualification...
#
# Conversation 27:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Strengths: The summary correctly states the main quantitative results (discovery of 42 white dwarfs; nine confirmed ZZ Ceti pulsators), the use of KIS color selection, spectro...
#
# Conversation 28:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Largely accurate: the summary correctly states that the paper combines measurements from seven clusters, finds little evidence for IMF variation across regions, and concludes ...
#
# Conversation 29:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the core content of the paper: it studies spin polarization in a three-terminal system with Rashba spin-orbit interaction, compares ring-like v...
#
# Conversation 30:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on a phase-damping (pure decoherence) qubit coupled to a bosonic environment and the study of system–environment correlations...
#
# Conversation 31:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic (woofer–tweeter AO architecture), the open-loop control focus, the tested device (ALPAO DM52), and the key quantitative resul...
#
# Conversation 32:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately reflects key themes of the paper: pulse-wise GRB correlations, the empirical nature of such correlations, interest in their cosmological use ...
#
# Conversation 33:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core content: a unified derivation of MFDRs around NESS using Agarwal’s formalism, equivalence of velocity-form MFDRs for Langevin ...
#
# Conversation 34:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: applying the composite operator formalism to QCD at finite temperature to compute scalar (sigma) and pseudoscalar (pion) mas...
#
# Conversation 35:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on current noise in double quantum dots, the role of Coulomb correlations, entanglement in two-electron states (singlet/tripl...
#
# Conversation 36:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it identifies Nessie as a filamentary IRDC with an extreme aspect ratio, reports uniform radial velocity indicating a sing...
#
# Conversation 37:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on FQHE in graphene under SU(4) symmetry (spin + valley), the prediction of new states without GaAs analogs, and their emerge...
#
# Conversation 38:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: molecular motors perform biased walks on filaments with small-probability unbinding, unbound motion is symmetric Brow...
#
# Conversation 39:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s main contributions: deriving the pairwise peculiar velocity distribution function (PVDF) within the dark halo framework; avoiding a...
#
# Conversation 40:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states: (1) a time-dependent Maxwell solution in the Einstein universe with fields aligned along Clifford par...
#
# Conversation 41:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic and approach: a Ginzburg–Landau phase-field model for SMAs with thermo-mechanical coupling, thermodynamic consistency, FE imp...
#
# Conversation 42:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 92)
# - The summary accurately reflects the paper’s central claims: (i) the Isham–Storey solution with the Isham–Salam–Strathdee potential is not a regular black hole because of hor...
#
# Conversation 43:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly captures the paper’s main aim (modeling accretion from clumpy OB supergiant winds in HMXBs/SFXTs), core modeling assumptions (ram-pressure-con...
#
# Conversation 44:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on using present-day kinematics and spatial distributions to constrain the formation of multiple populations in globular clus...
#
# Conversation 45:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core claims: that turbulence may have a maximally nonunique (“fragile”) limiting case, and that the Burgers equation—interpreted in...
#
# Conversation 46:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic (small-scale anisotropy/clustering in UHECRs), the contrasting AGASA and HiRes contexts, the asymmetric angular resolution in...
#
# Conversation 47:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects key aspects of the paper: it states the use of four-dimensional N=2 central charge superspace, focuses on the abelian vector–tensor multiplet, ...
#
# Conversation 48:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces several claims not supported by the provided text. It calls the Statistical Toolkit “open source,” which is not stated. It adds “detector performance mo...
#
# Conversation 49:
#   Judgment: No
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and scope: coherent backscattering (CBS) from two harmonically trapped atoms, the roles of recoil and Doppler effects near re...
#
# Conversation 50:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces information not supported by the provided text, notably the statement that the detector is “built from two independent sub devices, the pixel barrel and...
#
# Conversation 51:
#   Judgment: Yes
#   Explanation preview: Faithfulness (Score: 92)
# - The summary accurately reflects the paper’s content. It correctly states that the authors extend DMRG to random graphs of fixed connectivity, apply it to the random Ising mo...
#
# Conversation 52:
#   Judgment: No
#   Explanation preview: Faithfulness: 90/100
# - The summary correctly identifies the three main topics of the paper: (1) EFT for two-nucleon systems, (2) the flavor-singlet axial charge (proton spin problem) via the Cheshire ...
#
# Conversation 53:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly states that supra-arcade downflows are key indirect evidence for magnetic reconnection, that the authors pres...
#
# Conversation 54:
#   Judgment: No
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it notes STAR’s uniform azimuthal acceptance and extended pseudorapidity coverage, strong particle identification capabili...
#
# Conversation 55:
#   Judgment: No
#   Explanation preview: Faithfulness: 80/100
# - Mostly accurate and aligned with the paper: it correctly mentions ALICE’s PID using ITS, TPC, TOF, HMPID; reconstruction via weak decay topologies; coverage of long-lived hadron...
#
# Conversation 56:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and findings: it describes filament-axis rotation during eruptions, the usual twist-to-writhe interpretation, the typical cor...
#
# Conversation 57:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic (DFT/vdW-DF study of TPP physisorption on CNTs and graphene) and the main findings: strong π–π binding, binding strength incr...
#
# Conversation 58:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it describes simulating the solar coronal magnetic field evolution driven by flux emergence and photospheric shearing, the...
#
# Conversation 59:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: SMQC without nonlocal measurements is reduced to secure two-party computation of NL-CNOT, which in the passive adversary m...
#
# Conversation 60:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic (single-site entanglement entropy at the Mott metal–insulator transition in the infinite-dimensional Hubbard model) and metho...
#
# Conversation 61:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a key inaccuracy: it states that the three-armed spiral structure is seen on the Q0 map, whereas the paper explicitly attributes this structure to the Q1 ...
#
# Conversation 62:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and methods: a numerical approach to study non-ergodicity in the Coulomb glass, construction of an (almost) complete set of l...
#
# Conversation 63:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core contribution: extending the Nowak–May spatial Prisoner’s Dilemma by introducing an environmental threshold (xmath0) that agent...
#
# Conversation 64:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s key claims: that the geometry (paths) of Wilson lines in TMD PDFs and the soft factor can be derived from process kinematics togeth...
#
# Conversation 65:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content. The paper develops a simple electrostatic model with Thomas-Fermi–type screening (Poisson equation with a screening length...
#
# Conversation 66:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary includes incorrect and unsupported claims. The paper explicitly demonstrates at least one charged solution (the trigonometric case) that satisfies all physical acc...
#
# Conversation 67:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope and findings: N-body simulations of marginally unstable multi-planet systems with and without external planetesimal disks; is...
#
# Conversation 68:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on using light-cone sum rules (LCSR) with renewed distribution amplitudes and two interpolating currents (CZ-type and Ioffe-t...
#
# Conversation 69:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary introduces “the speed of removal,” which is not discussed in the provided text. The paper analyzes separation (distance) between leading and following polarities b...
#
# Conversation 70:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic and key findings: HST two-epoch differential proper-motion analysis of the Egg Nebula’s lobes and concentric arcs; two-step i...
#
# Conversation 71:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and main findings: a three-wave (two FF + one SH) quadratic medium with a Bragg grating; existence and broad modulational sta...
#
# Conversation 72:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary broadly matches the topic (quench from a domain-wall state in a gapped antiferromagnetic XXZ/Heisenberg chain, use of exact wavefunctions and overlaps) but oversta...
#
# Conversation 73:
#   Judgment: No
#   Explanation preview: Faithfulness (62/100):
# - The summary includes an incorrect overgeneralization: it states that nova duration is determined by strong wind mass loss that “depends only on the white dwarf mass.” The pape...
#
# Conversation 74:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope and findings: micromagnetic simulations plus Thiele-equation analysis; motion governed by interplay between magnonic driving ...
#
# Conversation 75:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - The summary correctly states the paper’s focus on transport properties of dense electron–proton plasma under strong quantizing magnetic fields and that an exact relativistic f...
#
# Conversation 76:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content. It correctly states the focus on aspherical nebulae around massive stars, the comparison to planetary nebulae (PNe), ...
#
# Conversation 77:
#   Judgment: No
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s context and goals: PHENIX’s large, distributed collaboration, growing data volumes (~1/4 PB/year), the focus on grid-based solution...
#
# Conversation 78:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and key claims: nematicity in Sr3Ru2O7 (bilayer ruthenate), the generic first-order nature of the isotropic–nematic transitio...
#
# Conversation 79:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It correctly states that multi-post re-entrant cavities are modeled as magnetically coupled lumped-element harmonic oscill...
#
# Conversation 80:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces at least one unsupported, specific numerical claim: it states that gas–liquid coexistence disappears “for particle radii in the range of 1–3 nm,” which ...
#
# Conversation 81:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it describes initial weak-lensing results for nearby SDSS clusters, selection from the C4 and Berlind spectroscopic catalo...
#
# Conversation 82:
#   Judgment: Yes
#   Explanation preview: Faithfulness (75/100):
# - Strengths: The summary correctly states that the paper studies how tight focusing affects far-field cross sections and near-field enhancement for gold and silver nanospheres, ...
#
# Conversation 83:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content. It correctly states the existence of gap-Townes solitons in multidimensional (2D/3D) Gross–Pitaevskii equations with ...
#
# Conversation 84:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - The summary accurately reflects the paper’s focus on 1D bosons and fermions with zero-range interactions but finite effective range, the use of a two-channel (Hamiltonian two-...
#
# Conversation 85:
#   Judgment: No
#   Explanation preview: Faithfulness (85/100):
# - The summary correctly states the central conclusion that the non-anticommutativity parameter in the N=1/2 (denoted @xmath0) SU(N) (denoted @xmath1) gauge theory is found to be...
#
# Conversation 86:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s focus on replacing EpicFlow’s sparse-to-dense interpolation with a fully convolutional, data-driven method.
# - It correctly notes th...
#
# Conversation 87:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the core content of the paper: it states Kauffman’s conjecture about the simplest solution, that the paper proves it, and notes the connection ...
#
# Conversation 88:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects key claims: quadratic divergences cancel when tadpoles cancel; this cancellation involves top, Goldstone, and Higgs loops; and bosonic correcti...
#
# Conversation 89:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on the hydrodynamic instability of an accelerating ionization front (IF) into a molecular cloud and the formation of pillars....
#
# Conversation 90:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states the central idea: connecting the cumulants of time-integrated observables in closed quantum systems to...
#
# Conversation 91:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It correctly states that the study analyzes high-frequency p-mode oscillations localized in neutron star envelopes, highli...
#
# Conversation 92:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s main claim that magneto-convection can form active regions without a pre-existing coherent flux tube.
# - It correctly describes the ...
#
# Conversation 93:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary largely reflects the core idea of the paper: that non-spherical (elliptical) galaxy halos induce a shear–ellipticity anti-correlation that can contaminate tomograp...
#
# Conversation 94:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: it refers to adiabatic techniques known from multi-level (optical/atomic) systems, their application to ultracold ato...
#
# Conversation 95:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s content: it describes a one-way light-path laser diffraction experiment aligned relative to the Earth’s velocity vector (as inferre...
#
# Conversation 96:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it reports new Chandra X-ray and FCRAO CO observations, the identification of three CO clouds around the lobe, the key fin...
#
# Conversation 97:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: constructing an interaction potential for ground-state Mg–Mg collisions, using it to reproduce rovibrational term val...
#
# Conversation 98:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core claims: bars drive gas inflow via gravitational torques; viscous torques are not the primary driver; CMC growth alone often ca...
#
# Conversation 99:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core claims: two sources of velocity error in PTV (acceleration vs. position uncertainty), opposing trends with frame rate, error p...
#
# Conversation 100:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: it reports a dip (dearth) of disk stars near zero angular momentum in Gaia-DR1/TGAS cross-matched with RAVE, attribut...
#
# Conversation 101:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content: it discusses UV spectra of hot hydrogen-rich CSPN observed with FUSE and HST, the dominance of Fe/Ni lines, their use as t...
#
# Conversation 102:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# ...
#
# Conversation 940:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a specific numerical claim that contradicts the paper: it states second-layer promotion occurs at 0.111(4) Å^-2, while the paper reports 0.107(3) Å^-2 (an...
#
# Conversation 941:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary includes several claims not supported by the provided paper text. It states that 0957+561 is the first gravitational lens discovered and the first with a measured ...
#
# Conversation 942:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly states the study measures FP parameters for six field ellipticals at intermediate redshift using HST MDS imaging, finds a zero-point offset in...
#
# Conversation 943:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the common belief that plane wave spacetimes are causally well-behaved and accurately captures the paper’s central claim that the autho...
#
# Conversation 944:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains factual inaccuracies. It states that the magnetic field is lower than 10 MG, whereas the paper constrains it more strictly to B < 3 MG based on the absenc...
#
# Conversation 945:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary is mostly aligned with the paper’s content (mission goal, Q1 analysis, use of raw vs PDC time series, and the conclusion that precision meets expectations).
# - How...
#
# Conversation 946:
#   Judgment: No
#   Explanation preview: Faithfulness (85/100):
# - The summary broadly aligns with the paper’s themes: QSO absorption lines as probes of chemical, ionization, and kinematic conditions; leveraging Milky Way and nearby galaxies ...
#
# Conversation 947:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s core claims: apparent cosmic acceleration arises from causal backreaction due to structure formation, without invoking dark energy,...
#
# Conversation 948:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: it focuses on uncertainty propagation with emphasis on asymmetric uncertainties; adopts a Bayesian probabilistic fram...
#
# Conversation 949:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: proposing and testing the WTMM (wavelet transform modulus maxima) method for automated coronal loop detection in EUV ...
#
# Conversation 950:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s focus: predicting correlations between Lyman-alpha forest transmitted flux and underlying mass using HPM simulations validated agai...
#
# Conversation 951:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# The summary accurately reflects the paper’s core content. It correctly states that the authors present a simple, exactly solvable model for qubit noise with zero-bandwidth envir...
#
# Conversation 952:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it mentions observed electron-cloud effects during LHC commissioning, the development of a benchmarking method that relate...
#
# Conversation 953:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary accurately states the main contribution (implementing a hierarchical tree algorithm within an individual-timestep Hermite scheme on GRAPE-9), the role of indirect ...
#
# Conversation 954:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core claims: the superconducting state in cuprates is inhomogeneous; two classes of inhomogeneous microscopic models are proposed; ...
#
# Conversation 955:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary includes specific details not supported in the provided text, notably that the muon tracker has “six horizontal layers” and that the neutron detector is “sandwiche...
#
# Conversation 956:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s core content: probing the excitations of strongly interacting 1D Bose gases via Bragg spectroscopy, analyzing the dynamical structu...
#
# Conversation 957:
#   Judgment: No
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately states that the paper discusses general properties of extensive air showers, focuses on longitudinal development (including energy flow), and covers lat...
#
# Conversation 958:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary misattributes the primary cause of the geometric distortion to the “off-axis location of the ACS.” The provided text explicitly states that the tilted focal surfac...
#
# Conversation 959:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope: interpolating Padova94 stellar evolutionary tracks in metallicity, care to avoid spurious features, subdivision into evoluti...
#
# Conversation 960:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic (2D viscous flow around a flapping foil in a uniform stream), method (lattice Boltzmann simulations at moderate Reynolds numb...
#
# Conversation 961:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the core content: use of MDI/SOHO data during solar cycle 23, analysis of centroid frequencies and splitting coefficients, construction of a se...
#
# Conversation 962:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it describes first-principles (DFT) investigation of graphene in contact with and sandwiched between WS2 and WSe2, notes i...
#
# Conversation 963:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content. It correctly states that confinement typically lowers transition temperatures (e.g., freezing and superfluid transition in...
#
# Conversation 964:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that 3D radiative-hydrodynamical simulations were performed for HD140283 and HD84937, that adiabatic c...
#
# Conversation 965:
#   Judgment: Yes
#   Explanation preview: Faithfulness (84/100):
# - The summary accurately reflects the paper’s core content: using a weather station to measure solar irradiance, employing a collocated sky camera to automatically compute cloud...
#
# Conversation 966:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that the analysis starts from coupled Boltzmann equations, addresses two-species cold gases in both a ...
#
# Conversation 967:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 88
# - The summary accurately reflects the paper’s main focus: calculating the mass and decay constant of a strange tensor meson via QCD sum rules.
# - It correctly notes consistency...
#
# Conversation 968:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content as an agenda-setting overview of open questions in star and cluster formation.
# - It correctly mentions key debates discusse...
#
# Conversation 969:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It states that the late-time behavior of the Einstein–dust system is well understood for homogeneous (Bianchi) spacetimes,...
#
# Conversation 970:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly states the core setup (BEC Bogoliubov modes coupled to a cavity field), and the main findings that radiation pressure modifies the Bogoliubov ...
#
# Conversation 971:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core claims: article page views peak and then decay, the decay is nonexponential, and this behavior resembles physical aging in com...
#
# Conversation 972:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - The summary accurately reflects the paper’s main claims: long-range interactions between dark solitons in inhomogeneous BECs mediated by sound, energy exchange without direct ...
#
# Conversation 973:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: exploiting low-dimensional slow/inertial manifolds to enable efficient computations; the difficulty of approximating ...
#
# Conversation 974:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it studies gravitational waves during preheating; notes that inflaton oscillations drive parametric resonance in scalar fl...
#
# Conversation 975:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it emphasizes the central role of the ISM in disk galaxy formation, the split between cosmological simulations and local I...
#
# Conversation 976:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it reports two possible infrared counterparts to SGR 1806-20, localization with archival Chandra data to a stated accuracy...
#
# Conversation 977:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core ideas: the importance of conformal invariance, the usual definition requiring a group action on fields and metric rescaling, a...
#
# Conversation 978:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary inaccurately describes the decays as “semileptonic” (“simileptonic”), whereas the paper studies OZI-forbidden hadronic annihilation decays of the B_c into light me...
#
# Conversation 979:
#   Judgment: No
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic: 2D Fermi gases, the BCS–BEC crossover enabled by Fano–Feshbach resonances, and the BKT transition.
# - It correctly states tha...
#
# Conversation 980:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content. It states that the theory expresses anomalous Hall conductivity in terms of local (single-site) atomic-like orbitals,...
#
# Conversation 981:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary correctly captures key observations (delayed, long-lived GeV emission), the proposed external-shock synchrotron interpretation, the no–magnetic-field-am...
#
# Conversation 982:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope: HI 21-cm absorption observations toward radio sources close to lines of sight to 25 previously studied stars; this is framed...
#
# Conversation 983:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it identifies attribute reduction as the motivating problem, notes the use of rough sets and matroids, states that a depen...
#
# Conversation 984:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary largely reflects the paper’s focus and conclusions for MCG−6-30-15 (i.e., that the Compton downscattering model violates constraints such as the blackbody limit an...
#
# Conversation 985:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains at least two factual inaccuracies relative to the paper. First, it claims that the majority of the IR emission arises from “@xmath0100pc,” introducing an ...
#
# Conversation 986:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s main topics: high-energy factorization in QCD for DIS and p–A, the use of Wilson lines and rapidity factorization, the role of the ...
#
# Conversation 987:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic (ODCR in nominally undoped CdTe/(Cd,Mn)Te QWs), key findings (electron effective mass increases as QW width decreases; numeri...
#
# Conversation 988:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary correctly captures the paper’s focus on assessing the 2880 Earth impact risk of asteroid (29075) 1950 DA, identifies the Yarkovsky effect as the dominan...
#
# Conversation 989:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - The summary accurately reflects the paper’s topic: evaluating how low- and high-energy hadronic interaction models and the transition energy affect ground-level muon and elect...
#
# Conversation 990:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 92
# - The summary accurately reflects the paper’s core content: spectrogram-based time–frequency analysis from a single stationary sensor; use of geometric arguments and an ideali...
#
# Conversation 991:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a clear factual error about data size: it states “33,708 tweets,” whereas the paper reports collecting 371,264 tweets (with 41% removed in preprocessing, ...
#
# Conversation 992:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: a two-dimensional numerical study of the boundary-fed CDIMA reaction–diffusion system using a realistic (LRE) model; ...
#
# Conversation 993:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and findings: stability of Uranus Trojans near L4/L5 using N-body OSS integrations; use of a-cuts (varying semimajor axis at ...
#
# Conversation 994:
#   Judgment: No
#   Explanation preview: Faithfulness (80/100):
# - Mostly accurate: The summary correctly states that the heavy quark is static, the light quark mass is near the strange quark, the study focuses on excited states (higher angul...
#
# Conversation 995:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on worst-case mobile users in OFDM-based cellular networks modeled via stochastic geometry.
# - It correctly states that the au...
#
# Conversation 996:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Largely accurate: it correctly states that 21 lithium-rich ROSAT counterparts were observed by Hipparcos; that parallaxes, proper motions, and photometry were analyzed; that 1...
#
# Conversation 997:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content. It correctly identifies XRF 030723 as the first likely XRF–SN association, describes the use of synthetic light curves to ...
#
# Conversation 998:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it describes the adiabatic matter creation framework, the datasets used (SNe Ia, H(z), CMB, BAO), the flat-universe assump...
#
# Conversation 999:
#   Judgment: No
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately states that the paper introduces a new equilibration scenario (ISIPP) in heavy-ion collisions and discusses its implications for equilibration and parti...
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total evaluated: 1000
# Yes: 748 (74.8%)
# No: 252 (25.2%)
# Unknown: 0 (0.0%)

# %%
# Save results to JSONL file
import json

# Create filename with baseline_eval in it
output_filename = f"/Users/ryanarman/code/lab/arxiv_abstract/data/original_eval_qwen3_4b_test.jsonl"

# Write results to JSONL file
with open(output_filename, 'w', encoding='utf-8') as f:
    for idx, result, prompt in original_results:
        output_data = {
            'index': idx,
            'judgment': result['judgment'],
            'explanation': result['explanation'],
            'evaluation_prompt': prompt
        }
        f.write(json.dumps(output_data, ensure_ascii=False) + '\n')

print(f"Saved {len(original_results)} results to {output_filename}")
# Out:
# Saved 1000 results to /Users/ryanarman/code/lab/arxiv_abstract/data/original_eval_qwen3_4b_test.jsonl

# %% [markdown]
# ## original abstract: 75%

# %% [markdown]
# # Run inference on the base model

# %%
train_instruct_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_instruct.jsonl"
val_instruct_path =   "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_val_instruct.jsonl"
test_instruct_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_test_instruct.jsonl"
# train_distilled_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_abstract_train_gpt5mini_think2.jsonl"
train_instruct_conversations = load_conversations(train_instruct_path)
val_instruct_conversations = load_conversations(val_instruct_path)
test_instruct_conversations = load_conversations(test_instruct_path)

# %%
train_instruct_conversations[0]
# Out:
# [{'role': 'system',
#   'content': "You are an expert academic abstract writer. Your task is to create a high-quality abstract for an arXiv paper based on the paper content and judge evaluation feedback.\n\nThe judge evaluates abstracts based on five dimensions:\n1. Faithfulness: The abstract must accurately reflect the paper's content without hallucination\n2. Coverage: The abstract must include the essential aspects (main problem, approach, and key results)\n3. Clarity: The abstract must be understandable and readable\n4. Conciseness: The abstract must be focused and not verbose\n5. Coherence: The abstract must be logically structured and flow naturally\n\nWhen creating the abstract:\n- Read the paper content carefully\n- Pay attention to the judge's feedback on what makes a good abstract\n- Ensure your abstract meets all five evaluation criteria\n- Write a concise, clear, and coherent summary that accurately covers the paper's main contributions\n- Focus on the main problem, approach, and key results\n\nYour response should be the abstract only, without any additional commentary or explanation."},
#  {'role': 'user',
#   'content': 'Paper Content:\nadditive models @xcite provide an important family of models for semiparametric regression or classification . some reasons for the success of additive models are their increased flexibility when compared to linear or generalized linear models and their increased interpretability when compared to fully nonparametric models . \n it is well - known that good estimators in additive models are in general less prone to the curse of high dimensionality than good estimators in fully nonparametric models . \n many examples of such estimators belong to the large class of regularized kernel based methods over a reproducing kernel hilbert space @xmath0 , see e.g. @xcite . in the last years \n many interesting results on learning rates of regularized kernel based models for additive models have been published when the focus is on sparsity and when the classical least squares loss function is used , see e.g. @xcite , @xcite , @xcite , @xcite , @xcite , @xcite and the references therein . of course , the least squares loss function is differentiable and has many nice mathematical properties , but it is only locally lipschitz continuous and therefore regularized kernel based methods based on this loss function typically suffer on bad statistical robustness properties , even if the kernel is bounded . \n this is in sharp contrast to kernel methods based on a lipschitz continuous loss function and on a bounded loss function , where results on upper bounds for the maxbias bias and on a bounded influence function are known , see e.g. @xcite for the general case and @xcite for additive models . \n therefore , we will here consider the case of regularized kernel based methods based on a general convex and lipschitz continuous loss function , on a general kernel , and on the classical regularizing term @xmath1 for some @xmath2 which is a smoothness penalty but not a sparsity penalty , see e.g. @xcite . \n such regularized kernel based methods are now often called support vector machines ( svms ) , although the notation was historically used for such methods based on the special hinge loss function and for special kernels only , we refer to @xcite .    in this paper we address the open question , whether an svm with an additive kernel can provide a substantially better learning rate in high dimensions than an svm with a general kernel , say a classical gaussian rbf kernel , if the assumption of an additive model is satisfied . \n our leading example covers learning rates for quantile regression based on the lipschitz continuous but non - differentiable pinball loss function , which is also called check function in the literature , see e.g. @xcite and @xcite for parametric quantile regression and @xcite , @xcite , and @xcite for kernel based quantile regression . \n we will not address the question how to check whether the assumption of an additive model is satisfied because this would be a topic of a paper of its own . \n of course , a practical approach might be to fit both models and compare their risks evaluated for test data . \n for the same reason we will also not cover sparsity . \n consistency of support vector machines generated by additive kernels for additive models was considered in @xcite . in this paper \n we establish learning rates for these algorithms . \n let us recall the framework with a complete separable metric space @xmath3 as the input space and a closed subset @xmath4 of @xmath5 as the output space . \n a borel probability measure @xmath6 on @xmath7 is used to model the learning problem and an independent and identically distributed sample @xmath8 is drawn according to @xmath6 for learning . \n a loss function @xmath9 is used to measure the quality of a prediction function @xmath10 by the local error @xmath11 . \n _ throughout the paper we assume that @xmath12 is measurable , @xmath13 , convex with respect to the third variable , and uniformly lipschitz continuous satisfying @xmath14 with a fini ...
#  {'role': 'assistant',
#   'content': 'additive models play an important role in semiparametric statistics . \n this paper gives learning rates for regularized kernel based methods for additive models . \n these learning rates compare favourably in particular in high dimensions to recent results on optimal learning rates for purely nonparametric regularized kernel based quantile regression using the gaussian radial basis function kernel , provided the assumption of an additive model is valid . \n additionally , a concrete example is presented to show that a gaussian function depending only on one variable lies in a reproducing kernel hilbert space generated by an additive gaussian kernel , but does not belong to the reproducing kernel hilbert space generated by the multivariate gaussian kernel of the same variance .    * \n key words and phrases . * additive model , kernel , quantile regression , semiparametric , rate of convergence , support vector machine .'}]

# %%
test_instruct_conversations[0]
# Out:
# [{'role': 'system',
#   'content': "You are an expert academic abstract writer. Your task is to create a high-quality abstract for an arXiv paper based on the paper content and judge evaluation feedback.\n\nThe judge evaluates abstracts based on five dimensions:\n1. Faithfulness: The abstract must accurately reflect the paper's content without hallucination\n2. Coverage: The abstract must include the essential aspects (main problem, approach, and key results)\n3. Clarity: The abstract must be understandable and readable\n4. Conciseness: The abstract must be focused and not verbose\n5. Coherence: The abstract must be logically structured and flow naturally\n\nWhen creating the abstract:\n- Read the paper content carefully\n- Pay attention to the judge's feedback on what makes a good abstract\n- Ensure your abstract meets all five evaluation criteria\n- Write a concise, clear, and coherent summary that accurately covers the paper's main contributions\n- Focus on the main problem, approach, and key results\n\nYour response should be the abstract only, without any additional commentary or explanation."},
#  {'role': 'user',
#   'content': 'Paper Content:\nas a common quantum phenomenon , the tunneling through a potential barrier plays a very important role in the microscopic world and has been studied extensively since the birth of quantum mechanics . \n one of the earliest applications of quantum tunneling is the explanation of @xmath0 decays in atomic nuclei . \n the quantum tunneling effect governs also many other nuclear processes such as fission and fusion . \n in particular , a lot of new features are revealed in sub - barrier fusion reactions which are closely connected with the tunneling phenomena  @xcite .    for most of the potential barriers , the penetrability can not be calculated analytically  @xcite . among those potentials for which analytical solutions can be obtained , \n the parabolic potential  @xcite is the mostly used in the study of nuclear fusion . by approximating the coulomb barrier to a parabola \n , wong derived an analytic expression for the fusion cross section  @xcite which is widely adopted today in the study of heavy ion reactions ( see , e.g. , recent refs . \n the parabolic approximation works remarkably well both for the penetrability and for the fusion cross section at energies around or above the coulomb barrier  @xcite . \n apparently the parabolic approximation breaks down at energies much smaller than the barrier height due to the long - range coulomb interaction . \n one may calculate the penetration probability numerically by using the path integral method or the wkb approximation . \n however , it is highly desirable to have an analytical expression for the barrier penetrability when one introduces an energy - dependent one - dimensional potential barrier  @xcite or barrier distribution functions  @xcite .    in the present work \n , we derived a new barrier penetration formula based on the wkb approximation . \n the influence of the long coulomb tail in the barrier potential is taken into accout properly . \n therefore this formula is especially applicable to the barrier penetration with penetration energy much lower than the coulomb barrier .    as a first attempt and a test study \n , we apply this new formula to evaluate @xmath0 decay half - lives of atomic nuclei . for the @xmath0 decay , \n the penetrability is usually calculated with the wkb approach  @xcite , in other words , integrating numerically the wave number within two turning points at which the interaction potential is equal to the @xmath1-value of the @xmath0 decay . \n we will show that the present analytical formula reproduces the experimental results very well , especially for spherical nuclei . \n the paper is organized as follows . in sec . \n [ sec : formalism ] we present the new barrier penetration formula . \n the validity of the new formula is investigated and its application to @xmath0 decays are given in sec . \n [ sec : results ] . finally in sec . \n [ sec : summary ] we summarize our work . in the appendix , \n the detailed derivation of the new penetration formula is given . \n when the penetration energy is well below the coulomb barrier , the barrier penetrability formula derived from the wkb approximation reads , @xmath2 ,   \\label{eq : wkb}\\ ] ] where the potential usually consists of three parts , the nuclear , the coulomb , and the centrifugal potentials , @xmath3 @xmath4 and @xmath5 are the inner and outer turning points determined by the relation @xmath6 .    by approximating @xmath7 to a parabola with the height @xmath8 and the width @xmath9 , eq . \n ( [ eq : wkb ] ) is reduced as @xmath10 ,   \\label{eq : hw}\\ ] ] which has been widely used in the study of heavy ion reactions .    because of the long - range coulomb interaction , the coulomb barrier given in eq . \n ( [ eq : potential ] ) has a long tail and is asymmetric . \n thus for the penetration well below the barrier , the parabolic approximation is not valid . \n we may divide the potential barrier into two parts at the barrier position @xmath11 . \n ...

# %% [markdown]
# How to run inference on the cluster
#
# From the arxiv_abstract root directory:
#
# Option 1: Basic usage (uses defaults)
#   cd scripts
#   ./submit_inference_rsync.sh
#
# Option 2: Custom input file
#   cd scripts
#   ./submit_inference_rsync.sh ../data/arxiv_summarization_test_instruct.jsonl
#
# Option 3: Full specification
#   cd scripts
#   ./submit_inference_rsync.sh \
#     ../data/arxiv_summarization_test_instruct.jsonl \
#     ../configs/4b_instruct_vllm_infer.yaml \
#     qwen3_4b_test
#
# Option 4: With trained LoRA adapter
#   cd scripts
#   ./submit_inference_rsync.sh \
#     ../data/arxiv_summarization_test_instruct.jsonl \
#     ../configs/4b_instruct_vllm_infer.yaml \
#     output_name \
#     path/to/adapter/checkpoint \
#     ryan@exun
#
# Defaults:
#   - Input: data/arxiv_summarization_test_instruct.jsonl
#   - Config: configs/4b_instruct_vllm_infer.yaml
#   - Output name: output
#   - Cluster: ryan@exun
#
# The script will:
#   1. Copy files to the cluster using rsync
#   2. Submit a SLURM job for inference
#   3. Output will be saved to: data/output_<job_id>.jsonl on the cluster
#
# To check job status:
#   ssh ryan@exun 'squeue -u ryan'
#
# To view logs:
#   ssh ryan@exun 'tail -f /home/ryan/code/oumi/lab/arxiv_abstract/logs/arxiv_abstract_inference_qwen3_4b_*.log'
#
# To download results:
#   scp ryan@exun:/home/ryan/code/oumi/lab/arxiv_abstract/data/output_*.jsonl ./data/

# %%
base_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/qwen3_4b_test_2795.jsonl"
# train_distilled_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_abstract_train_gpt5mini_think2.jsonl"
base_qwen3_4b_test_conversations = load_conversations(base_qwen3_4b_test_path)

# %%
base_qwen3_4b_test_conversations_eval = [conv[1:] for conv in base_qwen3_4b_test_conversations]

# %%
conv = base_qwen3_4b_test_conversations_eval[0]
# Out:
# [{'content': 'Paper Content:\nas a common quantum phenomenon , the tunneling through a potential barrier plays a very important role in the microscopic world and has been studied extensively since the birth of quantum mechanics . \n one of the earliest applications of quantum tunneling is the explanation of @xmath0 decays in atomic nuclei . \n the quantum tunneling effect governs also many other nuclear processes such as fission and fusion . \n in particular , a lot of new features are revealed in sub - barrier fusion reactions which are closely connected with the tunneling phenomena  @xcite .    for most of the potential barriers , the penetrability can not be calculated analytically  @xcite . among those potentials for which analytical solutions can be obtained , \n the parabolic potential  @xcite is the mostly used in the study of nuclear fusion . by approximating the coulomb barrier to a parabola \n , wong derived an analytic expression for the fusion cross section  @xcite which is widely adopted today in the study of heavy ion reactions ( see , e.g. , recent refs . \n the parabolic approximation works remarkably well both for the penetrability and for the fusion cross section at energies around or above the coulomb barrier  @xcite . \n apparently the parabolic approximation breaks down at energies much smaller than the barrier height due to the long - range coulomb interaction . \n one may calculate the penetration probability numerically by using the path integral method or the wkb approximation . \n however , it is highly desirable to have an analytical expression for the barrier penetrability when one introduces an energy - dependent one - dimensional potential barrier  @xcite or barrier distribution functions  @xcite .    in the present work \n , we derived a new barrier penetration formula based on the wkb approximation . \n the influence of the long coulomb tail in the barrier potential is taken into accout properly . \n therefore this formula is especially applicable to the barrier penetration with penetration energy much lower than the coulomb barrier .    as a first attempt and a test study \n , we apply this new formula to evaluate @xmath0 decay half - lives of atomic nuclei . for the @xmath0 decay , \n the penetrability is usually calculated with the wkb approach  @xcite , in other words , integrating numerically the wave number within two turning points at which the interaction potential is equal to the @xmath1-value of the @xmath0 decay . \n we will show that the present analytical formula reproduces the experimental results very well , especially for spherical nuclei . \n the paper is organized as follows . in sec . \n [ sec : formalism ] we present the new barrier penetration formula . \n the validity of the new formula is investigated and its application to @xmath0 decays are given in sec . \n [ sec : results ] . finally in sec . \n [ sec : summary ] we summarize our work . in the appendix , \n the detailed derivation of the new penetration formula is given . \n when the penetration energy is well below the coulomb barrier , the barrier penetrability formula derived from the wkb approximation reads , @xmath2 ,   \\label{eq : wkb}\\ ] ] where the potential usually consists of three parts , the nuclear , the coulomb , and the centrifugal potentials , @xmath3 @xmath4 and @xmath5 are the inner and outer turning points determined by the relation @xmath6 .    by approximating @xmath7 to a parabola with the height @xmath8 and the width @xmath9 , eq . \n ( [ eq : wkb ] ) is reduced as @xmath10 ,   \\label{eq : hw}\\ ] ] which has been widely used in the study of heavy ion reactions .    because of the long - range coulomb interaction , the coulomb barrier given in eq . \n ( [ eq : potential ] ) has a long tail and is asymmetric . \n thus for the penetration well below the barrier , the parabolic approximation is not valid . \n we may divide the potential barrier into two parts at the barrier position @xmath11 . \n ...
#   'role': 'user'},
#  {'content': '**Abstract**\n\nQuantum tunneling through potential barriers is a fundamental phenomenon in nuclear physics, particularly in processes such as alpha decay. While the parabolic approximation has long been used to calculate barrier penetrability, it fails at low energies—much below the Coulomb barrier—due to the long-range nature of the Coulomb interaction. In this work, we derive a new analytical formula for barrier penetrability based on the WKB approximation that properly accounts for the Coulomb tail in the potential. By dividing the potential into inner and outer regions and applying a Woods-Saxon form to the nuclear part, we obtain a closed-form expression that accurately describes the penetration probability at energies well below the barrier. We apply this formula to calculate alpha decay half-lives for 344 nuclei using realistic nuclear and Coulomb potentials. For spherical and even-even nuclei, our results show excellent agreement with experimental data, with a root-mean-square deviation of 0.34. The new formula reproduces the WKB results well and significantly improves upon the parabolic approximation in the low-energy regime. It is especially useful for systems where energy-dependent potentials or barrier distributions are involved, offering a practical analytical tool for studying sub-barrier tunneling phenomena.',
#   'role': 'assistant'}]

# %%
result, evaluation_prompt = evaluate_summary(conv, model="gpt-5")
print(f"Judgment: {result['judgment']}")
print(f"\nExplanation:\n{result['explanation']}")

# %%
# Batch evaluation for the first 10 conversations

base_results, base_errors = evaluate_summaries_batch(
    # base_qwen3_4b_test_conversations_eval[:10],
    base_qwen3_4b_test_conversations_eval,
    model="gpt-5",
    temperature=1.0,
    max_workers=1000,  # Adjust based on your API rate limits
    show_progress=True
)

# Display results
print("\n" + "="*80)
print("BATCH EVALUATION RESULTS")
print("="*80)

for idx, result, prompt in base_results:
    print(f"\nConversation {idx}:")
    print(f"  Judgment: {result['judgment']}")
    # Optionally show a snippet of the explanation
    explanation_preview = result['explanation'][:200] + "..." if len(result['explanation']) > 200 else result['explanation']
    print(f"  Explanation preview: {explanation_preview}")

if base_errors:
    print(f"\nErrors encountered: {len(base_errors)}")
    for idx, error in base_errors:
        print(f"  Conversation {idx}: {error}")

# Summary statistics
judgments = [result['judgment'] for _, result, _ in base_results]
yes_count = judgments.count('Yes')
no_count = judgments.count('No')
unknown_count = judgments.count('Unknown')

print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Total evaluated: {len(base_results)}")
print(f"Yes: {yes_count} ({yes_count/len(base_results)*100:.1f}%)")
print(f"No: {no_count} ({no_count/len(base_results)*100:.1f}%)")
print(f"Unknown: {unknown_count} ({unknown_count/len(base_results)*100:.1f}%)")
# Out:
# Evaluating 1000 conversations with 1000 workers...
#   Completed 1/1000
#   Completed 2/1000
#   Completed 3/1000
#   Completed 4/1000
#   Completed 5/1000
#   Completed 6/1000
#   Completed 7/1000
#   Completed 8/1000
#   Completed 9/1000
#   Completed 10/1000
#   Completed 11/1000
#   Completed 12/1000
#   Completed 13/1000
#   Completed 14/1000
#   Completed 15/1000
#   Completed 16/1000
#   Completed 17/1000
#   Completed 18/1000
#   Completed 19/1000
#   Completed 20/1000
#   Completed 21/1000
#   Completed 22/1000
#   Completed 23/1000
#   Completed 24/1000
#   Completed 25/1000
#   Completed 26/1000
#   Completed 27/1000
#   Completed 28/1000
#   Completed 29/1000
#   Completed 30/1000
#   Completed 31/1000
#   Completed 32/1000
#   Completed 33/1000
#   Completed 34/1000
#   Completed 35/1000
#   Completed 36/1000
#   Completed 37/1000
#   Completed 38/1000
#   Completed 39/1000
#   Completed 40/1000
#   Completed 41/1000
#   Completed 42/1000
#   Completed 43/1000
#   Completed 44/1000
#   Completed 45/1000
#   Completed 46/1000
#   Completed 47/1000
#   Completed 48/1000
#   Completed 49/1000
#   Completed 50/1000
#   Completed 51/1000
#   Completed 52/1000
#   Completed 53/1000
#   Completed 54/1000
#   Completed 55/1000
#   Completed 56/1000
#   Completed 57/1000
#   Completed 58/1000
#   Completed 59/1000
#   Completed 60/1000
#   Completed 61/1000
#   Completed 62/1000
#   Completed 63/1000
#   Completed 64/1000
#   Completed 65/1000
#   Completed 66/1000
#   Completed 67/1000
#   Completed 68/1000
#   Completed 69/1000
#   Completed 70/1000
#   Completed 71/1000
#   Completed 72/1000
#   Completed 73/1000
#   Completed 74/1000
#   Completed 75/1000
#   Completed 76/1000
#   Completed 77/1000
#   Completed 78/1000
#   Completed 79/1000
#   Completed 80/1000
#   Completed 81/1000
#   Completed 82/1000
#   Completed 83/1000
#   Completed 84/1000
#   Completed 85/1000
#   Completed 86/1000
#   Completed 87/1000
#   Completed 88/1000
#   Completed 89/1000
#   Completed 90/1000
#   Completed 91/1000
#   Completed 92/1000
#   Completed 93/1000
#   Completed 94/1000
#   Completed 95/1000
#   Completed 96/1000
#   Completed 97/1000
#   Completed 98/1000
#   Completed 99/1000
#   Completed 100/1000
#   Completed 101/1000
#   Completed 102/1000
#   Completed 103/1000
#   Completed 104/1000
#   Completed 105/1000
#   Completed 106/1000
#   Completed 107/1000
#   Completed 108/1000
#   Completed 109/1000
#   Completed 110/1000
#   Completed 111/1000
#   Completed 112/1000
#   Completed 113/1000
#   Completed 114/1000
#   Completed 115/1000
#   Completed 116/1000
#   Completed 117/1000
#   Completed 118/1000
#   Completed 119/1000
#   Completed 951/1000
#   Completed 952/1000
#   Completed 953/1000
#   Completed 954/1000
#   Completed 955/1000
#   Completed 956/1000
#   Completed 957/1000
#   Completed 958/1000
#   Completed 959/1000
#   Completed 960/1000
#   Completed 961/1000
#   Completed 962/1000
#   Completed 963/1000
#   Completed 964/1000
#   Completed 965/1000
#   Completed 966/1000
#   Completed 967/1000
#   Completed 968/1000
#   Completed 969/1000
#   Completed 970/1000
#   Completed 971/1000
#   Completed 972/1000
#   Completed 973/1000
#   Completed 974/1000
#   Completed 975/1000
#   Completed 976/1000
#   Completed 977/1000
#   Completed 978/1000
#   Completed 979/1000
#   Completed 980/1000
#   Completed 981/1000
#   Completed 982/1000
#   Completed 983/1000
#   Completed 984/1000
#   Completed 985/1000
#   Completed 986/1000
#   Completed 987/1000
#   Completed 988/1000
#   Completed 989/1000
#   Completed 990/1000
#   Completed 991/1000
#   Completed 992/1000
#   Completed 993/1000
#   Completed 994/1000
#   Completed 995/1000
#   Completed 996/1000
#   Completed 997/1000
#   Completed 998/1000
#   Completed 999/1000
#   Completed 1000/1000
#
# ✓ Completed: 1000 successful, 0 errors
#
# ================================================================================
# BATCH EVALUATION RESULTS
# ================================================================================
#
# Conversation 0:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it presents a new WKB-based analytical penetration formula that accounts for the long-range Coulomb tail, describes dividi...
#
# Conversation 1:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100): The summary accurately describes the problem setting (efficient HMC integrators), the methods compared (leap-frog, force-gradient, nested/multirate, and an adapted nested force-...
#
# Conversation 2:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly identifies two methods: (1) algebraic relations between products of propagators (using linear dependence amon...
#
# Conversation 3:
#   Judgment: Yes
#   Explanation preview: Faithfulness (84/100):
# - Strengths: The summary accurately describes the paper’s goal (mitigating sensitivity loss in blind searches for continuous gravitational waves), the proposed frequency Hough a...
#
# Conversation 4:
#   Judgment: No
#   Explanation preview: Faithfulness (52/100):
# - The summary introduces specific numerical claims that are not supported by the provided text. The paper uses placeholders (@xmath) for key mass values, but the summary states ...
#
# Conversation 5:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately captures the paper’s core topics: SSAs in dijet azimuthal correlations at RHIC, the role of TMDs and the Sivers effect, process dependence du...
#
# Conversation 6:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains notable inaccuracies and misattributions relative to the paper. It claims large deviation results for the time to the most recent common ancestor (MRCA), ...
#
# Conversation 7:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly identifies the paper’s goal (quantifying four-particle entanglement via the von Neumann entropy of a reduced three-particle subsystem), the ph...
#
# Conversation 8:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary largely aligns with the paper’s scope: PBH constraints on inflation, breakdown of the Stewart–Lyth formula near the end of inflation, use of a modified flow analys...
#
# Conversation 9:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 85
# - Strengths: Accurately identifies FMI’s purpose, the dual planning/execution architecture, wind/drift constraints, need to consider entire flight series, external constraints...
#
# Conversation 10:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains factual inaccuracies. It calls the D configuration a “two-level” system, whereas the paper clearly treats the D configuration as a three-level system (gro...
#
# Conversation 11:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a significant inaccuracy: it claims “an upper bound of about 90 GeV on the light top squark mass,” whereas the paper sets an upper bound of about 180 GeV ...
#
# Conversation 12:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly describes the problem setting (integer multiplication), cites relevant algorithms (Karatsuba, Toom-Cook, Schönhage–Strassen, Fürer), notes hig...
#
# Conversation 13:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported and likely incorrect specifics: it claims the differential flux falls as E^-2 and that the spectrum is nearly featureless from 10^15 to 10^1...
#
# Conversation 14:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately explains microlensing, caustic-induced anomalies, sensitivity to low-mass planets (including terrestrial masses), and emphasizes that no clea...
#
# Conversation 15:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately states the paper’s goal (estimating the Milky Way circular velocity at the Sun’s radius), the dataset (18 masers with 6D phase-space data), the modeling...
#
# Conversation 16:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple factual inaccuracies:
#   - It claims the measured channel is d + p → d + π+ + π−, whereas the paper studies the isoscalar double-pionic fusion pn ...
#
# Conversation 17:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary accurately conveys the paper’s core ideas: the limitations of linear wave functions for strong correlation, the role of stenciling, the nonlocality of H...
#
# Conversation 18:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains two key inaccuracies. It claims the simulations “reproduce the observed metallicity distribution,” whereas the paper repeatedly states the simulated distr...
#
# Conversation 19:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on semi-infinite non-Hermitian systems without PT symmetry, the dynamic balance between a non-Hermitian cluster and a semi-in...
#
# Conversation 20:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s aim (deriving the VFT law), method (quantum mechanical transition-rate arguments using activation entropy), and core modeling (clos...
#
# Conversation 21:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: a rank-three tensor model reinterpreted as dynamical commutative, nonassociative fuzzy spaces; Gaussian classical bac...
#
# Conversation 22:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately captures the paper’s motivation (cosmological constant and coincidence problems), the proposed mechanism (decaying dark matter producing a sc...
#
# Conversation 23:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 55)
# - The summary introduces “X(5568)” as an input resonance for fitting the LECs and as a partner state. The paper text does not mention X(5568); rather, it indicates that the re...
#
# Conversation 24:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic and contributions: using classical interference to realize truncated Fourier, Gauss, Kummer, and exponential sums for factori...
#
# Conversation 25:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s setting (universal PAC learning over total recursive concepts and partial recursive hypotheses), the existence of a computable lear...
#
# Conversation 26:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: first detection of [C i] emission from a protoplanetary disk (DM Tau), observations toward DM Tau, LKCa 15, TW Hya, and tw...
#
# Conversation 27:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported and likely incorrect specifics. It states ZZ Ceti stars have effective temperatures of ~5000–7000 K and pulsation periods of ~100–1000 s; th...
#
# Conversation 28:
#   Judgment: Yes
#   Explanation preview: Faithfulness (87/100):
# - Strengths: The summary accurately reflects the paper’s aims (constraining the substellar IMF via star-to–brown-dwarf ratios across nearby clusters), methods (compiling extinct...
#
# Conversation 29:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on curvature effects (linear chain vs. bent ring) in Rashba SO-coupled, multi-terminal systems using a tight-binding and Gree...
#
# Conversation 30:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on a qubit undergoing pure dephasing via coupling to a thermal bosonic bath, the use of a partial p-representation to obtain ...
#
# Conversation 31:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary misrepresents key quantitative results by changing units. The paper’s measurements are in physical units (e.g., nanometers), with 1 wavelength ≈ 650 nm on th...
#
# Conversation 32:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary generally captures the paper’s themes: pulse-wise GRB correlations, an empirical pulse model (Band+Norris+LK96) implemented in XSPEC, evidence for a two...
#
# Conversation 33:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it states the unified derivation of MFDRs at NESS using the Agarwal formalism; covers both Langevin and discrete master eq...
#
# Conversation 34:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly identifies the paper’s goal (study of chiral symmetry restoration at finite temperature), the method (composite operator formalism with an eff...
#
# Conversation 35:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s goals, setup, and main findings: linking zero-frequency current noise to Coulomb correlations and entanglement in a double quantum ...
#
# Conversation 36:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic, object of study (the Nessie IRDC), observational approach (MOPRA millimeter molecular line mapping), main observational find...
#
# Conversation 37:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces incorrect claims. It states that the paper finds “new FQHE states at ν = 1/3 and ν = 2/5 … absent in GaAs,” but the paper explicitly notes that in the n...
#
# Conversation 38:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - The summary correctly states that the paper studies molecular motor transport via lattice and continuum models, and that unbinding enhances longitudinal diffusion while reduci...
#
# Conversation 39:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s goals, methodology, and key findings: improving PVDF modeling using the halo approach, deriving velocity distributions via Abel inv...
#
# Conversation 40:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 88/100):
# - The summary accurately describes the paper’s main constructions: Maxwell solutions in the Einstein universe aligned with Hopf fibration fibres; their conformal interpre...
#
# Conversation 41:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: a thermomechanical Ginzburg–Landau model for SMAs that couples an order parameter, strain, and temperature, includes a heat ...
#
# Conversation 42:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - Strengths: The summary accurately captures the core claims: (i) the Isham–Storey solution (with the Isham–Salam–Strathdee-type potential) does not yield a regular black hole e...
#
# Conversation 43:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 58/100)
# - The summary contains at least one significant factual error: it states that the mass-loss rate inferred from Hγ emission is overestimated by a factor of ~200, whereas th...
#
# Conversation 44:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 86/100):
# - The summary accurately captures the paper’s focus on using present-day kinematics and spatial distributions to constrain the formation of multiple populations in globul...
#
# Conversation 45:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately conveys the core ideas: singular Laplacian growth as “maximally nonunique,” the notion of “fragility” via singularity splitting, the role of ...
#
# Conversation 46:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45)
# - The summary introduces specific numerical values that are not present in the provided text and are likely incorrect or fabricated:
#   - Energy threshold is stated as > 10^18 ...
#
# Conversation 47:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - Major error: The summary repeatedly states the work is in “four-dimensional N=0 supersymmetry,” which is incorrect. The paper clearly concerns N=2 supersymmetry in four dimens...
#
# Conversation 48:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and contributions: initial focus on two-sample GOF tests, iterative development driven by experimental use cases (notably Gea...
#
# Conversation 49:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on coherent backscattering (CBS) from two harmonically trapped atoms and how atomic motion (recoil and Doppler effects) affec...
#
# Conversation 50:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and unsupported specifics:
#   - It states a 25 μm pixel size, which is not given in the paper; the paper references a specific hybrid ...
#
# Conversation 51:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains at least one incorrect claim: it states that the block entanglement entropy “diverges,” whereas the paper reports that it attains a maximum at the pseudo-...
#
# Conversation 52:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the three-part structure of the paper: low-energy two-nucleon EFT and its relation to realistic potentials, the chiral bag/Cheshire Cat perspec...
#
# Conversation 53:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly describes the topic (supra-arcade downflows as indirect evidence of magnetic reconnection), the instruments used (AIA/SDO and STEREO), the use...
#
# Conversation 54:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 60)
# - Strengths: Most statements align with the paper, including the emphasis on elliptic flow consistent with ideal hydrodynamics, constituent quark scaling, the observation of r...
#
# Conversation 55:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and introduces ratios not supported by the paper. The paper discusses p/π and K/π ratios (pT-dependent and integrated), but the summa...
#
# Conversation 56:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reports the key finding: two quiescent filament eruptions rotated counterclockwise despite right-handed post-eruption arcades. It correctly notes the si...
#
# Conversation 57:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly identifies the study’s scope (TPP on SWCNTs and graphene), methods (vdW-DF with SIESTA), number of CNT species (42), key qualitative findings ...
#
# Conversation 58:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope, methods, and findings: a 30-month global coronal simulation using a coupled flux-transport/magnetofrictional model; emergenc...
#
# Conversation 59:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on SMQC without nonlocal measurements, the reduction to secure two-party computation of nl-CNOT, and the reduction of secure ...
#
# Conversation 60:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# - The summary accurately reflects the paper’s focus on the single-site entanglement entropy at the Mott transition in the half-filled Hubbard model in infinite dimensions.
# - It ...
#
# Conversation 61:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary introduces specific galaxy names (NGC 5194 and NGC 5195) that are not given in the paper; the mention of M51 in the paper refers to prior work, not the targets in ...
#
# Conversation 62:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - Strengths: The summary accurately reflects the paper’s topic (non-ergodicity in Coulomb glass), methodology (three-stage construction of low-energy states using local search, ...
#
# Conversation 63:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core contributions: introducing an environmental payoff threshold to spatial PD with unconditional strategies, exploring two update...
#
# Conversation 64:
#   Judgment: Yes
#   Explanation preview: Faithfulness (87/100):
# - The summary accurately reflects the paper’s core ideas: deriving the Wilson-line geometry for integrated and TMD PDFs and the soft factor directly from QCD via gauge rotations...
#
# Conversation 65:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately captures the paper’s core: a simple electrostatic model for the voltage profile along molecular wires, modeled as a cylinder between planar electrodes, ...
#
# Conversation 66:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope: constructing new exact, spherically symmetric, static solutions to the Einstein–Maxwell equations in curvature coordinates b...
#
# Conversation 67:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary accurately captures many core elements: the study combines planet–planet and planetesimal scattering via N-body simulations, uses two ensembles (high- and low-mass...
#
# Conversation 68:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately captures the paper’s focus on determining form factors for a heavy-baryon semileptonic decay using LCSR, the use of two interpolating current...
#
# Conversation 69:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Strengths: The summary accurately reflects the paper’s focus on leveraging the SOHO/MDI–Debrecen Sunspot Data (SDD) to study sunspot group internals (polarity separation, lead...
#
# Conversation 70:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately reflects the paper’s objectives, data, and main findings: a two-epoch HST differential proper-motion analysis (7.25-year baseline), alignment...
#
# Conversation 71:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a notable inaccuracy about the phase relation of the stable continuous-wave (cw) background. The paper’s modulationally stable cw is the “pi-type,” where ...
#
# Conversation 72:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a key factual error about the Loschmidt echo. The paper states that in finite systems the nonzero bandwidth of the m-string leads to the long-time average...
#
# Conversation 73:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately reflects the core of the paper: nova decay phases governed by optically thick winds driven by an iron-line opacity peak; strong dependence of...
#
# Conversation 74:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on skyrmion motion in nanowires driven by longitudinal and transverse spin waves, the use of micromagnetic simulations, and t...
#
# Conversation 75:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported or incorrect specifics. It cites electron-photon scattering as part of the relaxation-time calculation, but the paper discusses electron-ele...
#
# Conversation 76:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core arguments: parallels between massive-star nebulae and PNe; limitations of interacting-winds and merger scenarios; the case for...
#
# Conversation 77:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly captures the use of Globus (GSI, GridFTP, job submission), the two-level file catalog with a central PHENIX catalog and local Magda at SUNYSB,...
#
# Conversation 78:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains notable inaccuracies:
#   - It repeatedly refers to SrRuO3, whereas the paper is about the bilayer ruthenate Sr3Ru2O7 (Sr-327). This is a substantive ...
#
# Conversation 79:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on multi-post re-entrant cavities, modeling posts as coupled harmonic oscillators with gaps as capacitors and posts as induct...
#
# Conversation 80:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies and unsupported claims. It introduces a specific critical interaction range “~0.4 nm,” which is not given in the paper; the paper ref...
#
# Conversation 81:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several unsupported or incorrect claims relative to the paper.
#   - It describes SDSS imaging as “deep,” whereas the paper explicitly emphasizes SDSS is sh...
#
# Conversation 82:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 90/100):
# - The summary accurately reflects the paper’s scope: comparing high-NA focused-beam illumination to plane-wave (PW) excitation for spherical metal nanoparticles using a m...
#
# Conversation 83:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately describes the paper’s core focus on delocalizing transitions in multidimensional BECs in optical lattices and the role of unstable gap-Townes solitons a...
#
# Conversation 84:
#   Judgment: No
#   Explanation preview: Faithfulness (62/100):
# - Strengths: The summary correctly identifies the paper’s focus (integrability of 1D Bose/Fermi gases with large effective range), the use of a two-channel Hamiltonian model (HT...
#
# Conversation 85:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains two notable inaccuracies. First, it describes the theory as N=1 supersymmetric, whereas the paper clearly focuses on the non-anticommutative N=1/2 supersy...
#
# Conversation 86:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s focus on replacing EpicFlow’s sparse-to-dense interpolation step with a fully convolutional network that uses edges, layer-wise sup...
#
# Conversation 87:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary incorrectly states the main quantitative result: it claims the minimal complexity for n columns is n−1. The paper’s argument (via doubling at each inductive step a...
#
# Conversation 88:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - Strengths: The summary correctly identifies the main problem (quadratic divergences/hierarchy problem), the core approach (imposing Ward–Takahashi identities and enforcing tad...
#
# Conversation 89:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies relative to the paper. It states that prior models “fail to reproduce observed velocity gradients and pillar morphologies,” but the p...
#
# Conversation 90:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s main claims: the use of time-integrated observables in closed quantum systems, the construction of a non-Hermitian deformed Hamilto...
#
# Conversation 91:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on high-frequency p-modes in neutron star envelopes, the use of a plane-parallel approximation with relativistic context, inc...
#
# Conversation 92:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains significant numerical inaccuracies not supported by the paper text. It reports an emergence rate of 2–4 × 10^-3 Mx/h, whereas the paper’s notation (“2–4@x...
#
# Conversation 93:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately captures the paper’s main contribution: a distinct, lensing-only shear–ellipticity anti-correlation arising from galaxy–galaxy lensing, even without tid...
#
# Conversation 94:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains a key inaccuracy: it describes STIRAP as a “resonance-free pathway,” whereas the paper explicitly states that adiabatic techniques require a resonance bet...
#
# Conversation 95:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a key inaccuracy: it states that “the EGT model predicts a light-speed anisotropy of amplitude twice that of the CMB dipole.” In the paper, EGT predicts t...
#
# Conversation 96:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary is largely aligned with the paper’s content (context of SNR–molecular cloud interactions, CTB 109’s thermal X-ray lobe, identification of three CO clouds, location...
#
# Conversation 97:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly states the problem (scattering properties of ground-state Mg), the use of four potentials (RKR, IPA, a prior theoretical potential, and a new ...
#
# Conversation 98:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s main points: gas inflow is driven by gravitational (bar) torques rather than viscous torques; CMC growth alone is insufficient to e...
#
# Conversation 99:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary captures most core claims accurately (two error sources; higher frame rates worsen position-uncertainty-induced velocity errors; acceleration errors shrink with hi...
#
# Conversation 100:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several unsupported or incorrect factual claims relative to the paper text.
#   - It places the dip in the tangential velocity distribution between −10 and ...
#
# Conversation 101:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains several factual inaccuracies relative to the paper:
#   - It repeatedly refers to Fe II, whereas the paper clearly focuses on the Fe VI/Fe VII ionizat...
#
# Conversation 102:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains significant inaccuracies. The paper states that models cannot reproduce the large radius of HD 209458b (the first transiting hot Jupiter), whereas the sum...
#
# ...
#
# Conversation 940:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states the problem (phase diagram of 4He on graphene), the method (large-scale QMC/worm algorithm in the gran...
#
# Conversation 941:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces incorrect or unsupported numerical claims. The paper’s best estimate for the lensing galaxy G1’s velocity dispersion is not stated explicitly in plain n...
#
# Conversation 942:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces specific FP slope values (“a ~ 1.35” and “b ~ 1.50”) that are not present in the provided text and are likely inconsistent with typical FP formulations ...
#
# Conversation 943:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary largely reflects the paper’s content but introduces a significant inaccuracy: it claims the authors “demonstrate the existence of closed timelike and null causal c...
#
# Conversation 944:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100): The summary contains several factual inaccuracies and misinterpretations. It incorrectly states the white dwarf contributes ~1.7% at 4500 Å and ~0.6% at 6500 Å; the paper report...
#
# Conversation 945:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains several inaccuracies:
#   - It states “for main-sequence stars, the 29.4-minute precision reaches below 30 ppm,” which contradicts the paper. At 29.4 ...
#
# Conversation 946:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies relative to the paper. It claims “we find a strong correlation between absorption equivalent width and disk inclination,” whereas the...
#
# Conversation 947:
#   Judgment: Yes
#   Explanation preview: Faithfulness (84/100):
# - Strengths: The summary accurately captures the paper’s central thesis (causal backreaction as an alternative to dark energy), the motivation (fine-tuning and coincidence probl...
#
# Conversation 948:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on the prevalent but ad hoc practice of combining systematic and random uncertainties in quadrature, especially the issues ar...
#
# Conversation 949:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - The summary accurately captures the paper’s focus on automated coronal loop detection using the 2D wavelet transform modulus maxima (WTMM) method, its multiscale and direction...
#
# Conversation 950:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately presents the paper’s goal (predicting the mass–Lyα forest flux correlation), the approach (HPM simulations calibrated against hydrodynamic ru...
#
# Conversation 951:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s goals, methods, and findings. It correctly critiques the simplistic incoherent sum of non-commuting error channels, introduces the ...
#
# Conversation 952:
#   Judgment: Yes
#   Explanation preview: Faithfulness (87/100):
# - The summary accurately captures the problem (electron-cloud effects in the LHC and their impacts), the lack of direct in-situ diagnostics, the proposed benchmarking approach (...
#
# Conversation 953:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains at least two factual inaccuracies. It states that interaction lists are generated at intervals of Δt = 3, misreading the paper’s symbolic interval (@xmath...
#
# Conversation 954:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately reflects the paper’s focus on inhomogeneous (striped) superconductivity in cuprates, the role of magnetic inhomogeneities that locally break ...
#
# Conversation 955:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on muon-induced spallation neutrons as a key background in underground experiments, the Aberdeen Tunnel setup (611 m.w.e.), t...
#
# Conversation 956:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and findings: Bragg spectroscopy of 1D interacting bosons, comparison with a finite-temperature Bethe-ansatz-based Lieb–Linig...
#
# Conversation 957:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a key factual error: it states that heavier nuclei like iron produce “deeper, more extended showers.” The paper explicitly shows that heavier primaries le...
#
# Conversation 958:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly identifies the problem (geometric distortion in HST/ACS), the observational approach (dithered star clusters 47 Tuc and NGC 6681), the iterati...
#
# Conversation 959:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly states the motivation (improving metallicity coverage of Padova94 SEMs for SFH studies), the core interpolation procedure (phase subdivision, ...
#
# Conversation 960:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the problem (2D viscous flow around a flapping foil, fixed vs free), method (LBM with immersed/moving boundaries), geometry (semicircle...
#
# Conversation 961:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains notable inaccuracies:
#   - It states the analysis uses MDI data “from solar cycle 21 to cycle 22,” whereas the paper uses 24 MDI data sets from May 1...
#
# Conversation 962:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 58)
# - Strengths: The summary correctly identifies the main goal (realizing a QSH state in graphene without magnetic fields), the approach (DFT with van der Waals corrections on gr...
#
# Conversation 963:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic, setup, and key findings: first-principles simulations of parahydrogen confined in spherical nanocavities; comparison of weak...
#
# Conversation 964:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains at least two factual inaccuracies:
#   - It groups “neutral species (e.g., Li, Be)” together. In the paper, Be is analyzed via Be II (ionized), and the repo...
#
# Conversation 965:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces unsupported specifics: “analysis of 19 days in March 2016 (from 06:00 to 18:00)” is not in the paper. The paper states it considers all days in March 20...
#
# Conversation 966:
#   Judgment: Yes
#   Explanation preview: Faithfulness (86/100):
# - The summary accurately reflects the paper’s scope and methods: thermalization in two-species ultracold gases in box and harmonic traps; use of coupled Boltzmann equations; inc...
#
# Conversation 967:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 30/100)
# - The summary introduces incorrect and unsupported facts. It labels the studied state as “f2s(1235),” which is not mentioned in the paper and is inconsistent with the cont...
#
# Conversation 968:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately captures the paper’s central themes: the debate between clustered versus hierarchical star formation; the emphasis on spatial/temporal correl...
#
# Conversation 969:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on the Einstein–Vlasov system with Bianchi I symmetry, the small-data assumptions (small anisotropy and bounded momenta), and...
#
# Conversation 970:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# - The summary accurately reflects the paper’s content: it describes a BEC in a high-finesse cavity with an intracavity optical lattice, the optomechanical coupling modifying the...
#
# Conversation 971:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on modeling the decay of article page views, its analogy to physical relaxation/aging, and the use of a modified stretched ex...
#
# Conversation 972:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on sound-mediated, long-range interactions between dark solitons in inhomogeneous Bose–Einstein condensates, caused by axial ...
#
# Conversation 973:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 82
# - Strengths: The summary accurately conveys the paper’s core problem (approximating slow/attracting invariant manifolds), the on-the-fly “steady AIM” approach using vanishing ...
#
# Conversation 974:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic, framework, and main findings: use of the Maxwell–Weyl covariant formalism; numerical integration of Friedmann and Klein–Gord...
#
# Conversation 975:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s scope: the tension between dark-matter-only predictions and observable galaxy properties, the central role of ISM physics and sub-g...
#
# Conversation 976:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary is largely faithful to the paper’s topic, methods, and qualitative conclusions, but it introduces incorrect numerical values by misreading placeholders. Specifical...
#
# Conversation 977:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s core ideas: a metric-independent definition of conformal invariance via measure line bundles and invariance under changes of the co...
#
# Conversation 978:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several factual inaccuracies. The paper studies the B_c meson (a bound state of b and c quarks), not the Xi_cb baryon/meson as stated.
# - It incorrectly cl...
#
# Conversation 979:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately captures the paper’s scope (2D Fermi superfluids across the BCS–BEC crossover), the use of beyond-mean-field Gaussian fluctuations with zero-...
#
# Conversation 980:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the paper’s goals and approach: expressing anomalous Hall conductivity in terms of local atomic-like orbitals, showing equivalence to B...
#
# Conversation 981:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary introduces unsupported and likely incorrect numerical claims:
#   - It states that observed GeV photons imply a minimal upstream magnetic field of ~100–200 G. ...
#
# Conversation 982:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary accurately states the study uses 21 cm HI absorption toward ~25 directions selected based on prior Ca II/Na I absorption, uses the VLA with 44″ and 4″ beams, targe...
#
# Conversation 983:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on attribute reduction via a dependence space induced by matroids and the use of closure operators to define a congruence rel...
#
# Conversation 984:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s focus: testing the Compton downscattering model for broad iron Kα lines against observational constraints in MCG–6-30-15 and NGC 35...
#
# Conversation 985:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that cat3d-wind combines a geometrically thin dusty disk with a hollow polar outflow launched near the...
#
# Conversation 986:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a key inversion of the paper’s stated causal relationship: the paper says that k_T-factorization for DIS emerges as a consequence of rapidity factorizatio...
#
# Conversation 987:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary correctly identifies the problem (measuring electron effective mass vs. QW width in CdTe/(Cd,Mn)Te), the method (ODCR/ODR), the sample structure (four wells of 30,...
#
# Conversation 988:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces inaccuracies by conflating different results. It states a predicted impact probability of 0.33% with the “highest Palermo Scale value,” which reflects e...
#
# Conversation 989:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: indirect study of ultra-high-energy cosmic rays via air showers, the dependence on hadronic interaction models, and the know...
#
# Conversation 990:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately captures the paper’s main contributions: extending spectrogram-based ship wake analysis to finite-depth channels, modeling a ship as a Gaussian pressure...
#
# Conversation 991:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately reflects the paper’s topic (predicting 2016 U.S. election outcomes from Twitter), data collection (371,264 tweets from Dec 16, 2015–Feb 29, 2...
#
# Conversation 992:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly identifies the problem (2D Turing patterns in a boundary-fed CDIMA system), the realistic LRE model, use of a pseudospectral method with paral...
#
# Conversation 993:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s scope and methods: a numerical study of hypothetical Uranus Trojans in the outer solar system, using Newtonian N-body integrations ...
#
# Conversation 994:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a significant inaccuracy: it claims agreement with experimental measurements of the χc1 and χc2 mesons, which are charmonium (heavy-heavy) states. The pap...
#
# Conversation 995:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately captures the paper’s core setting and contributions: modeling base stations with a PPP, analyzing worst-case users at Voronoi vertices under ...
#
# Conversation 996:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s goals, methods, and findings. It correctly states the debate (PMS vs. ZAMS), the use of Hipparcos parallaxes to derive distances an...
#
# Conversation 997:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - Accurate: The summary correctly identifies the object (XRF 030723), the suspected SN Ic association due to an optical bump, the modeling framework (LTE radiation hydrodynamics...
#
# Conversation 998:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s goal (testing adiabatic matter creation as a driver of cosmic acceleration), the datasets used (186 SNe Ia, H(z) from differential ...
#
# Conversation 999:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100): The summary closely reflects the paper’s content: it introduces the ISIPP scenario driven by the running coupling, explains the decreasing momentum transfer leading to stronger ...
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total evaluated: 1000
# Yes: 497 (49.7%)
# No: 503 (50.3%)
# Unknown: 0 (0.0%)

# %%
# Save results to JSONL file
import json

# Create filename with baseline_eval in it
output_filename = f"/Users/ryanarman/code/lab/arxiv_abstract/data/baseline_eval_qwen3_4b_test.jsonl"

# Write results to JSONL file
with open(output_filename, 'w', encoding='utf-8') as f:
    for idx, result, prompt in results:
        output_data = {
            'index': idx,
            'judgment': result['judgment'],
            'explanation': result['explanation'],
            'evaluation_prompt': prompt
        }
        f.write(json.dumps(output_data, ensure_ascii=False) + '\n')

print(f"Saved {len(results)} results to {output_filename}")
# Out:
# Saved 1000 results to /Users/ryanarman/code/lab/arxiv_abstract/data/baseline_eval_qwen3_4b_test.jsonl

# %% [markdown]
# score of basemodel: 49.7%

# %% [markdown]
# # Training

# %% [markdown]
# train_instruct_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_instruct.jsonl"
# val_instruct_path =   "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_val_instruct.jsonl"
#
# ./submit_training_rsync.sh \
#   data/arxiv_summarization_train_instruct.jsonl \
#   data/arxiv_summarization_val_instruct.jsonl \
#   configs/qwen4b_train_lora.yaml \
#   my_custom_output_name \
#   ryan@exun \
#   arxiv-abstract-qwen3-4b \
#   my-team
#
# # Trained on gpt-5 distilled on 1k train, 1k validation
#    /home/ryan/code/oumi/lab/arxiv_abstract/output/arxiv_abstract_qwen3_4b_gpt5_lora_2807

# %%
gen_train_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_instruct_article_gpt5.jsonl"


cd /Users/ryanarman/code/lab/arxiv_abstract/scripts
./submit_training_rsync.sh

# %% [markdown]
# #Eval trained model

# %%
cd /Users/ryanarman/code/lab/arxiv_abstract/scripts

./submit_inference_rsync.sh \
  data/arxiv_summarization_test_instruct.jsonl \
  configs/4b_instruct_vllm_infer_checkpoint.yaml \
  fine_tuned_results \
  output/arxiv_abstract_qwen3_4b_lora_2800


./submit_inference_rsync.sh \
  data/arxiv_summarization_test_instruct.jsonl \
  configs/4b_instruct_vllm_infer_checkpoint.yaml \
  fine_tuned_gpt5_distilled_results \
  output/arxiv_abstract_qwen3_4b_gpt5_lora_2808

  ./submit_inference_rsync.sh \
  data/arxiv_summarization_test_instruct.jsonl \
  configs/4b_instruct_vllm_infer_checkpoint.yaml \
  fine_tuned_gpt5_distilled_article_results \
  output/arxiv_abstract_qwen3_4b_gpt5_article_lora_fixed_2820

# %% [markdown]
# # Run judge

# %%
# tuned_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_results_2801.jsonl"
tuned_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_gpt5_distilled_results_2809.jsonl"
tuned_qwen3_4b_test_conversations = load_conversations(tuned_qwen3_4b_test_path)

# %%
display_message(tuned_qwen3_4b_test_conversations[10], role='assistant')
# Out:
# ================================================================================
# Role: ASSISTANT
# Characters: 1,285 | Words: 198 | Lines: 1
# ================================================================================
# <pre style="white-space: pre-wrap; word-wrap: break-word; font-family: monospace; background-color: #f5f5f5; color: #000000; padding: 10px; border-radius: 5px; line-height: 1.5;">We investigate cooperative effects arising from dipole–dipole interactions for
# two multi-level systems with macroscopic light and dark periods, motivated by
# experiments with Ba and Hg ions. We treat first two “d”-type systems (analogue
# of Hg), which model two active transitions driven by a strong laser and a slow
# decay to a metastable level, via coupled Bloch equations in a dicke basis; we
# then extend the approach to an effective model based on a single large-dipole
# transition from the ground state to a two-level intermediate system that decays
# incoherently to the metastable level. We expand the subleading terms of the
# reset map and derive transition rates and double jump probabilities as the
# leading order is the unperturbed result. We find that two “d” systems exhibit
# cooperative rate enhancement (up to ∼30%) at intermediate distances of one to
# two decay lengths and modest suppression at longer distances, similar to two “V”
# systems, in qualitative agreement with the measurements. For the effective model
# for Ba we find orders-of-magnitude smaller cooperative effects, consistent with
# the recent measurements in Ba and contrasting with the experiments with Ca
# atoms. The results emphasize how cooperative effects depend sensitively on the
# scheme for detrapping the ions.</pre>

# %%
fine_tuned_results, fine_tuned_errors = evaluate_summaries_batch(
    tuned_qwen3_4b_test_conversations,
    model="gpt-5",
    temperature=1.0,
    max_workers=1000,  # Adjust based on your API rate limits
    show_progress=True
)

# Display results
print("\n" + "="*80)
print("BATCH EVALUATION RESULTS")
print("="*80)

for idx, result, prompt in fine_tuned_results:
    print(f"\nConversation {idx}:")
    print(f"  Judgment: {result['judgment']}")
    # Optionally show a snippet of the explanation
    explanation_preview = result['explanation'][:200] + "..." if len(result['explanation']) > 200 else result['explanation']
    print(f"  Explanation preview: {explanation_preview}")

if fine_tuned_errors:
    print(f"\nErrors encountered: {len(fine_tuned_errors)}")
    for idx, error in fine_tuned_errors:
        print(f"  Conversation {idx}: {error}")

# Summary statistics
judgments = [result['judgment'] for _, result, _ in fine_tuned_results]
yes_count = judgments.count('Yes')
no_count = judgments.count('No')
unknown_count = judgments.count('Unknown')

print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Total evaluated: {len(fine_tuned_results)}")
print(f"Yes: {yes_count} ({yes_count/len(fine_tuned_results)*100:.1f}%)")
print(f"No: {no_count} ({no_count/len(fine_tuned_results)*100:.1f}%)")
print(f"Unknown: {unknown_count} ({unknown_count/len(fine_tuned_results)*100:.1f}%)")
# Out:
# Evaluating 1000 conversations with 1000 workers...
#   Completed 1/1000
#   Completed 2/1000
#   Completed 3/1000
#   Completed 4/1000
#   Completed 5/1000
#   Completed 6/1000
#   Completed 7/1000
#   Completed 8/1000
#   Completed 9/1000
#   Completed 10/1000
#   Completed 11/1000
#   Completed 12/1000
#   Completed 13/1000
#   Completed 14/1000
#   Completed 15/1000
#   Completed 16/1000
#   Completed 17/1000
#   Completed 18/1000
#   Completed 19/1000
#   Completed 20/1000
#   Completed 21/1000
#   Completed 22/1000
#   Completed 23/1000
#   Completed 24/1000
#   Completed 25/1000
#   Completed 26/1000
#   Completed 27/1000
#   Completed 28/1000
#   Completed 29/1000
#   Completed 584/1000
#   Completed 585/1000
#   Completed 586/1000
#   Completed 587/1000
#   Completed 588/1000
#   Completed 589/1000
#   Completed 590/1000
#   Completed 591/1000
#   Completed 592/1000
#   Completed 593/1000
#   Completed 594/1000
#   Completed 595/1000
#   Completed 596/1000
#   Completed 597/1000
#   Completed 598/1000
#   Completed 599/1000
#   Completed 600/1000
#   Completed 601/1000
#   Completed 602/1000
#   Completed 603/1000
#   Completed 604/1000
#   Completed 605/1000
#   Completed 606/1000
#   Completed 607/1000
#   Completed 608/1000
#   Completed 609/1000
#   Completed 610/1000
#   Completed 611/1000
#   Completed 612/1000
#   Completed 613/1000
#   Completed 614/1000
#   Completed 615/1000
#   Completed 616/1000
#   Completed 617/1000
#   Completed 618/1000
#   Completed 619/1000
#   Completed 620/1000
#   Completed 621/1000
#   Completed 622/1000
#   Completed 623/1000
#   Completed 624/1000
#   Completed 625/1000
#   Completed 626/1000
#   Completed 627/1000
#   Completed 628/1000
#   Completed 629/1000
#   Completed 630/1000
#   Completed 631/1000
#   Completed 632/1000
#   Completed 633/1000
#   Completed 634/1000
#   Completed 635/1000
#   Completed 636/1000
#   Completed 637/1000
#   Completed 638/1000
#   Completed 639/1000
#   Completed 640/1000
#   Completed 641/1000
#   Completed 642/1000
#   Completed 643/1000
#   Completed 644/1000
#   Completed 645/1000
#   Completed 646/1000
#   Completed 647/1000
#   Completed 648/1000
#   Completed 649/1000
#   Completed 650/1000
#   Completed 651/1000
#   Completed 652/1000
#   Completed 653/1000
#   Completed 654/1000
#   Completed 655/1000
#   Completed 656/1000
#   Completed 657/1000
#   Completed 658/1000
#   Completed 659/1000
#   Completed 660/1000
#   Completed 661/1000
#   Completed 662/1000
#   Completed 663/1000
#   Completed 664/1000
#   Completed 665/1000
#   Completed 666/1000
#   Completed 667/1000
#   Completed 668/1000
#   Completed 669/1000
#   Completed 670/1000
#   Completed 671/1000
#   Completed 672/1000
#   Completed 673/1000
#   Completed 674/1000
#   Completed 675/1000
#   Completed 676/1000
#   Completed 677/1000
#   Completed 678/1000
#   Completed 679/1000
#   Completed 680/1000
#   Completed 681/1000
#   Completed 682/1000
#   Completed 683/1000
#   Completed 684/1000
#   Completed 685/1000
#   Completed 686/1000
#   Completed 687/1000
#   Completed 688/1000
#   Completed 689/1000
#   Completed 690/1000
#   Completed 691/1000
#   Completed 692/1000
#   Completed 693/1000
#   Completed 694/1000
#   Completed 695/1000
#   Completed 696/1000
#   Completed 697/1000
#   Completed 698/1000
#   Completed 699/1000
#   Completed 700/1000
#   Completed 701/1000
#   Completed 702/1000
#   Completed 703/1000
#   Completed 704/1000
#   Completed 705/1000
#   Completed 706/1000
#   Completed 707/1000
#   Completed 708/1000
#   Completed 709/1000
#   Completed 710/1000
#   Completed 711/1000
#   Completed 712/1000
#   Completed 713/1000
#   Completed 714/1000
#   Completed 715/1000
#   Completed 716/1000
#   Completed 717/1000
#   Completed 718/1000
#   Completed 719/1000
#   Completed 720/1000
#   Completed 721/1000
#   Completed 722/1000
#   Completed 723/1000
#   Completed 724/1000
#   Completed 725/1000
#   Completed 726/1000
#   Completed 727/1000
#   Completed 728/1000
#   Completed 729/1000
#   Completed 730/1000
#   Completed 731/1000
#   Completed 732/1000
#   Completed 733/1000
#   Completed 734/1000
#   Completed 735/1000
#   Completed 736/1000
#   Completed 737/1000
#   Completed 738/1000
#   Completed 739/1000
#   Completed 740/1000
#   Completed 741/1000
#   Completed 742/1000
#   Completed 743/1000
#   Completed 744/1000
#   Completed 745/1000
#   Completed 746/1000
#   Completed 747/1000
#   Completed 748/1000
#   Completed 749/1000
#   Completed 750/1000
#   Completed 751/1000
#   Completed 752/1000
#   Completed 753/1000
#   Completed 754/1000
#   Completed 755/1000
#   Completed 756/1000
#   Completed 757/1000
#   Completed 758/1000
#   Completed 759/1000
#   Completed 760/1000
#   Completed 761/1000
#   Completed 762/1000
#   Completed 763/1000
#   Completed 764/1000
#   Completed 765/1000
#   Completed 766/1000
#   Completed 767/1000
#   Completed 768/1000
#   Completed 769/1000
#   Completed 770/1000
#   Completed 771/1000
#   Completed 772/1000
#   Completed 773/1000
#   Completed 774/1000
#   Completed 775/1000
#   Completed 776/1000
#   Completed 777/1000
#   Completed 778/1000
#   Completed 779/1000
#   Completed 780/1000
#   Completed 781/1000
#   Completed 782/1000
#   Completed 783/1000
#   Completed 784/1000
#   Completed 785/1000
#   Completed 786/1000
#   Completed 787/1000
#   Completed 788/1000
#   Completed 789/1000
#   Completed 790/1000
#   Completed 791/1000
#   Completed 792/1000
#   Completed 793/1000
#   Completed 794/1000
#   Completed 795/1000
#   Completed 796/1000
#   Completed 797/1000
#   Completed 798/1000
#   Completed 799/1000
#   Completed 800/1000
#   Completed 801/1000
#   Completed 802/1000
#   Completed 803/1000
#   Completed 804/1000
#   Completed 805/1000
#   Completed 806/1000
#   Completed 807/1000
#   Completed 808/1000
#   Completed 809/1000
#   Completed 810/1000
#   Completed 811/1000
#   Completed 812/1000
#   Completed 813/1000
#   Completed 814/1000
#   Completed 815/1000
#   Completed 816/1000
#   Completed 817/1000
#   Completed 818/1000
#   Completed 819/1000
#   Completed 820/1000
#   Completed 821/1000
#   Completed 822/1000
#   Completed 823/1000
#   Completed 824/1000
#   Completed 825/1000
#   Completed 826/1000
#   Completed 827/1000
#   Completed 828/1000
#   Completed 829/1000
#   Completed 830/1000
#   Completed 831/1000
#   Completed 832/1000
#   Completed 833/1000
#   Completed 834/1000
#   Completed 835/1000
#   Completed 836/1000
#   Completed 837/1000
#   Completed 838/1000
#   Completed 839/1000
#   Completed 840/1000
#   Completed 841/1000
#   Completed 842/1000
#   Completed 843/1000
#   Completed 844/1000
#   Completed 845/1000
#   Completed 846/1000
#   Completed 847/1000
#   Completed 848/1000
#   Completed 849/1000
#   Completed 850/1000
#   Completed 851/1000
#   Completed 852/1000
#   Completed 853/1000
#   Completed 854/1000
#   Completed 855/1000
#   Completed 856/1000
#   Completed 857/1000
#   Completed 858/1000
#   Completed 859/1000
#   Completed 860/1000
#   Completed 861/1000
#   Completed 862/1000
#   Completed 863/1000
#   Completed 864/1000
#   Completed 865/1000
#   Completed 866/1000
#   Completed 867/1000
#   Completed 868/1000
#   Completed 869/1000
#   Completed 870/1000
#   Completed 871/1000
#   Completed 872/1000
#   Completed 873/1000
#   Completed 874/1000
#   Completed 875/1000
#   Completed 876/1000
#   Completed 877/1000
#   Completed 878/1000
#   Completed 879/1000
#   Completed 880/1000
#   Completed 881/1000
#   Completed 882/1000
#   Completed 883/1000
#   Completed 884/1000
#   Completed 885/1000
#   Completed 886/1000
#   Completed 887/1000
#   Completed 888/1000
#   Completed 889/1000
#   Completed 890/1000
#   Completed 891/1000
#   Completed 892/1000
#   Completed 893/1000
#   Completed 894/1000
#   Completed 895/1000
#   Completed 896/1000
#   Completed 897/1000
#   Completed 898/1000
#   Completed 899/1000
#   Completed 900/1000
#   Completed 901/1000
#   Completed 902/1000
#   Completed 903/1000
#   Completed 904/1000
#   Completed 905/1000
#   Completed 906/1000
#   Completed 907/1000
#   Completed 908/1000
#   Completed 909/1000
#   Completed 910/1000
#   Completed 911/1000
#   Completed 912/1000
#   Completed 913/1000
#   Completed 914/1000
#   Completed 915/1000
#   Completed 916/1000
#   Completed 917/1000
#   Completed 918/1000
#   Completed 919/1000
#   Completed 920/1000
#   Completed 921/1000
#   Completed 922/1000
#   Completed 923/1000
#   Completed 924/1000
#   Completed 925/1000
#   Completed 926/1000
#   Completed 927/1000
#   Completed 928/1000
#   Completed 929/1000
#   Completed 930/1000
#   Completed 931/1000
#   Completed 932/1000
#   Completed 933/1000
#   Completed 934/1000
#   Completed 935/1000
#   Completed 936/1000
#   Completed 937/1000
#   Completed 938/1000
#   Completed 939/1000
#   Completed 940/1000
#   Completed 941/1000
#   Completed 942/1000
#   Completed 943/1000
#   Completed 944/1000
#   Completed 945/1000
#   Completed 946/1000
#   Completed 947/1000
#   Completed 948/1000
#   Completed 949/1000
#   Completed 950/1000
#   Completed 951/1000
#   Completed 952/1000
#   Completed 953/1000
#   Completed 954/1000
#   Completed 955/1000
#   Completed 956/1000
#   Completed 957/1000
#   Completed 958/1000
#   Completed 959/1000
#   Completed 960/1000
#   Completed 961/1000
#   Completed 962/1000
#   Completed 963/1000
#   Completed 964/1000
#   Completed 965/1000
#   Completed 966/1000
#   Completed 967/1000
#   Completed 968/1000
#   Completed 969/1000
#   Completed 970/1000
#   Completed 971/1000
#   Completed 972/1000
#   Completed 973/1000
#   Completed 974/1000
#   Completed 975/1000
#   Completed 976/1000
#   Completed 977/1000
#   Completed 978/1000
#   Completed 979/1000
#   Completed 980/1000
#   Completed 981/1000
#   Completed 982/1000
#   Completed 983/1000
#   Completed 984/1000
#   Completed 985/1000
#   Completed 986/1000
#   Completed 987/1000
#   Completed 988/1000
#   Completed 989/1000
#   Completed 990/1000
#   Completed 991/1000
#   Completed 992/1000
#   Completed 993/1000
#   Completed 994/1000
#   Completed 995/1000
#   Completed 996/1000
#   Completed 997/1000
#   Completed 998/1000
#   Completed 999/1000
#   Completed 1000/1000
#
# ✓ Completed: 1000 successful, 0 errors
#
# ================================================================================
# BATCH EVALUATION RESULTS
# ================================================================================
#
# Conversation 0:
#   Judgment: No
#   Explanation preview: Faithfulness (Accuracy to the paper): 45/100
# - The summary contains notable inaccuracies. It misrepresents the reported accuracy: the paper states that for (68) spherical nuclei, most differences betw...
#
# Conversation 1:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and hallucinations. It refers to a “gaugino action,” which is not part of the Schwinger model (the paper distinguishes gauge vs. ferm...
#
# Conversation 2:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains inaccuracies and hallucinations. It claims results for “crossed-box” integrals, which are not mentioned in the paper (the paper discusses box-type integra...
#
# Conversation 3:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccuracies and hallucinations. It cites unrelated or nonexistent references (“Hellings and van Bemmel 1978,” “Theia data”) and invents terms li...
#
# Conversation 4:
#   Judgment: No
#   Explanation preview: Faithfulness (25/100):
# - The summary contains multiple inaccuracies and hallucinations. It claims “catalog the progenitors of 12 CC-SN events: 8 type II–P and 19 others,” which contradicts the paper’s...
#
# Conversation 5:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple inaccuracies and hallucinations. It references “arXiv:nucl-ex/0701037,” which is not specified in the paper and appears unrelated. It claims a “@...
#
# Conversation 6:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several incorrect or hallucinated statements. It claims “time-to-uniqueness is roughly log n,” which contradicts the paper’s statements (e.g., number of l...
#
# Conversation 7:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary begins with accurate elements (two three-level atoms in a two-mode cavity, Raman pulses, adiabatic preparation of a dark/CPT state, using SSA and von Neumann entro...
#
# Conversation 8:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains numerous hallucinations and incorrect statements not supported by the paper, such as “horizon-crossing eigenspace-attractor effects,” “ΛCDM-corrected samp...
#
# Conversation 9:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - The summary introduces inaccuracies and speculative phrasing. It misstates the use of ECMWF reanalysis as being for “out-of-range targets,” whereas the paper clearly says it i...
#
# Conversation 10:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary contains a key factual error about the Ba system. The paper explicitly states that, for the effective four-level model of Ba, the predicted cooperative effects are...
#
# Conversation 11:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces inaccuracies and hallucinations not supported by the paper. It claims the model lacks “scalar quartic couplings,” which is incorrect (the paper emphasiz...
#
# Conversation 12:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains an incorrect claim about the Nikhilam method: it says the method uses “only 3 @xmath4-digit multiplications,” whereas the paper explicitly highlights a ca...
#
# Conversation 13:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous hallucinations and incorrect statements not supported by the paper. Examples include “Flashtime ViewPlus,” “atmospheric sound absorption,” “evele...
#
# Conversation 14:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous hallucinations and incorrect claims not supported by the paper. Examples include mentions of a “new ground-based network of 4-meter telescopes,” ...
#
# Conversation 15:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary includes several inaccuracies and hallucinations. It describes the sample as “seven-year” and “H2O megamasers,” whereas the paper analyzes 18 Galactic masers (from...
#
# Conversation 16:
#   Judgment: No
#   Explanation preview: Faithfulness (25/100):
# - The summary contains multiple inaccuracies and hallucinations. It misidentifies the reaction as “2H(d, d+2π0)2H” and calls it inclusive, whereas the paper studies the exclusiv...
#
# Conversation 17:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains numerous inaccuracies and hallucinations. It introduces terms and concepts not in the paper (e.g., “artificial cliques,” “HSGF,” “bose-stabilized,” “GOAs,...
#
# Conversation 18:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple unsupported or incorrect claims relative to the paper. It introduces “radiation-modulated” star formation, “delayed direct solar abundance compar...
#
# Conversation 19:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary includes several claims and terms that are not supported by the paper. Examples of hallucinations/misrepresentations:
#   - “complex spectra require time-independent...
#
# Conversation 20:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary introduces multiple concepts not present in the paper, such as a “bulk exciton gas,” “Imamiya approximations,” “VFT Richardson levels,” “topo–graphically–classical...
#
# Conversation 21:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several unsupported or incorrect statements and hallucinated terms. Examples include “infinitesimal inconsistency with the algebra of functions is require...
#
# Conversation 22:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces multiple unsupported or incorrect claims not present in the paper: “primordial Dirac-type dark matter,” “dying lump process,” “local O(1) density,” “tem...
#
# Conversation 23:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple hallucinations and incorrect claims not supported by the paper. Examples include references to “quartic coupling of the single heavy-quark loop,”...
#
# Conversation 24:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary introduces multiple unsupported and incorrect elements, such as references to “von Neumann–Bernays–Gödel,” “Schur-type sums,” “Fibonacci sequence,” and “Gödel syst...
#
# Conversation 25:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains several inaccuracies and hallucinations. It states “target distributions are over all partial and total recursive functions,” which is incorrect—the paper...
#
# Conversation 26:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous hallucinations and inaccuracies not supported by the paper, such as “Sy 341,” “H3CN,” “H2PH2,” “CO10(wing) ScF,” “two sense-line scans,” “Jansky”...
#
# Conversation 27:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100): The summary contains several inaccuracies and hallucinations. It invents details about the KIS filters (claims V, V–I, V–V′ instead of the actual ugri + Hα), calls KIS “multi-ep...
#
# Conversation 28:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains notable inaccuracies. It states that the study “rules out dynamical mass segregation, multiplicity confusion, or unresolved hierarchical orbits,” whereas ...
#
# Conversation 29:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces inaccuracies and hallucinates specifics not in the paper. It claims a “two-site chain–ring geometry,” which is incorrect; the paper studies a finite cha...
#
# Conversation 30:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains several inaccuracies and hallucinations. It claims the total evolution is “numerically unraveled,” while the paper’s core contribution is an exact analyti...
#
# Conversation 31:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: Accurately mentions the MCAO/MOAO testbed, use of three optically addressed SLMs, introduction of a high-stroke “woofer” mirror, open-loop control with the Alpao DM...
#
# Conversation 32:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary includes several incorrect or fabricated claims. It states “∼400 pulses from 19 redshifted bursts,” while the paper reports 19 GRBs with 43 pulses. It introduces a...
#
# Conversation 33:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces several claims not supported by the paper. Examples:
#   - “time-integral of transverse currents relative to a spatial-mean velocity” is not in the paper;...
#
# Conversation 34:
#   Judgment: No
#   Explanation preview: Faithfulness (0-100): 15
# - The summary contains numerous hallucinations and incorrect claims not supported by the paper. Examples include: introduction of a “Polyakov loop gauge link” in the method (n...
#
# Conversation 35:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces numerous unsupported and incorrect elements, such as “UPD-protected” states, “PYRMP noise,” “BIJ-Naslow series symmetry,” “spinon mean-field fully-popul...
#
# Conversation 36:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains several incorrect or invented details. Examples:
#   - States a velocity resolution of 1.4 km/s; the paper reports 0.11 km/s channel spacing.
#   - Claims map...
#
# Conversation 37:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous unsupported or incorrect claims and hallucinated terminology. Examples include “IQHE at half filling,” “Fock-cycling descent techniques,” “{vorte...
#
# Conversation 38:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces several claims and terms not supported by the paper: “hydrodynamic neutral drifting,” “Langevin-type master equations,” “mean-field approximation,” “mea...
#
# Conversation 39:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary includes multiple hallucinations and incorrect statements. It mentions a “Singh–Peebles singularity,” “XLCDM,” “baryon-containing halo profiles,” and nonsensical p...
#
# Conversation 40:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary introduces numerous hallucinations and incorrect claims. It references Gödel-type models, “Schnigl–Lemaitre–Sandage+Buchdahl Feynman string–flares,” “QFT–then–rede...
#
# Conversation 41:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary introduces numerous false or unsupported claims not present in the paper, such as a “reverse Goscinny effect,” “variant codification involved with tissue segments,...
#
# Conversation 42:
#   Judgment: No
#   Explanation preview: Faithfulness (25/100):
# - The summary contains multiple unsupported or nonsensical claims (e.g., “kruskal=two ISofvaluations,” “metric tangent to its crunner,” “CPphs,” “Goddard generalisation,” “trans...
#
# Conversation 43:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces multiple unsupported or incorrect claims. It states the use of a “time-dependent” clumpy wind model, whereas the paper explicitly notes the dynamical pr...
#
# Conversation 44:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and hallucinations. It misuses placeholders (e.g., “@xmath0 mass is expected to have been lost”), incorrectly states “colour–magnitud...
#
# Conversation 45:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple unsupported and incorrect claims. The paper argues that a “fragile” (maximally nonunique) limit for turbulence is suggested by considering Burger...
#
# Conversation 46:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains numerous hallucinations and incorrect statements not supported by the paper. Examples include references to “best-maximum-likelihood energy spectral-fit,”...
#
# Conversation 47:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several factual inaccuracies. It repeatedly refers to “N=0 supersymmetry” and “N=0 superspace,” whereas the paper is clearly about N=2 supersymmetry (with...
#
# Conversation 48:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - Strengths: Accurately notes the iterative development process, modernization of the build and configuration (Subversion, CMake, minimal GSL dependency), the CSV user layer and...
#
# Conversation 49:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several unsupported or incorrect claims. It introduces “average medium”–induced dissipation as a mechanism for loss of which-way information, which is not...
#
# Conversation 50:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple inaccuracies and hallucinations. It claims a “0.25 mm pixel size,” but 0.25 mm refers to ladder thickness in the paper; the pixel size is not spe...
#
# Conversation 51:
#   Judgment: No
#   Explanation preview: Faithfulness (5/100):
# - The summary contains numerous hallucinations and incorrect claims not supported by the paper, such as “replica-breaking vacua,” “circuit-effective delocalization,” “evaluationo...
#
# Conversation 52:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 15/100)
# - The summary contains numerous hallucinations and incorrect claims not supported by the paper, such as references to pomeron graphs, Einstein–Vlasov Lagrangian, wormholes...
#
# Conversation 53:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple incorrect and unsupported claims. It calls the downflows “relativistic,” which is false; observed speeds are hundreds of km/s, not relativistic. ...
#
# Conversation 54:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccuracies and hallucinations not supported by the paper. It mentions p–Pb collisions (not part of the STAR/RHIC results described here), “iden...
#
# Conversation 55:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100): The summary contains multiple inaccuracies and hallucinations. It incorrectly states the analysis is at forward rapidity, while the paper is explicitly at central rapidity (|y| ...
#
# Conversation 56:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces unsupported or incorrect details, such as “three-decade EIT rings,” “IMF observations,” and “Hinode Hα data,” none of which appear in the paper. The pap...
#
# Conversation 57:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary includes several inaccuracies and unsupported claims. The paper computes optical absorption via first-order time-dependent perturbation theory using Kohn–Sham orbi...
#
# Conversation 58:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains multiple inaccurate or hallucinated elements. It claims a “pronounced hemispheric sign reversal after only a few days,” whereas the paper reports that a c...
#
# Conversation 59:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately states the paper’s scope (SMQC without nonlocal measurements), the core reduction to secure two-party computation of nl-CNOT, the use of bit commitment ...
#
# Conversation 60:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains several inaccuracies and hallucinations. It refers to “non‑local dimensions” and “spatially identical Green’s function,” which are not in the paper; the p...
#
# Conversation 61:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple hallucinations and incorrect facts not supported by the paper. It invents specific galaxy names (M31 and M101), whereas the paper discusses two s...
#
# Conversation 62:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies and hallucinations. It refers to “localized low-energy eigenstates,” whereas the paper treats classical many-particle configurations/...
#
# Conversation 63:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary introduces numerous claims and terminology not present in the paper, e.g., “partition function,” “Moreau’s diffusive Elo–Fisher–Harris game,” “qubit interpretation...
#
# Conversation 64:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccurate and hallucinated statements. It mentions “second-order effects,” “an effective counter-term,” “fundamental gauge,” “five-dimensional k...
#
# Conversation 65:
#   Judgment: No
#   Explanation preview: Faithfulness (15/100):
# - The summary introduces multiple inaccuracies and hallucinations. It claims a “generic 1D Poisson model,” whereas the paper explicitly solves a 3D Poisson equation with cylindr...
#
# Conversation 66:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary introduces several unsupported and incorrect claims. It invents specific functional forms such as ρ(r) ∝ [1 − (r/a)^τ]/r (singular at the origin), which contradict...
#
# Conversation 67:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary includes numerous inaccuracies and hallucinations not supported by the paper. Examples: references to a “keplr package,” “planetesimal-disk voltage,” “Radford/Jovi...
#
# Conversation 68:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains numerous inaccuracies and hallucinations. It misidentifies the process as B⋆ → Bℓν (the paper studies a heavy-baryon semileptonic decay using LCSR, not a ...
#
# Conversation 69:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains inaccuracies and likely hallucinations. It introduces an unexplained and unsupported numeric range “436–482 measured tilts,” which does not appear in the ...
#
# Conversation 70:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccuracies and hallucinations. It claims “three epochs” of data, whereas the paper uses two epochs (WFPC2 in 1995 and ACS/WFC in 2002; 7.25-yea...
#
# Conversation 71:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary includes multiple inaccurate and invented claims. It states the stable cw has a “phase-shifted by √2” relation, while the paper clearly specifies a π/2 phase shift...
#
# Conversation 72:
#   Judgment: No
#   Explanation preview: Faithfulness (0/100):
# - The response bears no relation to the paper’s content. The paper studies nonequilibrium dynamics of the gapped XXZ spin chain after a domain-wall quench using the algebraic Bet...
#
# Conversation 73:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous hallucinations and incorrect statements not supported by the paper. Examples include: “six phases,” “impenetrable disks,” “Gaussian early decay,”...
#
# Conversation 74:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains inaccuracies and hallucinations. It claims “the saturated velocity scales with the driving amplitude as the square root of all relevant parameters,” which...
#
# Conversation 75:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple inaccuracies and hallucinations. It invents terms and concepts not in the paper (e.g., “quantum black” fields, “thermal radiation” as a process i...
#
# Conversation 76:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The response contains extensive hallucinated content (random technical-sounding jargon, code-like snippets, URLs, and unrelated system logs) not present in the paper.
# - It mis...
#
# Conversation 77:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous inaccuracies and hallucinations not supported by the paper. Terms like “eGrid,” “Lumina (interconnecting cats),” “Gigasub,” and “audio recovery” ...
#
# Conversation 78:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100): The response contains numerous hallucinations, unrelated references, and nonsensical text. It does not accurately reflect the paper’s content. While it briefly mentions “electro...
#
# Conversation 79:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple hallucinations and incorrect claims not supported by the paper. Examples include “topological mode splitting,” a “barbell-shaped curve,” a “Jones...
#
# Conversation 80:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary introduces numerous methods and concepts not present in the paper, such as density-functional theory, a “Haswell-Buerger-type tensor,” “self-consistent chain of fu...
#
# Conversation 81:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces several unsupported or incorrect details. Examples include: “well-constrained critical surface mass density calibration,” “10 logarithmically spaced ann...
#
# Conversation 82:
#   Judgment: No
#   Explanation preview: Faithfulness (15/100):
# - The summary contains multiple inaccuracies and hallucinations not supported by the paper. It mentions an “incident pulse,” an “annular lens,” and “approximating diffraction ef...
#
# Conversation 83:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly identifies the focus on gap–Townes solitons as unstable separatrices marking the delocalizing transition in 2D/3D GPEs with separable optical ...
#
# Conversation 84:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces several inaccurate or unsupported claims. It says “the two-body contact model is exactly solvable by the Bethe ansatz and integrable,” conflating two-bo...
#
# Conversation 85:
#   Judgment: No
#   Explanation preview: Faithfulness (15/100):
# - The summary introduces numerous concepts absent from the paper, such as superconformal theories, BRST cohomology, hypermultiplets, “KL-deformations,” “Mashke factor,” “SL(2)-g...
#
# Conversation 86:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies and hallucinations. It repeatedly refers to “episodic flow” instead of EPICFlow, which is the actual method discussed. It claims the ...
#
# Conversation 87:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100): The summary contains multiple inaccuracies and hallucinations. The paper’s main quantitative result is that the minimal complexity (number of passes through a fixed arc) for the...
#
# Conversation 88:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces several inaccurate or hallucinated claims. It states that top-quark loops produce a “massive Goldstone-boson self-energy” violating current conservation...
#
# Conversation 89:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies and unsupported claims. It describes the main setup as a “periodic, initially semi-infinite molecular cloud,” whereas the primary sim...
#
# Conversation 90:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccuracies and hallucinations. It incorrectly suggests that in the PT-broken regime the cumulants scale sublinearly, whereas the paper states t...
#
# Conversation 91:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains many unsupported and incorrect statements, such as references to “torsion,” “magnetosphere,” and “cosmology,” which are not in the paper. It invents terms...
#
# Conversation 92:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccuracies and invented details not supported by the paper. Examples:
#   - Boundary conditions: The paper uses periodic horizontal and open vert...
#
# Conversation 93:
#   Judgment: No
#   Explanation preview: Faithfulness (0-100): 38
# - The summary includes several unsupported or incorrect statements. Examples:
#   - “Averaging over wavelengths” is irrelevant; the paper averages over lens mass and ellipticity...
#
# Conversation 94:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100): The summary contains multiple inaccuracies and hallucinations not supported by the paper. It incorrectly states that the goal is to transfer atoms to the central channel, wherea...
#
# Conversation 95:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple unsupported and incorrect claims. Examples:
#   - “Slowing a laser arm” is not described in the paper; the experiment uses a fixed laser and diffra...
#
# Conversation 96:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains numerous inaccuracies and hallucinations not supported by the paper. Examples include:
#   - Incorrect object name (“CRTC-107” instead of CTB 109).
#   - Nons...
#
# Conversation 97:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The response contains many hallucinations and incorrect statements not supported by the paper, such as references to “88Mg,” “¹⁶⁸Mg,” “Bardeen transformer,” “Holstein dimer co...
#
# Conversation 98:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 30/100)
# - The summary introduces multiple concepts and methods not present in the paper, including “octupole-mode” torques, “Eulerian Cartesian coordinates” as a key element, a “V...
#
# Conversation 99:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces unsupported or incorrect elements (e.g., “Ivea’s common assumption,” “mikroplasma,” “final velocities … spanning the entire measured velocity window,” “...
#
# Conversation 100:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100): The summary contains numerous inaccuracies and hallucinations. It invents methods and terms not present in the paper (e.g., “King-designed exponential star density prescription,...
#
# Conversation 101:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple factual errors and hallucinations. It incorrectly focuses on Fe I/Fe II/Fe III “coronal” lines, whereas the paper clearly studies Fe VI and Fe VI...
#
# Conversation 102:
#   Judgment: No
#   Explanation preview: Faithfulness (0/100):
# - The response does not accurately reflect the paper’s content. It contains extensive unrelated and nonsensical text (e.g., code-like fragments, random references, multilingual p...
#
# Conversation 103:
#   Judgment: No
# ...
#
# Conversation 940:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported or incorrect details. It claims densities “up to 0.150 atom per square micron,” whereas the paper uses areal densities in Å⁻² (e.g., 0.150 Å...
#
# Conversation 941:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains numerous hallucinations and inaccuracies not supported by the paper. Examples include mentioning OSIRIS (the paper uses Keck LRIS only), “VLT-XPERSI,” “Fo...
#
# Conversation 942:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary includes multiple hallucinations and incorrect attributions. It repeatedly references “FK96” and invented terms like “GRANDFIT,” “ZwPicker–Zwilling bands,” “GPK va...
#
# Conversation 943:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple unsupported or incorrect statements. The paper presents a specific cylindrically symmetric vacuum plane-wave metric that is Ricci-flat, Petrov ty...
#
# Conversation 944:
#   Judgment: No
#   Explanation preview: Faithfulness (5/100): The response contains extensive hallucinations and incorrect statements. It invents acronyms and author lists for BeppoSAX/ROSAT, mentions a “Fourier-transformed spectrograph,” m...
#
# Conversation 945:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100): The summary contains multiple inaccuracies and hallucinations. It incorrectly claims that “90% of nearby main-sequence stars saturate the 6–hour precision requirement”; the pape...
#
# Conversation 946:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary introduces many concepts and claims not present in the paper (e.g., “quadruple-emission sites,” “RSGB sample,” “meta–halo mountains,” “OH–molecular perpendicularit...
#
# Conversation 947:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary introduces multiple concepts not present in the paper, such as “half-point perturbation formulation,” “de Sitter-consistent manner,” “comoving de Broglie velocity ...
#
# Conversation 948:
#   Judgment: No
#   Explanation preview: Faithfulness (0-100): 15
# - The summary contains multiple inaccuracies and hallucinations not supported by the paper:
#   - Claims a “most general result (Poissonian)” and an “initial Poisson nature of r...
#
# Conversation 949:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous hallucinations and inaccurate statements not supported by the paper. Examples include: “sparse-dynamic CH scale,” “CF-type and F-island structure...
#
# Conversation 950:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple hallucinations and inaccuracies. It introduces irrelevant and incorrect elements such as “digital survey data on tng,” “3–6 kpc region,” “semicon...
#
# Conversation 951:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary introduces multiple inaccuracies and hallucinations. The paper’s core model is zero-bandwidth (time-independent) stochastic Hamiltonian noise with exact averaging;...
#
# Conversation 952:
#   Judgment: No
#   Explanation preview: Faithfulness (5/100):
# - The summary contains numerous hallucinated and incorrect statements that are not supported by the paper, such as “Peterson - lhc orbital power-to-pressure maps,” “hodoscope cav...
#
# Conversation 953:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains multiple hallucinations and incorrect facts. It invents “GaRAPE (Grape for a factorizable Averaged Potential integrator)” and cites nonexistent works and ...
#
# Conversation 954:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary includes several hallucinations and incorrect attributions not supported by the paper: “de Hartog hamiltonian,” “Rice and Matveev (1993),” “neutron–spectroscopy–co...
#
# Conversation 955:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and unsupported claims. It introduces the acronym “ATMN,” which is not present in the paper. It misstates the neutron detector energy...
#
# Conversation 956:
#   Judgment: No
#   Explanation preview: Faithfulness (15/100):
# - The summary contains multiple hallucinations and incorrect specifics not supported by the paper. Examples:
#   - “Ω = 2π × 150 GHz” is wrong; the paper mentions a Bragg pulse fr...
#
# Conversation 957:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Strengths: The summary accurately identifies the topic (extensive air showers from high-energy cosmic rays), the use of CORSIKA simulations, the decomposition into hadronic, e...
#
# Conversation 958:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies and hallucinations. It misnames the HST Optical Telescope Assembly (OTA) as “OPACT,” refers to “two-decade CCDs” and a “chip-chirp of...
#
# Conversation 959:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces several inaccuracies. It incorrectly labels the metallicity range (Z = 0.0004–0.004) with units of M⊙, which is wrong.
# - It claims results “relative to...
#
# Conversation 960:
#   Judgment: No
#   Explanation preview: Faithfulness (15/100):
# - The summary contains numerous hallucinations and incorrect claims. It introduces nonexistent terms and references (e.g., “Ostsotski type ‘stream interactions’,” “Carbuncular d...
#
# Conversation 961:
#   Judgment: No
#   Explanation preview: Faithfulness (5/100):
# - The response contains extensive hallucinations and incorrect statements not supported by the paper, including references to “Legendre–Legendre distortion,” “MIDI mode parameter...
#
# Conversation 962:
#   Judgment: No
#   Explanation preview: Faithfulness (0-100): 15
# - The summary contains multiple incorrect and hallucinated claims. It mentions “two-fermion” systems (not in the paper), “stacking-barrier–free” configurations (not stated), a...
#
# Conversation 963:
#   Judgment: No
#   Explanation preview: Faithfulness (0/100):
# - The summary is entirely unrelated to the paper. It mentions “proton,” “magnetohydrodynamic simulation,” “xylan solution,” and “transition coupling,” none of which appear in the...
#
# Conversation 964:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple inaccuracies and hallucinations. It claims the use of “full superposition Monte-Carlo radiative transfer,” which is not in the paper (the paper u...
#
# Conversation 965:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: Accurately states the problem (impact of cloud coverage on solar irradiance), the use of ground-based sky cameras, undistortion, blue/red ratio for cloud detection,...
#
# Conversation 966:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous hallucinations and incorrect statements not supported by the paper. Examples include “partial-wave interferometry,” “space–velocity gauge,” “exac...
#
# Conversation 967:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary begins with accurate statements about using QCD sum rules, a phenomenological vs. OPE treatment, and a Borel transform, which are in the paper.
# - However, it quick...
#
# Conversation 968:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccuracies and hallucinations not supported by the paper. Examples:
#   - Claims “we develop a unified picture” and states that “star formation i...
#
# Conversation 969:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces claims not supported by the paper. It states that the “shear part of the Weyl tensor tends exponentially to zero,” but the paper gives algebraic decay e...
#
# Conversation 970:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple inaccuracies and hallucinations not supported by the paper. Examples include specifying “metastable 87Rb atoms” (the paper does not name a specif...
#
# Conversation 971:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains several inaccuracies:
#   - It claims the authors analyzed page-view statistics from six journals. The paper’s own analysis uses two datasets from Sci...
#
# Conversation 972:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary introduces incorrect or unsupported claims. The paper states that identical solitons symmetrically displaced in a single harmonic trap show at most minor effects f...
#
# Conversation 973:
#   Judgment: No
#   Explanation preview: Faithfulness (25/100):
# - The summary contains several hallucinations and incorrect claims not supported by the paper. Examples include references to “Maxwell’s projection space,” “binary nonlinear spa...
#
# Conversation 974:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains numerous hallucinations and incorrect statements not supported by the paper, such as “Maassen Weyl spinorial approach,” “kernel shell screens,” “helpkap-l...
#
# Conversation 975:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces multiple hallucinated concepts and references not present in the paper, such as “multicycle radiation capture à la Zhou & Huang,” “radiflux,” “ξ˜νPV,” “...
#
# Conversation 976:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains many fabricated and incorrect details (e.g., specific RA/Dec coordinates, “˜3-pixel region,” “90% uncertainty: ˜1.8 arcsec,” bizarre spectral parameters l...
#
# Conversation 977:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The first paragraph accurately captures the paper’s core idea: a metric-independent definition of conformal invariance via measure line bundles and invariance under changes of...
#
# Conversation 978:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several inaccuracies not supported by the paper. It claims branching ratios “around the percent level,” whereas the paper reports orders of magnitude cons...
#
# Conversation 979:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary introduces unsupported and incorrect claims. Examples:
#   - “Feshbach-tuned Atomic Interferometry” is not mentioned in the paper; the paper discusses Fano–Feshbach ...
#
# Conversation 980:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several factual inaccuracies and hallucinations. It states that the extraordinary/anomalous Hall effect “vanishes at zero magnetic field,” whereas the pap...
#
# Conversation 981:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains numerous hallucinations and unsupported terms (e.g., “ERGO/BAN competition,” “Viola light curves,” “quasi-Boyer,” “Ricci-Liepin models,” “Galapagos views,...
#
# Conversation 982:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple unsupported or incorrect claims. The paper reports 24 fields (two stars in the same field) but does not provide counts like “≳35 absorption syste...
#
# Conversation 983:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100): The summary introduces a clear hallucination: “for any prime p,” which is not mentioned anywhere in the paper. It also says “examining matrixs,” which conflates matrices with ma...
#
# Conversation 984:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple inaccuracies and hallucinations. It claims a “single generic source exterior to a surrounding cloud,” whereas the paper models the continuum sour...
#
# Conversation 985:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100): The summary contains several inaccuracies and hallucinations. It claims the model is “trained with 132,300 empirical morphologies,” whereas the paper reports simulating 132,300 ...
#
# Conversation 986:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary includes several inaccuracies and hallucinations not supported by the paper. It claims “logistic behaviour of the geometric scaling corrections is verified in log-...
#
# Conversation 987:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 15/100)
# - The summary contains multiple hallucinations and factual errors not supported by the paper. Examples include references to “tunable” ODCR, comparisons to doped GaAs/AlGa...
#
# Conversation 988:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple inaccuracies and hallucinations. It introduces nonexistent elements such as a “closed-form N-body propagation framework,” “non-gravitational powe...
#
# Conversation 989:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains numerous unsupported or incorrect claims. It invents specific energy ranges (e.g., “10–13 TeV,” “20–30 TeV and/or 40–50 TeV”) and thresholds (“n > 10,000”...
#
# Conversation 990:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies and hallucinations. It describes the applied pressure as “sharply truncated (Gaussian),” whereas the paper uses a Gaussian pressure d...
#
# Conversation 991:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: Correctly states the dataset source and period (Twitter Streaming API, Dec 16, 2015–Feb 29, 2016), use of #election2016, simple preprocessing (remove URLs/pictures;...
#
# Conversation 992:
#   Judgment: No
#   Explanation preview: Faithfulness (15/100):
# - The summary includes multiple incorrect and hallucinated claims. It states the problem as a “three-dimensional boundary-value problem,” whereas the paper performs two-dimensio...
#
# Conversation 993:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple unsupported and incorrect claims. It states analysis to a “10^5-year theoretical limit,” whereas the paper integrates over 10^6, 10^7–10^8, and u...
#
# Conversation 994:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains multiple hallucinations and incorrect statements not supported by the paper. It mentions an MSSM framework, “quengan4s,” “two-bodies lattice strings,” “Mo...
#
# Conversation 995:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary includes inaccurate or invented methodological phrases not supported by the paper, such as “expulsive interference statistics” and “convolution inverses with verte...
#
# Conversation 996:
#   Judgment: No
#   Explanation preview: Faithfulness (10/100):
# - The summary contains numerous hallucinations and incorrect claims. It invents specific statistics (e.g., “average ϖ = 3.7–3.8 mas,” “mean μ = 115 mas/yr”) not supported by the...
#
# Conversation 997:
#   Judgment: No
#   Explanation preview: Faithfulness (score: 5/100):
# - The summary contains numerous hallucinations and incorrect statements (e.g., references to Seyfert galaxies, Type Ia SNe, “BIR detectors,” software/code snippets, and un...
#
# Conversation 998:
#   Judgment: No
#   Explanation preview: Faithfulness (25/100):
# - The summary introduces numerous unsupported or incorrect claims. Examples include nonsensical parameter notations like “1−17∼6.9×10−2” and “1−63,” invented concepts such as “o...
#
# Conversation 999:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains notable inaccuracies. It states there is a “new type of nonmonotonic behavior” in the collision time, whereas the paper explicitly reports that for ISIPP ...
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total evaluated: 1000
# Yes: 26 (2.6%)
# No: 974 (97.4%)
# Unknown: 0 (0.0%)

# %%
# Save results to JSONL file
import json

# Create filename with baseline_eval in it
output_filename = f"/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_eval_qwen3_4b_test_gpt5_instruct_lora_fixed.jsonl"

# Write results to JSONL file
with open(output_filename, 'w', encoding='utf-8') as f:
    for idx, result, prompt in fine_tuned_results:
        output_data = {
            'index': idx,
            'judgment': result['judgment'],
            'explanation': result['explanation'],
            'evaluation_prompt': prompt
        }
        f.write(json.dumps(output_data, ensure_ascii=False) + '\n')

print(f"Saved {len(fine_tuned_results)} results to {output_filename}")
# Out:
# Saved 1000 results to /Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_eval_qwen3_4b_test_gpt5_instruct_lora_fixed.jsonl

# %% [markdown]
# ## score finetuned: 7%
