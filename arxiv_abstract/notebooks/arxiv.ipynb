# %%
# Import utility functions
from utils import (
    evaluate_summary,
    evaluate_summaries_batch,
    display_text,
    display_message,
    load_conversations,
    client,
    JUDGE_SYSTEM_INSTRUCTION,
    JUDGE_PROMPT_TEMPLATE_WITH_REQUEST_AND_RESPONSE
)

# %% [markdown]
# # Examine data

# %%
# train_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train.jsonl"
train_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_filtered_10k.jsonl"
val_path =   "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_val_filtered_10k.jsonl"
test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_test_filtered_10k.jsonl"
# train_distilled_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_abstract_train_gpt5mini_think2.jsonl"
train_conversations = load_conversations(train_path)
val_conversations = load_conversations(val_path)
test_conversations = load_conversations(test_path)
# train_distilled_conversations = load_conversations(train_distilled_path)

# %%
test_conversations[0]
# Out:
# [{'role': 'user',
#   'content': 'as a common quantum phenomenon , the tunneling through a potential barrier plays a very important role in the microscopic world and has been studied extensively since the birth of quantum mechanics . \n one of the earliest applications of quantum tunneling is the explanation of @xmath0 decays in atomic nuclei . \n the quantum tunneling effect governs also many other nuclear processes such as fission and fusion . \n in particular , a lot of new features are revealed in sub - barrier fusion reactions which are closely connected with the tunneling phenomena  @xcite .    for most of the potential barriers , the penetrability can not be calculated analytically  @xcite . among those potentials for which analytical solutions can be obtained , \n the parabolic potential  @xcite is the mostly used in the study of nuclear fusion . by approximating the coulomb barrier to a parabola \n , wong derived an analytic expression for the fusion cross section  @xcite which is widely adopted today in the study of heavy ion reactions ( see , e.g. , recent refs . \n the parabolic approximation works remarkably well both for the penetrability and for the fusion cross section at energies around or above the coulomb barrier  @xcite . \n apparently the parabolic approximation breaks down at energies much smaller than the barrier height due to the long - range coulomb interaction . \n one may calculate the penetration probability numerically by using the path integral method or the wkb approximation . \n however , it is highly desirable to have an analytical expression for the barrier penetrability when one introduces an energy - dependent one - dimensional potential barrier  @xcite or barrier distribution functions  @xcite .    in the present work \n , we derived a new barrier penetration formula based on the wkb approximation . \n the influence of the long coulomb tail in the barrier potential is taken into accout properly . \n therefore this formula is especially applicable to the barrier penetration with penetration energy much lower than the coulomb barrier .    as a first attempt and a test study \n , we apply this new formula to evaluate @xmath0 decay half - lives of atomic nuclei . for the @xmath0 decay , \n the penetrability is usually calculated with the wkb approach  @xcite , in other words , integrating numerically the wave number within two turning points at which the interaction potential is equal to the @xmath1-value of the @xmath0 decay . \n we will show that the present analytical formula reproduces the experimental results very well , especially for spherical nuclei . \n the paper is organized as follows . in sec . \n [ sec : formalism ] we present the new barrier penetration formula . \n the validity of the new formula is investigated and its application to @xmath0 decays are given in sec . \n [ sec : results ] . finally in sec . \n [ sec : summary ] we summarize our work . in the appendix , \n the detailed derivation of the new penetration formula is given . \n when the penetration energy is well below the coulomb barrier , the barrier penetrability formula derived from the wkb approximation reads , @xmath2 ,   \\label{eq : wkb}\\ ] ] where the potential usually consists of three parts , the nuclear , the coulomb , and the centrifugal potentials , @xmath3 @xmath4 and @xmath5 are the inner and outer turning points determined by the relation @xmath6 .    by approximating @xmath7 to a parabola with the height @xmath8 and the width @xmath9 , eq . \n ( [ eq : wkb ] ) is reduced as @xmath10 ,   \\label{eq : hw}\\ ] ] which has been widely used in the study of heavy ion reactions .    because of the long - range coulomb interaction , the coulomb barrier given in eq . \n ( [ eq : potential ] ) has a long tail and is asymmetric . \n thus for the penetration well below the barrier , the parabolic approximation is not valid . \n we may divide the potential barrier into two parts at the barrier position @xmath11 . \n the first part  ...
#  {'role': 'assistant',
#   'content': 'starting from the wkb approximation , a new barrier penetration formula is proposed for potential barriers containing a long - range coulomb interaction . \n this formula is especially proper for the barrier penetration with penetration energy much lower than the coulomb barrier . \n the penetrabilities calculated from the new formula agree well with the results from the wkb method . as a first attempt , \n this new formula is used to evaluate @xmath0 decay half - lives of atomic nuclei and a good agreement with the experiment is obtained .'}]

# %% [markdown]
# # Judge

# %%
# Test the helper function on the first message
# First, let's examine train_conversations[0]

conv = train_conversations[6]
print("="*80)
print(f"Number of messages: {len(conv)}")
print(f"Message roles: {[msg['role'] for msg in conv]}")
print("\n" + "="*80)
print("USER MESSAGE (the paper content):")
print("="*80)
# display_message(train_conversations[0], role='user')
# print("\n" + "="*80)
print("ASSISTANT MESSAGE (the summary being evaluated):")
print("="*80)
display_message(conv, role='assistant')

print("\n" + "="*80)
print("JUDGE EVALUATION:")
print("="*80)
result, evaluation_prompt = evaluate_summary(conv, model="gpt-5")

print(f"Judgment: {result['judgment']}")
print(f"\nExplanation:\n{result['explanation']}")
# Out:
# ================================================================================
# Number of messages: 2
# Message roles: ['user', 'assistant']
#
# ================================================================================
# USER MESSAGE (the paper content):
# ================================================================================
# ASSISTANT MESSAGE (the summary being evaluated):
# ================================================================================
# ================================================================================
# Role: ASSISTANT
# Characters: 1,721 | Words: 315 | Lines: 8
# ================================================================================
# <pre style="white-space: pre-wrap; word-wrap: break-word; font-family: monospace; background-color: #f5f5f5; color: #000000; padding: 10px; border-radius: 5px; line-height: 1.5;">this paper investigates , using prior shape models and the concept of ball scale
# ( b - scale ) , ways of automatically recognizing objects in 3d images without
# performing elaborate searches or optimization .
#  that is , the goal is to place the model in a single shot close to the right
# pose ( position , orientation , and scale ) in a given image so that the model
# boundaries fall in the close vicinity of object boundaries in the image .
#  this is achieved via the following set of key ideas : ( a ) a semi - automatic
# way of constructing a multi - object shape model assembly .
#  ( b ) a novel strategy of encoding , via b - scale , the pose relationship
# between objects in the training images and their intensity patterns captured in
# b - scale images . ( c )
#  a hierarchical mechanism of positioning the model , in a one - shot way , in a
# given image from a knowledge of the learnt pose relationship and the b - scale
# image of the given image to be segmented .
#  the evaluation results on a set of 20 routine clinical abdominal female and
# male ct data sets indicate the following : ( 1 ) incorporating a large number of
# objects improves the recognition accuracy dramatically .
#  ( 2 ) the recognition algorithm can be thought as a hierarchical framework such
# that quick replacement of the model assembly is defined as coarse recognition
# and delineation itself is known as finest recognition .
#  ( 3 ) scale yields useful information about the relationship between the model
# assembly and any given image such that the recognition results in a placement of
# the model close to the actual pose without doing any elaborate searches or
# optimization . ( 4 ) effective object recognition can make delineation most
# accurate .</pre>
# ================================================================================
# JUDGE EVALUATION:
# ================================================================================
# Judgment: No
#
# Explanation:
# Faithfulness (60/100):
# - The summary largely reflects the paper’s topic (object recognition to aid segmentation via b-scale and shape models) and the hierarchical recognition idea. However, it introduces a specific evaluation detail not present in the provided text: “a set of 20 routine clinical abdominal female and male CT data sets.” The number 20 is not supported by the text (which uses variables for the number of subjects and mentions only that data are routine PET/CT-derived CT scans).
# - It also paraphrases a reported finding as “recognition accuracy” improving with more objects, whereas the paper explicitly states “specificity” increases; this is a subtle but meaningful shift in the reported metric.
# - It slightly overstates the conclusion with “make delineation most accurate,” which is stronger than the paper’s framing that efficient recognition enables successful delineation.
#
# Coverage (85/100):
# - The summary states the main problem (automatic object recognition to assist segmentation), the core method (model assembly, b-scale encoding of pose relationships, hierarchical/one-shot placement), and at least one main finding (more objects improve recognition; b-scale captures useful information).
# - It omits some specific components described in the paper, such as the intensity-weighted b-scale variant, the PCA-based pose system and transformation, and the optional refinement using the skin boundary, but overall covers the essential aspects adequately for a brief summary.
#
# Clarity (90/100):
# - Sentences are grammatical and understandable. Technical terms (b-scale, model assembly, hierarchical recognition) are used appropriately and in context. The meaning is clear to a technically literate reader.
#
# Conciseness (90/100):
# - The summary is focused, avoids filler, and includes only relevant information. Length is appropriate for an abstract-style summary.
#
# Coherence (90/100):
# - The summary follows a logical structure (goal → method → key ideas → findings) and flows smoothly without contradictions.
#
# Overall (77/100)

# %% [markdown]
# ## Eval original abstracts

# %%
# Batch evaluation for the first 10 conversations

original_results, original_errors = evaluate_summaries_batch(
    test_conversations,
    model="gpt-5",
    temperature=1.0,
    max_workers=1000,  # Adjust based on your API rate limits
    show_progress=True
)

# Display results
print("\n" + "="*80)
print("BATCH EVALUATION RESULTS")
print("="*80)

for idx, result, prompt in original_results:
    print(f"\nConversation {idx}:")
    print(f"  Judgment: {result['judgment']}")
    # Optionally show a snippet of the explanation
    explanation_preview = result['explanation'][:200] + "..." if len(result['explanation']) > 200 else result['explanation']
    print(f"  Explanation preview: {explanation_preview}")

if original_errors:
    print(f"\nErrors encountered: {len(original_errors)}")
    for idx, error in original_errors:
        print(f"  Conversation {idx}: {error}")

# Summary statistics
judgments = [result['judgment'] for _, result, _ in original_results]
yes_count = judgments.count('Yes')
no_count = judgments.count('No')
unknown_count = judgments.count('Unknown')

print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Total evaluated: {len(original_results)}")
print(f"Yes: {yes_count} ({yes_count/len(original_results)*100:.1f}%)")
print(f"No: {no_count} ({no_count/len(original_results)*100:.1f}%)")
print(f"Unknown: {unknown_count} ({unknown_count/len(original_results)*100:.1f}%)")
# Out:
# Evaluating 1000 conversations with 1000 workers...
#   Completed 1/1000
#   Completed 2/1000
#   Completed 3/1000
#   Completed 4/1000
#   Completed 5/1000
#   Completed 6/1000
#   Completed 7/1000
#   Completed 8/1000
#   Completed 9/1000
#   Completed 10/1000
#   Completed 11/1000
#   Completed 12/1000
#   Completed 13/1000
#   Completed 14/1000
#   Completed 15/1000
#   Completed 16/1000
#   Completed 17/1000
#   Completed 18/1000
#   Completed 19/1000
#   Completed 20/1000
#   Completed 21/1000
#   Completed 22/1000
#   Completed 23/1000
#   Completed 24/1000
#   Completed 25/1000
#   Completed 26/1000
#   Completed 27/1000
#   Completed 28/1000
#   Completed 29/1000
#   Completed 30/1000
#   Completed 31/1000
#   Completed 32/1000
#   Completed 594/1000
#   Completed 595/1000
#   Completed 596/1000
#   Completed 597/1000
#   Completed 598/1000
#   Completed 599/1000
#   Completed 600/1000
#   Completed 601/1000
#   Completed 602/1000
#   Completed 603/1000
#   Completed 604/1000
#   Completed 605/1000
#   Completed 606/1000
#   Completed 607/1000
#   Completed 608/1000
#   Completed 609/1000
#   Completed 610/1000
#   Completed 611/1000
#   Completed 612/1000
#   Completed 613/1000
#   Completed 614/1000
#   Completed 615/1000
#   Completed 616/1000
#   Completed 617/1000
#   Completed 618/1000
#   Completed 619/1000
#   Completed 620/1000
#   Completed 621/1000
#   Completed 622/1000
#   Completed 623/1000
#   Completed 624/1000
#   Completed 625/1000
#   Completed 626/1000
#   Completed 627/1000
#   Completed 628/1000
#   Completed 629/1000
#   Completed 630/1000
#   Completed 631/1000
#   Completed 632/1000
#   Completed 633/1000
#   Completed 634/1000
#   Completed 635/1000
#   Completed 636/1000
#   Completed 637/1000
#   Completed 638/1000
#   Completed 639/1000
#   Completed 640/1000
#   Completed 641/1000
#   Completed 642/1000
#   Completed 643/1000
#   Completed 644/1000
#   Completed 645/1000
#   Completed 646/1000
#   Completed 647/1000
#   Completed 648/1000
#   Completed 649/1000
#   Completed 650/1000
#   Completed 651/1000
#   Completed 652/1000
#   Completed 653/1000
#   Completed 654/1000
#   Completed 655/1000
#   Completed 656/1000
#   Completed 657/1000
#   Completed 658/1000
#   Completed 659/1000
#   Completed 660/1000
#   Completed 661/1000
#   Completed 662/1000
#   Completed 663/1000
#   Completed 664/1000
#   Completed 665/1000
#   Completed 666/1000
#   Completed 667/1000
#   Completed 668/1000
#   Completed 669/1000
#   Completed 670/1000
#   Completed 671/1000
#   Completed 672/1000
#   Completed 673/1000
#   Completed 674/1000
#   Completed 675/1000
#   Completed 676/1000
#   Completed 677/1000
#   Completed 678/1000
#   Completed 679/1000
#   Completed 680/1000
#   Completed 681/1000
#   Completed 682/1000
#   Completed 683/1000
#   Completed 684/1000
#   Completed 685/1000
#   Completed 686/1000
#   Completed 687/1000
#   Completed 688/1000
#   Completed 689/1000
#   Completed 690/1000
#   Completed 691/1000
#   Completed 692/1000
#   Completed 693/1000
#   Completed 694/1000
#   Completed 695/1000
#   Completed 696/1000
#   Completed 697/1000
#   Completed 698/1000
#   Completed 699/1000
#   Completed 700/1000
#   Completed 701/1000
#   Completed 702/1000
#   Completed 703/1000
#   Completed 704/1000
#   Completed 705/1000
#   Completed 706/1000
#   Completed 707/1000
#   Completed 708/1000
#   Completed 709/1000
#   Completed 710/1000
#   Completed 711/1000
#   Completed 712/1000
#   Completed 713/1000
#   Completed 714/1000
#   Completed 715/1000
#   Completed 716/1000
#   Completed 717/1000
#   Completed 718/1000
#   Completed 719/1000
#   Completed 720/1000
#   Completed 721/1000
#   Completed 722/1000
#   Completed 723/1000
#   Completed 724/1000
#   Completed 725/1000
#   Completed 726/1000
#   Completed 727/1000
#   Completed 728/1000
#   Completed 729/1000
#   Completed 730/1000
#   Completed 731/1000
#   Completed 732/1000
#   Completed 733/1000
#   Completed 874/1000
#   Completed 875/1000
#   Completed 876/1000
#   Completed 877/1000
#   Completed 878/1000
#   Completed 879/1000
#   Completed 880/1000
#   Completed 881/1000
#   Completed 882/1000
#   Completed 883/1000
#   Completed 884/1000
#   Completed 885/1000
#   Completed 886/1000
#   Completed 887/1000
#   Completed 888/1000
#   Completed 889/1000
#   Completed 890/1000
#   Completed 891/1000
#   Completed 892/1000
#   Completed 893/1000
#   Completed 894/1000
#   Completed 895/1000
#   Completed 896/1000
#   Completed 897/1000
#   Completed 898/1000
#   Completed 899/1000
#   Completed 900/1000
#   Completed 901/1000
#   Completed 902/1000
#   Completed 903/1000
#   Completed 904/1000
#   Completed 905/1000
#   Completed 906/1000
#   Completed 907/1000
#   Completed 908/1000
#   Completed 909/1000
#   Completed 910/1000
#   Completed 911/1000
#   Completed 912/1000
#   Completed 913/1000
#   Completed 914/1000
#   Completed 915/1000
#   Completed 916/1000
#   Completed 917/1000
#   Completed 918/1000
#   Completed 919/1000
#   Completed 920/1000
#   Completed 921/1000
#   Completed 922/1000
#   Completed 923/1000
#   Completed 924/1000
#   Completed 925/1000
#   Completed 926/1000
#   Completed 927/1000
#   Completed 928/1000
#   Completed 929/1000
#   Completed 930/1000
#   Completed 931/1000
#   Completed 932/1000
#   Completed 933/1000
#   Completed 934/1000
#   Completed 935/1000
#   Completed 936/1000
#   Completed 937/1000
#   Completed 938/1000
#   Completed 939/1000
#   Completed 940/1000
#   Completed 941/1000
#   Completed 942/1000
#   Completed 943/1000
#   Completed 944/1000
#   Completed 945/1000
#   Completed 946/1000
#   Completed 947/1000
#   Completed 948/1000
#   Completed 949/1000
#   Completed 950/1000
#   Completed 951/1000
#   Completed 952/1000
#   Completed 953/1000
#   Completed 954/1000
#   Completed 955/1000
#   Completed 956/1000
#   Completed 957/1000
#   Completed 958/1000
#   Completed 959/1000
#   Completed 960/1000
#   Completed 961/1000
#   Completed 962/1000
#   Completed 963/1000
#   Completed 964/1000
#   Completed 965/1000
#   Completed 966/1000
#   Completed 967/1000
#   Completed 968/1000
#   Completed 969/1000
#   Completed 970/1000
#   Completed 971/1000
#   Completed 972/1000
#   Completed 973/1000
#   Completed 974/1000
#   Completed 975/1000
#   Completed 976/1000
#   Completed 977/1000
#   Completed 978/1000
#   Completed 979/1000
#   Completed 980/1000
#   Completed 981/1000
#   Completed 982/1000
#   Completed 983/1000
#   Completed 984/1000
#   Completed 985/1000
#   Completed 986/1000
#   Completed 987/1000
#   Completed 988/1000
#   Completed 989/1000
#   Completed 990/1000
#   Completed 991/1000
#   Completed 992/1000
#   Completed 993/1000
#   Completed 994/1000
#   Completed 995/1000
#   Completed 996/1000
#   Completed 997/1000
#   Completed 998/1000
#   Completed 999/1000
#   Completed 1000/1000
#
# ✓ Completed: 1000 successful, 0 errors
#
# ================================================================================
# BATCH EVALUATION RESULTS
# ================================================================================
#
# Conversation 0:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core content: a new WKB-based barrier penetration formula that properly accounts for the long-range Coulomb tail, its applicability...
#
# Conversation 1:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it focuses on adapted nested force-gradient integrators within HMC, the Schwinger model as the testbed, derivation of the ...
#
# Conversation 2:
#   Judgment: No
#   Explanation preview: Faithfulness (88/100):
# - The core claims match the paper: it presents new methods for deriving functional equations for Feynman integrals, applies them to one- and two-loop cases, and uses these equat...
#
# Conversation 3:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 92
# - The summary accurately reflects the paper’s focus on hierarchical Hough-transform-based searches for continuous gravitational waves, the comparison between the “sky Hough” a...
#
# Conversation 4:
#   Judgment: Yes
#   Explanation preview: Faithfulness (accuracy to the paper): 95/100
# - The summary accurately reflects the paper’s focus: using pre-explosion imaging (space-based optical and ground-based IR with LGS-AO) to identify or const...
#
# Conversation 5:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and scope: SSAs in back-to-back dijet azimuthal correlations in pp collisions at RHIC.
# - It correctly notes the role of initi...
#
# Conversation 6:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and main contributions: large deviations for quantities in Kingman’s coalescent tied to two well-known laws of large numbers ...
#
# Conversation 7:
#   Judgment: No
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately states that the paper studies the strong subadditivity inequality (SSI) for a tripartite system using a four-particle entangled state, and that the setu...
#
# Conversation 8:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that PBH abundance limits constrain the small-scale primordial power spectrum, that standard Stewart–L...
#
# Conversation 9:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces several factual details not supported by the provided paper text: that SOFIA is a 2.5-meter airborne infrared telescope, mounted on a Boeing 747SP, and ...
#
# Conversation 10:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 97
# - The summary accurately reflects the paper’s content: it identifies the problem (cooperative dipole-dipole effects on fluorescence/quantum jumps), the systems studied (3-leve...
#
# Conversation 11:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on one-loop vertex corrections in an R-symmetric (MR) extension of the MSSM and their impact on the observable denoted @xmath...
#
# Conversation 12:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary includes claims not supported by the provided paper text, such as statements about the time complexity relationships of squaring, division, reciprocal, GCD, and re...
#
# Conversation 13:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly notes that HiRes reported preliminary monocular spectra from both sites, that the results are consistent with...
#
# Conversation 14:
#   Judgment: No
#   Explanation preview: Faithfulness (75/100):
# - Mostly accurate: it correctly states that microlensing is sensitive to planets around common (M-dwarf) stars, is well-suited to detect Jovian-mass planets at several AU, probe...
#
# Conversation 15:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic and findings. It correctly states that the authors re-analyze 18 masers with a probabilistic model allowing a nonzero mean of...
#
# Conversation 16:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it reports a polarized-beam measurement of the isoscalar double-pionic fusion reaction (@xmath0), performed with WASA at C...
#
# Conversation 17:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core claims: introducing 4-body real-space Jastrow factors designed for wave function stenciling; removing ionic configurations to ...
#
# Conversation 18:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately states the observational finding: a scarcity of very metal-poor stars in Milky Way dSphs despite low average metallicities.
# - It correctly describes the...
#
# Conversation 19:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s key content. It correctly states that semi-infinite non-Hermitian systems made of a finite non-Hermitian cluster attached to a semi...
#
# Conversation 20:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it states that the work derives the Vogel–Fulcher–Tammann (VFT) law for bulk polymer glasses, bases the derivation on the ...
#
# Conversation 21:
#   Judgment: Yes
#   Explanation preview: - Faithfulness (90/100): The summary accurately reflects the paper’s content. It correctly states that the paper summarizes results on the emergence of general relativity (GR) from tensor models with ...
#
# Conversation 22:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45)
# - The summary introduces claims not supported by the provided text, notably: “two types of models have this property: scalar fields with unconventional kinetic term and models...
#
# Conversation 23:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Mostly accurate: The summary correctly states that the paper uses an EFT based on HQSS, HFS, and HADS; fits counter-terms (LECs) using the heavy meson–antimeson sector; interp...
#
# Conversation 24:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it states that truncated Fourier, Gauss, Kummer, and exponential sums can be used for factorization, that factors yield un...
#
# Conversation 25:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on universal PAC learning over all computable classifiers, the infinite VC dimension implication, the use of adaptive sample ...
#
# Conversation 26:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it describes the targets (DM Tau, LkCa 15, TW Hya; L1551 IRS 5 and HL Tau), the instrumentation (ALMA Band 8 qualification...
#
# Conversation 27:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Strengths: The summary correctly states the main quantitative results (discovery of 42 white dwarfs; nine confirmed ZZ Ceti pulsators), the use of KIS color selection, spectro...
#
# Conversation 28:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Largely accurate: the summary correctly states that the paper combines measurements from seven clusters, finds little evidence for IMF variation across regions, and concludes ...
#
# Conversation 29:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the core content of the paper: it studies spin polarization in a three-terminal system with Rashba spin-orbit interaction, compares ring-like v...
#
# Conversation 30:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on a phase-damping (pure decoherence) qubit coupled to a bosonic environment and the study of system–environment correlations...
#
# Conversation 31:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic (woofer–tweeter AO architecture), the open-loop control focus, the tested device (ALPAO DM52), and the key quantitative resul...
#
# Conversation 32:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately reflects key themes of the paper: pulse-wise GRB correlations, the empirical nature of such correlations, interest in their cosmological use ...
#
# Conversation 33:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core content: a unified derivation of MFDRs around NESS using Agarwal’s formalism, equivalence of velocity-form MFDRs for Langevin ...
#
# Conversation 34:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: applying the composite operator formalism to QCD at finite temperature to compute scalar (sigma) and pseudoscalar (pion) mas...
#
# Conversation 35:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on current noise in double quantum dots, the role of Coulomb correlations, entanglement in two-electron states (singlet/tripl...
#
# Conversation 36:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it identifies Nessie as a filamentary IRDC with an extreme aspect ratio, reports uniform radial velocity indicating a sing...
#
# Conversation 37:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on FQHE in graphene under SU(4) symmetry (spin + valley), the prediction of new states without GaAs analogs, and their emerge...
#
# Conversation 38:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: molecular motors perform biased walks on filaments with small-probability unbinding, unbound motion is symmetric Brow...
#
# Conversation 39:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s main contributions: deriving the pairwise peculiar velocity distribution function (PVDF) within the dark halo framework; avoiding a...
#
# Conversation 40:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states: (1) a time-dependent Maxwell solution in the Einstein universe with fields aligned along Clifford par...
#
# Conversation 41:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic and approach: a Ginzburg–Landau phase-field model for SMAs with thermo-mechanical coupling, thermodynamic consistency, FE imp...
#
# Conversation 42:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 92)
# - The summary accurately reflects the paper’s central claims: (i) the Isham–Storey solution with the Isham–Salam–Strathdee potential is not a regular black hole because of hor...
#
# Conversation 43:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly captures the paper’s main aim (modeling accretion from clumpy OB supergiant winds in HMXBs/SFXTs), core modeling assumptions (ram-pressure-con...
#
# Conversation 44:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on using present-day kinematics and spatial distributions to constrain the formation of multiple populations in globular clus...
#
# Conversation 45:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core claims: that turbulence may have a maximally nonunique (“fragile”) limiting case, and that the Burgers equation—interpreted in...
#
# Conversation 46:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic (small-scale anisotropy/clustering in UHECRs), the contrasting AGASA and HiRes contexts, the asymmetric angular resolution in...
#
# Conversation 47:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects key aspects of the paper: it states the use of four-dimensional N=2 central charge superspace, focuses on the abelian vector–tensor multiplet, ...
#
# Conversation 48:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces several claims not supported by the provided text. It calls the Statistical Toolkit “open source,” which is not stated. It adds “detector performance mo...
#
# Conversation 49:
#   Judgment: No
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and scope: coherent backscattering (CBS) from two harmonically trapped atoms, the roles of recoil and Doppler effects near re...
#
# Conversation 50:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces information not supported by the provided text, notably the statement that the detector is “built from two independent sub devices, the pixel barrel and...
#
# Conversation 51:
#   Judgment: Yes
#   Explanation preview: Faithfulness (Score: 92)
# - The summary accurately reflects the paper’s content. It correctly states that the authors extend DMRG to random graphs of fixed connectivity, apply it to the random Ising mo...
#
# Conversation 52:
#   Judgment: No
#   Explanation preview: Faithfulness: 90/100
# - The summary correctly identifies the three main topics of the paper: (1) EFT for two-nucleon systems, (2) the flavor-singlet axial charge (proton spin problem) via the Cheshire ...
#
# Conversation 53:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly states that supra-arcade downflows are key indirect evidence for magnetic reconnection, that the authors pres...
#
# Conversation 54:
#   Judgment: No
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it notes STAR’s uniform azimuthal acceptance and extended pseudorapidity coverage, strong particle identification capabili...
#
# Conversation 55:
#   Judgment: No
#   Explanation preview: Faithfulness: 80/100
# - Mostly accurate and aligned with the paper: it correctly mentions ALICE’s PID using ITS, TPC, TOF, HMPID; reconstruction via weak decay topologies; coverage of long-lived hadron...
#
# Conversation 56:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and findings: it describes filament-axis rotation during eruptions, the usual twist-to-writhe interpretation, the typical cor...
#
# Conversation 57:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic (DFT/vdW-DF study of TPP physisorption on CNTs and graphene) and the main findings: strong π–π binding, binding strength incr...
#
# Conversation 58:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it describes simulating the solar coronal magnetic field evolution driven by flux emergence and photospheric shearing, the...
#
# Conversation 59:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: SMQC without nonlocal measurements is reduced to secure two-party computation of NL-CNOT, which in the passive adversary m...
#
# Conversation 60:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic (single-site entanglement entropy at the Mott metal–insulator transition in the infinite-dimensional Hubbard model) and metho...
#
# Conversation 61:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a key inaccuracy: it states that the three-armed spiral structure is seen on the Q0 map, whereas the paper explicitly attributes this structure to the Q1 ...
#
# Conversation 62:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and methods: a numerical approach to study non-ergodicity in the Coulomb glass, construction of an (almost) complete set of l...
#
# Conversation 63:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core contribution: extending the Nowak–May spatial Prisoner’s Dilemma by introducing an environmental threshold (xmath0) that agent...
#
# Conversation 64:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s key claims: that the geometry (paths) of Wilson lines in TMD PDFs and the soft factor can be derived from process kinematics togeth...
#
# Conversation 65:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content. The paper develops a simple electrostatic model with Thomas-Fermi–type screening (Poisson equation with a screening length...
#
# Conversation 66:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary includes incorrect and unsupported claims. The paper explicitly demonstrates at least one charged solution (the trigonometric case) that satisfies all physical acc...
#
# Conversation 67:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope and findings: N-body simulations of marginally unstable multi-planet systems with and without external planetesimal disks; is...
#
# Conversation 68:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on using light-cone sum rules (LCSR) with renewed distribution amplitudes and two interpolating currents (CZ-type and Ioffe-t...
#
# Conversation 69:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary introduces “the speed of removal,” which is not discussed in the provided text. The paper analyzes separation (distance) between leading and following polarities b...
#
# Conversation 70:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic and key findings: HST two-epoch differential proper-motion analysis of the Egg Nebula’s lobes and concentric arcs; two-step i...
#
# Conversation 71:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic and main findings: a three-wave (two FF + one SH) quadratic medium with a Bragg grating; existence and broad modulational sta...
#
# Conversation 72:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary broadly matches the topic (quench from a domain-wall state in a gapped antiferromagnetic XXZ/Heisenberg chain, use of exact wavefunctions and overlaps) but oversta...
#
# Conversation 73:
#   Judgment: No
#   Explanation preview: Faithfulness (62/100):
# - The summary includes an incorrect overgeneralization: it states that nova duration is determined by strong wind mass loss that “depends only on the white dwarf mass.” The pape...
#
# Conversation 74:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope and findings: micromagnetic simulations plus Thiele-equation analysis; motion governed by interplay between magnonic driving ...
#
# Conversation 75:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - The summary correctly states the paper’s focus on transport properties of dense electron–proton plasma under strong quantizing magnetic fields and that an exact relativistic f...
#
# Conversation 76:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content. It correctly states the focus on aspherical nebulae around massive stars, the comparison to planetary nebulae (PNe), ...
#
# Conversation 77:
#   Judgment: No
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s context and goals: PHENIX’s large, distributed collaboration, growing data volumes (~1/4 PB/year), the focus on grid-based solution...
#
# Conversation 78:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and key claims: nematicity in Sr3Ru2O7 (bilayer ruthenate), the generic first-order nature of the isotropic–nematic transitio...
#
# Conversation 79:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It correctly states that multi-post re-entrant cavities are modeled as magnetically coupled lumped-element harmonic oscill...
#
# Conversation 80:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces at least one unsupported, specific numerical claim: it states that gas–liquid coexistence disappears “for particle radii in the range of 1–3 nm,” which ...
#
# Conversation 81:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it describes initial weak-lensing results for nearby SDSS clusters, selection from the C4 and Berlind spectroscopic catalo...
#
# Conversation 82:
#   Judgment: Yes
#   Explanation preview: Faithfulness (75/100):
# - Strengths: The summary correctly states that the paper studies how tight focusing affects far-field cross sections and near-field enhancement for gold and silver nanospheres, ...
#
# Conversation 83:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content. It correctly states the existence of gap-Townes solitons in multidimensional (2D/3D) Gross–Pitaevskii equations with ...
#
# Conversation 84:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - The summary accurately reflects the paper’s focus on 1D bosons and fermions with zero-range interactions but finite effective range, the use of a two-channel (Hamiltonian two-...
#
# Conversation 85:
#   Judgment: No
#   Explanation preview: Faithfulness (85/100):
# - The summary correctly states the central conclusion that the non-anticommutativity parameter in the N=1/2 (denoted @xmath0) SU(N) (denoted @xmath1) gauge theory is found to be...
#
# Conversation 86:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s focus on replacing EpicFlow’s sparse-to-dense interpolation with a fully convolutional, data-driven method.
# - It correctly notes th...
#
# Conversation 87:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the core content of the paper: it states Kauffman’s conjecture about the simplest solution, that the paper proves it, and notes the connection ...
#
# Conversation 88:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects key claims: quadratic divergences cancel when tadpoles cancel; this cancellation involves top, Goldstone, and Higgs loops; and bosonic correcti...
#
# Conversation 89:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on the hydrodynamic instability of an accelerating ionization front (IF) into a molecular cloud and the formation of pillars....
#
# Conversation 90:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states the central idea: connecting the cumulants of time-integrated observables in closed quantum systems to...
#
# Conversation 91:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It correctly states that the study analyzes high-frequency p-mode oscillations localized in neutron star envelopes, highli...
#
# Conversation 92:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s main claim that magneto-convection can form active regions without a pre-existing coherent flux tube.
# - It correctly describes the ...
#
# Conversation 93:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary largely reflects the core idea of the paper: that non-spherical (elliptical) galaxy halos induce a shear–ellipticity anti-correlation that can contaminate tomograp...
#
# Conversation 94:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: it refers to adiabatic techniques known from multi-level (optical/atomic) systems, their application to ultracold ato...
#
# Conversation 95:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s content: it describes a one-way light-path laser diffraction experiment aligned relative to the Earth’s velocity vector (as inferre...
#
# Conversation 96:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it reports new Chandra X-ray and FCRAO CO observations, the identification of three CO clouds around the lobe, the key fin...
#
# Conversation 97:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: constructing an interaction potential for ground-state Mg–Mg collisions, using it to reproduce rovibrational term val...
#
# Conversation 98:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core claims: bars drive gas inflow via gravitational torques; viscous torques are not the primary driver; CMC growth alone often ca...
#
# Conversation 99:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core claims: two sources of velocity error in PTV (acceleration vs. position uncertainty), opposing trends with frame rate, error p...
#
# Conversation 100:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: it reports a dip (dearth) of disk stars near zero angular momentum in Gaia-DR1/TGAS cross-matched with RAVE, attribut...
#
# Conversation 101:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content: it discusses UV spectra of hot hydrogen-rich CSPN observed with FUSE and HST, the dominance of Fe/Ni lines, their use as t...
#
# Conversation 102:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# ...
#
# Conversation 940:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a specific numerical claim that contradicts the paper: it states second-layer promotion occurs at 0.111(4) Å^-2, while the paper reports 0.107(3) Å^-2 (an...
#
# Conversation 941:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary includes several claims not supported by the provided paper text. It states that 0957+561 is the first gravitational lens discovered and the first with a measured ...
#
# Conversation 942:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly states the study measures FP parameters for six field ellipticals at intermediate redshift using HST MDS imaging, finds a zero-point offset in...
#
# Conversation 943:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the common belief that plane wave spacetimes are causally well-behaved and accurately captures the paper’s central claim that the autho...
#
# Conversation 944:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains factual inaccuracies. It states that the magnetic field is lower than 10 MG, whereas the paper constrains it more strictly to B < 3 MG based on the absenc...
#
# Conversation 945:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary is mostly aligned with the paper’s content (mission goal, Q1 analysis, use of raw vs PDC time series, and the conclusion that precision meets expectations).
# - How...
#
# Conversation 946:
#   Judgment: No
#   Explanation preview: Faithfulness (85/100):
# - The summary broadly aligns with the paper’s themes: QSO absorption lines as probes of chemical, ionization, and kinematic conditions; leveraging Milky Way and nearby galaxies ...
#
# Conversation 947:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s core claims: apparent cosmic acceleration arises from causal backreaction due to structure formation, without invoking dark energy,...
#
# Conversation 948:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: it focuses on uncertainty propagation with emphasis on asymmetric uncertainties; adopts a Bayesian probabilistic fram...
#
# Conversation 949:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: proposing and testing the WTMM (wavelet transform modulus maxima) method for automated coronal loop detection in EUV ...
#
# Conversation 950:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s focus: predicting correlations between Lyman-alpha forest transmitted flux and underlying mass using HPM simulations validated agai...
#
# Conversation 951:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# The summary accurately reflects the paper’s core content. It correctly states that the authors present a simple, exactly solvable model for qubit noise with zero-bandwidth envir...
#
# Conversation 952:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it mentions observed electron-cloud effects during LHC commissioning, the development of a benchmarking method that relate...
#
# Conversation 953:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary accurately states the main contribution (implementing a hierarchical tree algorithm within an individual-timestep Hermite scheme on GRAPE-9), the role of indirect ...
#
# Conversation 954:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core claims: the superconducting state in cuprates is inhomogeneous; two classes of inhomogeneous microscopic models are proposed; ...
#
# Conversation 955:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary includes specific details not supported in the provided text, notably that the muon tracker has “six horizontal layers” and that the neutron detector is “sandwiche...
#
# Conversation 956:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s core content: probing the excitations of strongly interacting 1D Bose gases via Bragg spectroscopy, analyzing the dynamical structu...
#
# Conversation 957:
#   Judgment: No
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately states that the paper discusses general properties of extensive air showers, focuses on longitudinal development (including energy flow), and covers lat...
#
# Conversation 958:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary misattributes the primary cause of the geometric distortion to the “off-axis location of the ACS.” The provided text explicitly states that the tilted focal surfac...
#
# Conversation 959:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope: interpolating Padova94 stellar evolutionary tracks in metallicity, care to avoid spurious features, subdivision into evoluti...
#
# Conversation 960:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic (2D viscous flow around a flapping foil in a uniform stream), method (lattice Boltzmann simulations at moderate Reynolds numb...
#
# Conversation 961:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the core content: use of MDI/SOHO data during solar cycle 23, analysis of centroid frequencies and splitting coefficients, construction of a se...
#
# Conversation 962:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it describes first-principles (DFT) investigation of graphene in contact with and sandwiched between WS2 and WSe2, notes i...
#
# Conversation 963:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content. It correctly states that confinement typically lowers transition temperatures (e.g., freezing and superfluid transition in...
#
# Conversation 964:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that 3D radiative-hydrodynamical simulations were performed for HD140283 and HD84937, that adiabatic c...
#
# Conversation 965:
#   Judgment: Yes
#   Explanation preview: Faithfulness (84/100):
# - The summary accurately reflects the paper’s core content: using a weather station to measure solar irradiance, employing a collocated sky camera to automatically compute cloud...
#
# Conversation 966:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that the analysis starts from coupled Boltzmann equations, addresses two-species cold gases in both a ...
#
# Conversation 967:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 88
# - The summary accurately reflects the paper’s main focus: calculating the mass and decay constant of a strange tensor meson via QCD sum rules.
# - It correctly notes consistency...
#
# Conversation 968:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content as an agenda-setting overview of open questions in star and cluster formation.
# - It correctly mentions key debates discusse...
#
# Conversation 969:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It states that the late-time behavior of the Einstein–dust system is well understood for homogeneous (Bianchi) spacetimes,...
#
# Conversation 970:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly states the core setup (BEC Bogoliubov modes coupled to a cavity field), and the main findings that radiation pressure modifies the Bogoliubov ...
#
# Conversation 971:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core claims: article page views peak and then decay, the decay is nonexponential, and this behavior resembles physical aging in com...
#
# Conversation 972:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - The summary accurately reflects the paper’s main claims: long-range interactions between dark solitons in inhomogeneous BECs mediated by sound, energy exchange without direct ...
#
# Conversation 973:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: exploiting low-dimensional slow/inertial manifolds to enable efficient computations; the difficulty of approximating ...
#
# Conversation 974:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it studies gravitational waves during preheating; notes that inflaton oscillations drive parametric resonance in scalar fl...
#
# Conversation 975:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it emphasizes the central role of the ISM in disk galaxy formation, the split between cosmological simulations and local I...
#
# Conversation 976:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it reports two possible infrared counterparts to SGR 1806-20, localization with archival Chandra data to a stated accuracy...
#
# Conversation 977:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core ideas: the importance of conformal invariance, the usual definition requiring a group action on fields and metric rescaling, a...
#
# Conversation 978:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary inaccurately describes the decays as “semileptonic” (“simileptonic”), whereas the paper studies OZI-forbidden hadronic annihilation decays of the B_c into light me...
#
# Conversation 979:
#   Judgment: No
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic: 2D Fermi gases, the BCS–BEC crossover enabled by Fano–Feshbach resonances, and the BKT transition.
# - It correctly states tha...
#
# Conversation 980:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content. It states that the theory expresses anomalous Hall conductivity in terms of local (single-site) atomic-like orbitals,...
#
# Conversation 981:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary correctly captures key observations (delayed, long-lived GeV emission), the proposed external-shock synchrotron interpretation, the no–magnetic-field-am...
#
# Conversation 982:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope: HI 21-cm absorption observations toward radio sources close to lines of sight to 25 previously studied stars; this is framed...
#
# Conversation 983:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s content: it identifies attribute reduction as the motivating problem, notes the use of rough sets and matroids, states that a depen...
#
# Conversation 984:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary largely reflects the paper’s focus and conclusions for MCG−6-30-15 (i.e., that the Compton downscattering model violates constraints such as the blackbody limit an...
#
# Conversation 985:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains at least two factual inaccuracies relative to the paper. First, it claims that the majority of the IR emission arises from “@xmath0100pc,” introducing an ...
#
# Conversation 986:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s main topics: high-energy factorization in QCD for DIS and p–A, the use of Wilson lines and rapidity factorization, the role of the ...
#
# Conversation 987:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic (ODCR in nominally undoped CdTe/(Cd,Mn)Te QWs), key findings (electron effective mass increases as QW width decreases; numeri...
#
# Conversation 988:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary correctly captures the paper’s focus on assessing the 2880 Earth impact risk of asteroid (29075) 1950 DA, identifies the Yarkovsky effect as the dominan...
#
# Conversation 989:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - The summary accurately reflects the paper’s topic: evaluating how low- and high-energy hadronic interaction models and the transition energy affect ground-level muon and elect...
#
# Conversation 990:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 92
# - The summary accurately reflects the paper’s core content: spectrogram-based time–frequency analysis from a single stationary sensor; use of geometric arguments and an ideali...
#
# Conversation 991:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a clear factual error about data size: it states “33,708 tweets,” whereas the paper reports collecting 371,264 tweets (with 41% removed in preprocessing, ...
#
# Conversation 992:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: a two-dimensional numerical study of the boundary-fed CDIMA reaction–diffusion system using a realistic (LRE) model; ...
#
# Conversation 993:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic and findings: stability of Uranus Trojans near L4/L5 using N-body OSS integrations; use of a-cuts (varying semimajor axis at ...
#
# Conversation 994:
#   Judgment: No
#   Explanation preview: Faithfulness (80/100):
# - Mostly accurate: The summary correctly states that the heavy quark is static, the light quark mass is near the strange quark, the study focuses on excited states (higher angul...
#
# Conversation 995:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on worst-case mobile users in OFDM-based cellular networks modeled via stochastic geometry.
# - It correctly states that the au...
#
# Conversation 996:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Largely accurate: it correctly states that 21 lithium-rich ROSAT counterparts were observed by Hipparcos; that parallaxes, proper motions, and photometry were analyzed; that 1...
#
# Conversation 997:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content. It correctly identifies XRF 030723 as the first likely XRF–SN association, describes the use of synthetic light curves to ...
#
# Conversation 998:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it describes the adiabatic matter creation framework, the datasets used (SNe Ia, H(z), CMB, BAO), the flat-universe assump...
#
# Conversation 999:
#   Judgment: No
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately states that the paper introduces a new equilibration scenario (ISIPP) in heavy-ion collisions and discusses its implications for equilibration and parti...
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total evaluated: 1000
# Yes: 748 (74.8%)
# No: 252 (25.2%)
# Unknown: 0 (0.0%)

# %%
# Save results to JSONL file
import json

# Create filename with baseline_eval in it
output_filename = f"/Users/ryanarman/code/lab/arxiv_abstract/data/original_eval_qwen3_4b_test.jsonl"

# Write results to JSONL file
with open(output_filename, 'w', encoding='utf-8') as f:
    for idx, result, prompt in original_results:
        output_data = {
            'index': idx,
            'judgment': result['judgment'],
            'explanation': result['explanation'],
            'evaluation_prompt': prompt
        }
        f.write(json.dumps(output_data, ensure_ascii=False) + '\n')

print(f"Saved {len(original_results)} results to {output_filename}")
# Out:
# Saved 1000 results to /Users/ryanarman/code/lab/arxiv_abstract/data/original_eval_qwen3_4b_test.jsonl

# %% [markdown]
# ## original abstract: 75%

# %% [markdown]
# # Evaluate the teacher

# %%
gpt5_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_test_instruct_gpt5.jsonl"
gpt5_test_conversations = load_conversations(gpt5_test_path)

# %%
gpt5_results, gpt5_errors = evaluate_summaries_batch(
    gpt5_test_conversations,
    model="gpt-5",
    temperature=1.0,
    max_workers=1000,  # Adjust based on your API rate limits
    show_progress=True
)

# Display results
print("\n" + "="*80)
print("BATCH EVALUATION RESULTS")
print("="*80)

# %%
for idx, result, prompt in gpt5_results:
    print(f"\nConversation {idx}:")
    print(f"  Judgment: {result['judgment']}")
    # Optionally show a snippet of the explanation
    explanation_preview = result['explanation'][:200] + "..." if len(result['explanation']) > 200 else result['explanation']
    print(f"  Explanation preview: {explanation_preview}")

if gpt5_errors:
    print(f"\nErrors encountered: {len(gpt5_errors)}")
    for idx, error in gpt5_errors:
        print(f"  Conversation {idx}: {error}")

# Summary statistics
judgments = [result['judgment'] for _, result, _ in gpt5_results]
yes_count = judgments.count('Yes')
no_count = judgments.count('No')
unknown_count = judgments.count('Unknown')

print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Total evaluated: {len(gpt5_results)}")
print(f"Yes: {yes_count} ({yes_count/len(gpt5_results)*100:.1f}%)")
print(f"No: {no_count} ({no_count/len(gpt5_results)*100:.1f}%)")
print(f"Unknown: {unknown_count} ({unknown_count/len(gpt5_results)*100:.1f}%)")
# Out:
# Conversation 0:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s topic (quantum tunneling/barrier penetration), the limitation of the parabolic (Hill–Wheeler) approximation at deep sub-barrier ene...
#
# Conversation 1:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s goals, methods, and findings. It correctly describes the combination of force-gradient and multirate (nested) ideas, the introducti...
#
# Conversation 2:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s main contributions and scope. It correctly identifies two integration-by-parts–free methods: (1) algebraic relations between produc...
#
# Conversation 3:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 96
# - The summary accurately reflects the paper’s topic (hierarchical Hough-transform searches for continuous GWs), the proposed method (frequency Hough mapping time-observed freq...
#
# Conversation 4:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the review’s scope (pre-explosion imaging of CC SN progenitors), methods (registration of high-resolution pre- and post-SN images; use of space...
#
# Conversation 5:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope and findings: SSAs in nearly back-to-back dijet correlations at RHIC, focus on the Sivers effect’s process dependence, and th...
#
# Conversation 6:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly identifies the paper’s main objects and results: an LDP for nτn (time to come down from infinity to n lines) with speed n via the Gärtner–Elli...
#
# Conversation 7:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on using strong subadditivity (SSI) of von Neumann entropy to study and quantify entanglement in a physically realizable four...
#
# Conversation 8:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic and methods: PBH constraints on small-scale perturbations, limitations of the Stewart–Lyth approximation near the end of infl...
#
# Conversation 9:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100): The summary closely reflects the paper’s content. It accurately describes SOFIA’s unique coupling of telescope pointing to aircraft heading and target history, the dual planning...
#
# Conversation 10:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope: cooperative dipole–dipole effects on macroscopic quantum jumps in two-ion systems, considering a three-level D configuration...
#
# Conversation 11:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on a minimal R-symmetric supersymmetric model (continuous R-symmetry), noting the absence of the μ term, A-terms, and Majoran...
#
# Conversation 12:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on practical integer multiplication for small inputs and contrasts it with asymptotically fast algorithms (Schönhage–Strassen...
#
# Conversation 13:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly presents the HiRes monocular measurements, the fluorescence technique and geometry reconstruction via shower–...
#
# Conversation 14:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on microlensing for exoplanet detection, the role of binary-lens caustics, dependence of detection efficiency on sampling/pre...
#
# Conversation 15:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic (reanalysis of VLBI maser kinematics to infer the Milky Way’s circular speed at the Sun’s radius) and key methods (Bayesian f...
#
# Conversation 16:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100): The summary accurately reflects the paper’s content. It correctly identifies the reaction (pn → d π0π0), the experimental setup (WASA at COSY, quasi-free np in reversed kinemati...
#
# Conversation 17:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: the limitations of Hilbert-space Jastrow stenciling for dynamic correlation and DMC, the introduction of real-space f...
#
# Conversation 18:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper’s content. It correctly states the observational motivation (dearth of [Fe/H] ≤ −3 stars in dSphs), the hypothesis tested (self-enrichm...
#
# Conversation 19:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100): The summary accurately reflects the paper’s core content. It correctly states that the work studies semi-infinite non-Hermitian systems without PT symmetry, models a finite non-...
#
# Conversation 20:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper. It correctly states the goal (deriving the VFT law), the theoretical basis (quantum transition-rate rule with entropy from the logarit...
#
# Conversation 21:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the simplest O(N)-invariant, totally symmetric rank-three tensor model defining a commutative but ...
#
# Conversation 22:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s proposal: a small fraction of decaying dark matter converts into a scalar field that condenses late and behaves like quintessence, ...
#
# Conversation 23:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it states the goal (predicting heavy meson–doubly heavy baryon molecules), the EFT framework at LO constrained by HQSS and...
#
# Conversation 24:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on classical, interference-based factorization using truncated sums (Fourier, Gauss, Kummer, and higher-order variants) deriv...
#
# Conversation 25:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s setting (universal PAC learning over all total computable concepts on finite binary strings, with hypothesis space of partial compu...
#
# Conversation 26:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly reports the first [C I] 3P1–3P0 detection from a protoplanetary disk (DM Tau), the use of the ALMA Band 8 qua...
#
# Conversation 27:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly describes the KIS color–color selection (four broadband plus Hα), the use of DA model atmospheres and proximi...
#
# Conversation 28:
#   Judgment: Yes
#   Explanation preview: Faithfulness (83/100):
# - Strengths: The summary accurately reflects the paper’s aim (constraining the substellar IMF using star-to–brown-dwarf ratios across several clusters), the dataset (seven nearb...
#
# Conversation 29:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the system (three-terminal bridge, ring vs. linear chain), the method (nearest-neighbor tight-bind...
#
# Conversation 30:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and results: pure dephasing of a qubit non-dissipatively coupled to a bosonic bath; exact total state via a matrix-valued par...
#
# Conversation 31:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: an AO testbed exploring MCAO/MOAO with SLMs and the addition of a high-stroke “woofer” DM (ALPAO DM52) for open-loop control...
#
# Conversation 32:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# The summary accurately reflects the paper’s content. It correctly describes the pulse-wise modeling approach (Band + Norris + LK96), XSPEC implementation with two parameters, ap...
#
# Conversation 33:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 94
# - The summary accurately reflects the paper’s aims and contributions: a unified derivation of MFDRs at NESS using the Agarwal formalism; equivalence of Langevin and master-equ...
#
# Conversation 34:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope and methods: composite-operator (2PI) effective action, two-loop treatment, variational ansatz for the fermion self-energy, f...
#
# Conversation 35:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on using zero-frequency current noise in the nonlinear Coulomb-blockade regime of a spin-degenerate double quantum dot to acc...
#
# Conversation 36:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the object (the Nessie IRDC), observational method (Mopra mapping of HNC(1–0)), key observational ...
#
# Conversation 37:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on SU(4) symmetry in graphene’s Landau levels, the extension of composite-fermion theory via Fock’s cyclic condition, and the...
#
# Conversation 38:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately represents the paper’s focus on molecular motors performing alternating directed and diffusive motion due to binding/unbinding to cytoskeletal filaments...
#
# Conversation 39:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s topic and contributions: modeling the pairwise peculiar velocity distribution (PVDF) using the dark halo framework; deriving the si...
#
# Conversation 40:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes constructing Maxwell fields on the Einstein universe aligned with the Hopf fibration, the use of a ...
#
# Conversation 41:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s scope and contributions. It correctly states that the authors develop a thermodynamically consistent Ginzburg–Landau phase-field mo...
#
# Conversation 42:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and key findings: the analysis of black holes in bigravity, the non-regularity of the Isham–Storey solution except in the pro...
#
# Conversation 43:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on SFXTs and the clumpy, line-driven wind accretion model. It correctly mentions key elements: a power-law clump mass distrib...
#
# Conversation 44:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# The summary accurately reflects the paper’s content. It correctly states the two key dynamical processes (phase-space mixing and mass segregation), the expectation that outer re...
#
# Conversation 45:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core claims: singular Laplacian growth as a maximally nonunique “fragile” system; the proposal that turbulence has a fragile limiti...
#
# Conversation 46:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic, methodology, dataset, and conclusions. It correctly cites AGASA’s reported six doublets and one triplet, the HiRes-I monocul...
#
# Conversation 47:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s focus on a central-charge superspace formulation of the 4D N=2 vector–tensor multiplet.
# - It correctly notes the use of maximally c...
#
# Conversation 48:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately describes the toolkit’s original focus on two-sample goodness-of-fit testing, its iterative development driven by Geant4 validation use cases, and the e...
#
# Conversation 49:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the system (CBS from two well-separated atoms in shallow harmonic traps), the two-way interferomet...
#
# Conversation 50:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes the detector’s purpose (secondary-vertexing and track seeding in a high-multiplicity LHC environmen...
#
# Conversation 51:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100): The summary accurately reflects the paper’s content. It correctly identifies the model (random-coupling transverse-field Ising model on random regular graphs), the DMRG extensio...
#
# Conversation 52:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the three core topics: (1) low-energy two-nucleon EFT using Weinberg’s power counting with finite cutoff; (2) the chiral bag treatment of the p...
#
# Conversation 53:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately captures the paper’s scope, instruments (SDO/AIA 131 and 94 Å; STEREO/EUVI), event set (three C-class limb flares on 2011 Mar 16, May 9, May 18), method...
#
# Conversation 54:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes STAR’s capabilities, the use of triggered and non-triggered correlations, the same-side minijet pea...
#
# Conversation 55:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s scope (ALICE pp at √s = 13 TeV, |y| < 0.5), methods (ITS/TPC/TOF/HMPID PID; invariant-mass analyses with like-sign/event-mixing; we...
#
# Conversation 56:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the two specific quiescent filament eruptions (1999 Sep 20 and 2001 Sep 28), their southern-hemisp...
#
# Conversation 57:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope (noncovalent π-stacking of TPP on CNTs and graphene), methods (vdW-DF DFT with SIESTA and linear-response dielectric function...
#
# Conversation 58:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic (current helicity in the solar corona), definitions (h_c = B·j; relation to α under force-free conditions), method (coupled f...
#
# Conversation 59:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately captures the paper’s scope: SMQC for circuits without nonlocal measurements, reduction to secure two-party NL-CNOT via UC composition, and a simplified ...
#
# Conversation 60:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s focus on the single-site entanglement entropy at the Mott transition in the half-filled Hubbard model in infinite dimensions.
# - It ...
#
# Conversation 61:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on mitigating dust-related selective extinction using combined color indices (Q) derived from BVRI photometry and standard Ga...
#
# Conversation 62:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on non-ergodic effects in Coulomb glasses and their impact on the measured specific heat as a function of measurement time.
# -...
#
# Conversation 63:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes the motivation (limits of spatial PD under weak dilemmas), the model setup (unconditional agents on...
#
# Conversation 64:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# - The summary accurately reflects the paper’s focus on determining Wilson-line geometry for (un)integrated PDFs and the soft factor in TMD factorization.
# - It correctly contrast...
#
# Conversation 65:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately captures the paper’s focus on the electrostatic potential distribution in biased molecular wires and the conflicting prior results (linear vs contact-do...
#
# Conversation 66:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and contributions: constructing exact, static, spherically symmetric interior solutions to the Einstein–Maxwell equations for...
#
# Conversation 67:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope and findings. It correctly states that the authors ran large ensembles of N-body simulations of marginally unstable, three-pl...
#
# Conversation 68:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it identifies the decay Λc → Λ ℓ ν̄, the LCSR method, the use of updated Λ-baryon distribution amplitudes, the two interpo...
#
# Conversation 69:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s content. It correctly states the use of the SOHO/MDI–Debrecen sunspot data (SDD), the hourly cadence, inclusion of polarity, areas,...
#
# Conversation 70:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope, data, and findings: two-epoch HST F606W imaging (WFPC2 1995; ACS/WFC 2002) over 7.25 years; image alignment using background...
#
# Conversation 71:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 94
# - The summary accurately reflects the paper’s scope and findings: a three-wave χ(2) planar waveguide with a Bragg grating coupling two counterpropagating FF waves and quadrati...
#
# Conversation 72:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s topic (post-quench dynamics in the antiferromagnetic XXZ spin-1/2 chain from a domain-wall state) and core methods (integrability, ...
#
# Conversation 73:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it describes optically thick, radiation-driven winds triggered by the iron-opacity peak; the quasi-evolution sequence of w...
#
# Conversation 74:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 96
# - The summary accurately reflects the paper’s scope, methods (3D micromagnetic simulations and Thiele equation), system (nanostrips with interfacial DMI, rf-excited spin waves...
#
# Conversation 75:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope: transport properties of dense electron–proton plasma in ultra-strong, quantizing magnetic fields relevant to magnetars.
# - It...
#
# Conversation 76:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s main arguments and evidence. It correctly states that the paper challenges interacting-wind and merger scenarios and advocates intr...
#
# Conversation 77:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly describes the PHENIX distributed environment, use of Globus Toolkit (2.2.x), two-level file cataloging (centr...
#
# Conversation 78:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - Accurate: The summary correctly identifies the context (Sr3Ru2O7 nematicity, metamagnetic transitions, transport anisotropy, quantum-critical thermodynamics), the core proposa...
#
# Conversation 79:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It correctly describes multi-post re-entrant cavities as arrays of mechanically tunable LC-like posts coupled via mutual i...
#
# Conversation 80:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on hollow nanoparticles (carbon fullerenes and inorganic analogues), modeled via continuum shell elasticity and vdW interacti...
#
# Conversation 81:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope, data source (SDSS DR6), selection from two spectroscopic catalogs (C4 and an FoF catalog based on NYU-VAGC), methodology (PH...
#
# Conversation 82:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately captures the paper’s focus on comparing high-NA focused illumination to plane-wave (PW) excitation for spherical metal nanoparticles using a generalized...
#
# Conversation 83:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s topic and contributions: multidimensional BECs in separable optical lattices governed by the GPE; identification and role of gap–To...
#
# Conversation 84:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on 1D Bose and Fermi gases with zero-range interactions including a finite effective range, the integrability controversy (BA...
#
# Conversation 85:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# The summary accurately reflects the paper’s focus on the two-loop renormalization of the non-anticommutativity parameter C in four-dimensional N=1/2 (deformed N=1) gauge theorie...
#
# Conversation 86:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and contributions: a neural network-based sparse-to-dense interpolation module replacing EpicFlow, use of edges as input, a l...
#
# Conversation 87:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately captures the paper’s topic (Chinese Rings puzzle), the main goal (proving optimality of a solution conjectured by Kauffman), the definition of complexit...
#
# Conversation 88:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on top-quark condensation, the hierarchy problem, and the role of quadratic divergences.
# - It correctly states that current c...
#
# Conversation 89:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper’s content. It correctly states the context (pillar formation at molecular cloud–H II interfaces), the core hypothesis (accelerating ion...
#
# Conversation 90:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s core claims: the link between time-integrated observables and the PT-symmetry of a non-Hermitian tilted Hamiltonian; unbroken PT le...
#
# Conversation 91:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope, methods, and findings. It correctly notes the study of high-frequency p-modes in neutron-star envelopes using the relativist...
#
# Conversation 92:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# The summary accurately reflects the paper’s content. It correctly states the motivation (testing whether coherent deep flux tubes are necessary), the setup (Stagger code; 48 Mm ...
#
# Conversation 93:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s core contribution: a shear–ellipticity cross-correlation induced by galaxy–galaxy lensing from foreground, non-circular galaxies, d...
#
# Conversation 94:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100): The summary accurately reflects the paper’s content. It correctly identifies the goal (spatial adiabatic passage/STIRAP analogue for atom transport), the modeling approach (thre...
#
# Conversation 95:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s aims, theoretical framework (Ether Gauge Theory based on Tangherlini–Selleri transformations and a preferred CMB-linked frame), exp...
#
# Conversation 96:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100): The summary accurately reflects the paper’s scope, data, methods, and conclusions. It correctly cites the instruments (FCRAO 12CO/13CO J=1–0 at 45″, 80 ks Chandra/ACIS-I), the a...
#
# Conversation 97:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100): The summary accurately reflects the paper’s goals, methods, and findings. It correctly identifies the four potentials (RKR, IPA, ab initio MVB, and another theoretical potential...
#
# Conversation 98:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly states that bar-driven gas inflow is initiated by gravitational (not viscous) torques, quantifies the 10–15% ...
#
# Conversation 99:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core content: two competing PTV velocity error sources (acceleration vs. position uncertainty), the counterintuitive worsening of n...
#
# Conversation 100:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# The summary accurately reflects the paper’s content. It correctly describes the data set (Gaia DR1 TGAS cross-matched with RAVE DR5, 216,201 stars within ~700 pc), the observed ...
#
# Conversation 101:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on UV spectroscopy of very hot, H-rich CSPN, the dominance of iron-group lines, and the use of the Fe VI/Fe VII ionization ba...
#
# Conversation 102:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on irradiated hot Jupiters, the need for consistent atmosphere–interior coupling including incident stellar flux, and the use...
#
# Conversation 103:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope, methods, and findings. It correctly states the CSP challenges, the use of nonlocal van der Waals DFT combined with an evolut...
#
# Conversation 104:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately captures the paper’s core content: the EPS motivation for Weyl geometry, restriction to Weyl integrable spacetime via a Palatini approach, the identific...
#
# Conversation 105:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s scope, methodology, and findings. It correctly describes the observational context (a thin, kinematically coherent plane of 15 out ...
#
# Conversation 106:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 97
# - The summary accurately reflects the paper’s content. It correctly identifies SMC 3 as a symbiotic supersoft X-ray source with a 4.5-year WD+M-giant binary, uses the 110-day ...
#
# Conversation 107:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s scope and findings: expansion dynamics of two-component fermions in the 1D Hubbard model using tDMRG; comparison between TL and MI ...
#
# Conversation 108:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s model: at each time step one element is added; with probability p it joins an existing group proportionally to its size, and with p...
#
# Conversation 109:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope (ALICE measurements of strange and multi-strange hadron production in p–Pb and Pb–Pb), methods (topological reconstruction wi...
#
# Conversation 110:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s core content: a record-dynamics framework with log-Poisson (“Poisson in log time”) statistics for quakes, marginal stability, and i...
#
# Conversation 111:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately captures the paper’s focus on testing the purported dichotomy via continuum analysis and on the correlation between Compton reflection strength and intr...
#
# Conversation 112:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on gamma rays from inelastic neutron scattering in natural iron (56Fe) measured with an HPGe detector inside a large pre–WWII...
#
# Conversation 113:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the architecture (MDM stack with a Sierpinski-carpet fractal of silver nanobricks on SiO2 and a th...
#
# Conversation 114:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately captures the paper’s main claims: Dirac neutrinos, an additional family gauge symmetry with right-handed neutrinos as a triplet, heavy family Higgs/gaug...
#
# Conversation 115:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the SDSS project components (2.5 m telescope, 50 cm photometric telescope, imaging camera, dual 320-fiber spectrographs), goals (five-band imag...
#
# Conversation 116:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It correctly states the dataset (SDSS DR5), sample size (~738 DLAs), redshift range (≈2–5), methodology (automated search ...
#
# Conversation 117:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly describes the system (two transmon qubits dispersively coupled to a coplanar waveguide resonator), the measur...
#
# Conversation 118:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100): The summary accurately reflects the paper’s content. It correctly states Palomar 13’s unusually high mass-to-light ratio and NFW-consistent profile, the alternative possibility ...
#
# Conversation 119:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content: Telescope 1’s operation since Jan 2005 at FLWO/Mt. Hopkins; use of 3.9 h Crab and 4.2 h Mrk 421 on–off data; CORSIKA-based...
#
# Conversation 120:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly describes RAVE’s scope (magnitude-limited, southern hemisphere, 6dF on the AAO UK Schmidt), spectral setup (R...
#
# Conversation 121:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s content: ASTRO-F’s role as Japan’s second IR mission, its 67 cm Ritchey–Chrétien telescope cooled to 5.8 K, two instruments (FIS an...
#
# Conversation 122:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on public goods games with group interactions, the introduction of heterogeneity via scaling factors drawn from uniform (mode...
#
# Conversation 123:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic (a square billiard rotating about a corner, breaking time-reversal symmetry) and motivation (relevance to rotating nuclei).
# -...
#
# Conversation 124:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it identifies the need for TRDs at higher Lorentz factors, the scintillator-based Compton scatter TRD design with thick/de...
#
# Conversation 125:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s main findings: discovery of 345 s pulsations with BeppoSAX, identification with 2E 0101.5−7225, confirmation with Chandra, steady s...
#
# Conversation 126:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100): The summary accurately reflects the paper’s scope and findings. It correctly states the focus on the high-density (classical-field) regime, the two main threads (defect-induced ...
#
# Conversation 127:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope: finite-temperature behavior of the dimension-two gluon condensate in Landau-gauge SU(N) Yang–Mills and its electric–magnetic...
#
# Conversation 128:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on LHC searches where signal location/shape may be unknown and the inadequacy of standard single-window significance calculat...
#
# Conversation 129:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic (electrostatics in quasi-2D/slab geometries), the limitations of 2D Ewald and naive 3D Ewald with a vacuum gap, and the need ...
#
# Conversation 130:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on explaining the tight M–σ (black hole mass–velocity dispersion) relation within the Kauffmann & Haehnelt (2000) semi-analyt...
#
# Conversation 131:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly reports the event (PF131010 “Ciechanów” fireball), the five-station PFN observations, derived trajectory and ...
#
# Conversation 132:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on timelike geodesic congruences in five-dimensional warped bulk spacetimes within braneworld scenarios, using the Raychaudhu...
#
# Conversation 133:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s contributions: FCN-based free-space segmentation, self-supervised training using disparity stixel world weak labels, and online sel...
#
# Conversation 134:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# The summary accurately reflects the paper’s scope and findings. It correctly specifies the system class (minimal LTI SISO with strictly proper rational transfer function, contro...
#
# Conversation 135:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 88
# - The summary closely reflects the paper’s content: it focuses on thermal monopoles identified as wrapping Euclidean trajectories in the maximally Abelian gauge, emphasizes Gr...
#
# Conversation 136:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s scope and findings. It correctly states the development of full-amplitude nonlinear convective models at Z=0.0004, the parameter ra...
#
# Conversation 137:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the close-limit, first-order perturbative approach, the two equal-mass black holes with equal and ...
#
# Conversation 138:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# The summary accurately reflects the paper’s content. It correctly states that the authors develop unconditionally stable semi-implicit algorithms for the PFC and SH equations vi...
#
# Conversation 139:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# The summary accurately reflects the paper’s topic, approach, and key findings: a one-zone SSC model is applied to PKS 2155−304’s 2006 flare and a 2003 low state; steady-state ki...
#
# Conversation 140:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper’s content. It correctly describes the two diagnostics studied (QPOs from co-rotating flares and light-bending-induced decoupling of lin...
#
# Conversation 141:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# - The summary accurately reflects the paper’s core content: the historical debate (absolute vs relational), the review of multiple relational/pregeometric approaches (events, pr...
#
# Conversation 142:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s system (a QH edge channel in an MZ interferometer Coulomb-coupled to a single-level quantum dot), the nonequilibrium drive (partiti...
#
# Conversation 143:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and findings: a finite-temperature Bethe–Salpeter equation (BSE) for a quark–scalar-diquark nucleon, quark-exchange kernel, m...
#
# Conversation 144:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope, methods, and findings. It correctly states the use of DFT (PW91; 6-31G** for H, LANL2DZ for Pd), reoptimization based on pri...
#
# Conversation 145:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately captures the paper’s aims (a semi-empirical, transferable framework combining EHT with NEGF), key components (non-orthogonal AO basis, level alignment f...
#
# Conversation 146:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper’s content. It correctly states that the author proposes a magnetic-flare origin for the radio and soft X-ray emission in Aql X-1’s Nove...
#
# Conversation 147:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope and findings: construction of thin-shell wormholes from the string-cloud (Letelier/global monopole) geometry via the cut-and-...
#
# Conversation 148:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s core contributions and context. It correctly states that RQ suffers from misaligned/noisy residuals and that the proposed TRQ learn...
#
# Conversation 149:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately describes the Fermi LAT as a pair-conversion gamma-ray telescope operating in all-sky survey mode and focuses on the FA-GSW service.
# - It correctly refl...
#
# Conversation 150:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it identifies the goal (predicting prompt atmospheric neutrino fluxes from charm), the methodology (NLO QCD matched to par...
#
# Conversation 151:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper’s goals, dataset (62 southern compact groups from Hickson and Prandoni within HIPASS), methods (estimation via Haynes & Giovanelli 1984...
#
# Conversation 152:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It captures the angle–EW test with superluminal sources, the cosθ dimming plus thin-disk limb darkening result, the “sum-o...
#
# Conversation 153:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: intersecting M2-brane solutions in 11D supergravity with self-dual 4D transverse spaces (Taub–NUT and triaxial Bianchi IX)...
#
# Conversation 154:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes the new high-cadence photometry (FLWO 1.2 m in g and z; TopHAT in r), the joint modeling with previ...
#
# Conversation 155:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s focus on the antiferromagnetic Ising model on 3-regular random networks with tunable clustering and the use of a node-to-triangle s...
#
# Conversation 156:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper's content. It correctly states the goal (creating ultracold molecules in the lowest rovibrational state), the approach (combining FOP...
#
# Conversation 157:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 93
# - The summary accurately reflects the experimental setup (Hele–Shaw cell, injected air creating a central band), key observations (threshold behavior: co-movement, faster-than...
#
# Conversation 158:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s content. It correctly describes the AHCAL’s use in test beams, the isolation criterion, the layer-by-layer straight-track search wi...
#
# Conversation 159:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - Accurate depiction of the paper’s focus on the low-metallicity tail of the Galactic halo MDF using HK, HES, SDSS DR3, and previewing SEGUE.
# - Correctly describes the estimatio...
#
# Conversation 160:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on EAS modeling for very high energy cosmic rays, the soft vs. semi-hard cascade picture, and the impact-parameter dependent ...
#
# Conversation 161:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes the Random Domino Automaton (RDA), its update rules, the use of elementary combinatorics to derive ...
#
# Conversation 162:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic: light-induced erosion of dusty sub-planetesimals via the solid-state greenhouse effect and photophoresis, and its gravity de...
#
# Conversation 163:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s topic: a DFI scheme using two in-line, double-pumped Fabry–Perot cavities to cancel mirror displacement noise and laser technical n...
#
# Conversation 164:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s focus on continuous-time collision avoidance in multi-agent, multi-obstacle settings using differential flatness with B-spline para...
#
# Conversation 165:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s three focal areas: GC origins in a cosmological context, mapping of compact stellar systems (including UCDs), and observations of t...
#
# Conversation 166:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100): The summary accurately reflects the paper’s content. It correctly presents the AID framework, its use of aggregation and selective declustering, the problem-specific optimality ...
#
# Conversation 167:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: a Tevatron-wide combination of CDF and D0 high-mass Higgs searches targeting H→WW in the 155–200 GeV range, using ~3 fb⁻¹ pe...
#
# Conversation 168:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It states the model’s reduction from trait-based attachment to a simpler process governed by k (number of candidates) and ...
#
# Conversation 169:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus: providing a semiclassical (classical-light) explanation for experiments that simulated Bell-state interference using pseudot...
#
# Conversation 170:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states the experimental context (CHASE setup with a 532 nm laser in a cryogenic magnet bore), the intended ch...
#
# Conversation 171:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s scope, dataset (1100 days; JD 2448387–2449480), instruments (BATSE LAD), energy bands (45–140 keV for spectra; 20–50 and 50–100 keV...
#
# Conversation 172:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes PSI’s HIPA-driven, high-intensity low-momentum muon program and its integration with SINQ, the prom...
#
# Conversation 173:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and findings. It correctly describes the system (AB-stacked BLG nanoflake between nonmagnetic zGNR electrodes), the modeling ...
#
# Conversation 174:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states the long-standing use of a linear k-factor and identifies the violated assumptions (linearity, symmetr...
#
# Conversation 175:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it describes the WISE–2MASS decade-long baseline, selection of WISE sources lacking 2MASS matches within 3 arcsec, color c...
#
# Conversation 176:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s scope and content: the motivation from nucleosynthesis modeling and alpha-induced reaction uncertainties, the focus on activation-b...
#
# Conversation 177:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s setup (phase estimation with a two-level system interacting with a squeezed thermal reservoir), method (non-perturbative path-integ...
#
# Conversation 178:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content: nine RXTE observations (Feb–Oct 1996), analysis using PCA in the stated energy bands, construction of hardness–intensity d...
#
# Conversation 179:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: SINFONI/VLT K-band AO integral-field spectroscopy on 2005 June 18, a >3 h NIR flare with ~10 min substructure and a period...
#
# Conversation 180:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states the SSME is based on Z=126 and proposed as a substitute for the Z=114 model within two shell regions b...
#
# Conversation 181:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s goals, setup, models, and findings: dynamic control of ENZ tunneling using lumped nonlinear elements in a cut-off waveguide; extens...
#
# Conversation 182:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly describes the simulation setup (3D N-body/SPH of a Milky Way–like galaxy with cooling, star formation, feedba...
#
# Conversation 183:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# ...
#
# Conversation 940:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope, methods, and findings: it describes grand-canonical path-integral QMC with the continuous-space worm algorithm, the modeling...
#
# Conversation 941:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s aims, methodology (Keck II/LRIS long-slit spectroscopy with a slit orientation to minimize QSO contamination), and the three disper...
#
# Conversation 942:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s goals, dataset, methodology, and findings. It correctly notes the selection from HST/WFPC2 MDS, the dual photometric fitting approa...
#
# Conversation 943:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it identifies the construction of a Ricci-flat, cylindrically symmetric spacetime with a covariantly constant null vector;...
#
# Conversation 944:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s content: observational setup (OHP 1.93 m; 43 spectra; 3600–7200 Å; ~7 Å resolution), refined orbital period (P = 5.341 ± 0.005 h), ...
#
# Conversation 945:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s aims (detecting Earth-size planets with ~20 ppm precision over 6.5 hours for Kp=12 G2V stars), dataset (first 33.5 days of Q1 long-...
#
# Conversation 946:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s aims, scope, and core findings: moving beyond line counts to probe galactic structures; combining Milky Way and nearby-galaxy sight...
#
# Conversation 947:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly states the motivation (accelerating expansion and issues with Λ), the backreaction alternative, and the criti...
#
# Conversation 948:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# The summary accurately reflects the paper’s content. It captures the critique of ad hoc quadrature/symmetrization rules for asymmetric systematic effects, the Bayesian framework...
#
# Conversation 949:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the WTMM method (2D wavelet-transform modulus maxima) using derivatives of a Gaussian, its multisc...
#
# Conversation 950:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately captures the paper’s focus on predicting large-scale correlations between Lyα transmitted flux and mass, motivated by galaxy–Lyα measurements, and the u...
#
# Conversation 951:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and contributions: a Hamiltonian model of zero-bandwidth (static, randomly distributed) noise, exact Kraus representations, c...
#
# Conversation 952:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s topic (electron-cloud effects in the LHC), mitigation context, and the proposed methodology. It correctly states that pressure rise...
#
# Conversation 953:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s aims, methods, hardware constraints, and solutions: implementing a Barnes–Hut tree within a block individual-timestep, 4th-order He...
#
# Conversation 954:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on inhomogeneous (striped) superconductivity in cuprates, the role of phase fluctuations and spatially varying superfluid den...
#
# Conversation 955:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s scope and content. It correctly states the experiment’s purpose (studying muon-induced spallation neutrons), location and depth (61...
#
# Conversation 956:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100): The summary accurately reflects the paper’s focus, methods, and conclusions: Bragg spectroscopy is used to probe the dynamical structure factor of 1D Bose gases; the data are co...
#
# Conversation 957:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary closely matches the paper’s content. It correctly states the role of EAS for high-energy cosmic ray studies, the use of CORSIKA simulations and simple (Heitler/sup...
#
# Conversation 958:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately describes the problem (geometric distortion in ACS), the key sources (tilted focal surface, OTA, ACS optics, SBC detector elements), the observational s...
#
# Conversation 959:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope and content: interpolating Padova94 stellar evolutionary models to densify the metallicity grid (Z=0.0004–0.004), the interpo...
#
# Conversation 960:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope (2D viscous flow around a flapping foil at moderate Reynolds numbers), method (lattice Boltzmann with moving immersed boundar...
#
# Conversation 961:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s content. It correctly states the use of 24 sets of 72-day MDI data (1996–2001), analysis of centroid frequencies and even-order spl...
#
# Conversation 962:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on inducing a QSH state in graphene at zero magnetic field via proximity to WS2 and WSe2.
# - It correctly describes the use of...
#
# Conversation 963:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly states the motivation (p-H2 crystallizes at 13.8 K; prior confinement in silica promotes freezing), the metho...
#
# Conversation 964:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on replacing traditional 1D LTE abundance analyses with 3D radiation–hydrodynamics simulations for metal-poor stars HD 140283...
#
# Conversation 965:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately captures the paper’s goals, methods, and findings. It correctly describes the use of ground-based sky cameras, undistortion via camera calibration, blue-t...
#
# Conversation 966:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s scope and contributions: a kinetic theory of thermalization for two-species ultracold gases in a box and harmonic trap, based on co...
#
# Conversation 967:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on computing the mass and leptonic decay constant of the ground-state strange tensor meson via QCD sum rules, with a derivati...
#
# Conversation 968:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope: a synthesized discussion (“tertulia”) on whether star clusters are fundamental building blocks or part of a hierarchical sta...
#
# Conversation 969:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on the Einstein–Vlasov system with Bianchi I symmetry and vanishing cosmological constant.
# - It correctly notes that the Vlas...
#
# Conversation 970:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100): The summary accurately reflects the paper. It correctly describes the system (BEC in a high-finesse cavity, Bogoliubov mode as a mechanical oscillator), the modeling (optomechan...
#
# Conversation 971:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s topic (decay of online article attention), datasets (42 articles in 2012; 19 in early 2015 from Scientific Reports with high initia...
#
# Conversation 972:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on sound-mediated interactions between dark solitons in inhomogeneous Bose–Einstein condensates, the use of the 1D Gross–Pita...
#
# Conversation 973:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper’s content. It correctly states the goal (on-the-fly approximation of a slow/approximate inertial manifold using only time-derivative ev...
#
# Conversation 974:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s topic, framework, and findings. It correctly states the use of the Maxwell–Weyl (covariant) description of gravitational waves, num...
#
# Conversation 975:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core content: it presents an AMR Enzo simulation with ~200 pc resolution, finds a warped disk, numerous satellites, an overly massi...
#
# Conversation 976:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it reports Chandra imaging and JHK near-IR observations, notes pile-up but usable localization, an absorbed power-law spec...
#
# Conversation 977:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s core ideas: a metric-independent definition of conformal invariance via measure line bundles; defining invariance as independence o...
#
# Conversation 978:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on OZI-forbidden B_c decays mediated by two gluons, computed at one loop in perturbative QCD without effective couplings or s...
#
# Conversation 979:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic (2D Fermi gases across the BCS–BEC crossover and BKT transition), methods (functional integral with renormalized Gaussian flu...
#
# Conversation 980:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s scope and contributions: a unified treatment of the anomalous Hall effect using Kubo linear response, an expression in terms of on-...
#
# Conversation 981:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content: delayed, power-law GeV emission; evaluation of external-shock synchrotron origin; focus on cases without magnetic-field am...
#
# Conversation 982:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope: a 21 cm H I absorption study along 25 sight lines (with two stars sharing one field, resulting in 24 pointings), selected ba...
#
# Conversation 983:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope: linking attribute reduction (in rough-set settings) with matroid theory via a dependence space constructed from a closure-in...
#
# Conversation 984:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s aim, methodology, and conclusions. It correctly states that the authors test the Compton downscattering model for broad Fe Kα lines...
#
# Conversation 985:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s motivation (polar-dominated mid-IR emission challenging classical torus models), approach (CAT3D-WIND with a thin clumpy disk plus ...
#
# Conversation 986:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on high-energy factorization in QCD for DIS and pA collisions, the use of high-energy OPE with Wilson lines and a rigid rapid...
#
# Conversation 987:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100): The summary accurately reflects the paper. It correctly states the system (nominally undoped CdTe/(Cd,Mn)Te QWs), method (optically detected cyclotron resonance via PL modulatio...
#
# Conversation 988:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it identifies the main object (NEA 1950 DA), the central role of the Yarkovsky effect in the 2880 encounter, the use of ex...
#
# Conversation 989:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s content. It correctly identifies the motivation (muon deficit in simulations), the simulation setup (CORSIKA with high-energy model...
#
# Conversation 990:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100): The summary accurately reflects the paper’s scope and contributions. It correctly states that the work extends spectrogram analysis of ship wakes to finite-depth channels, model...
#
# Conversation 991:
#   Judgment: Yes
#   Explanation preview: Faithfulness (99/100):
# - The summary accurately reflects the paper’s content. It correctly reports the dataset size (371,264 tweets), time window (Dec 16, 2015–Feb 29, 2016), use of the official hasht...
#
# Conversation 992:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s content. It correctly states that the authors provide the first 2D numerical solution of sustained Turing patterns in a boundary-fe...
#
# Conversation 993:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s scope, model (Sun + four giant planets), methods (Lie-series integrator; massless test particles; grids in semimajor axis and incli...
#
# Conversation 994:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s scope and findings: static heavy-quark limit; two degenerate light flavors; three ensembles with varying lattice spacings and light...
#
# Conversation 995:
#   Judgment: Yes
#   Explanation preview: Faithfulness (97/100):
# - The summary accurately reflects the paper’s content: it identifies the focus on worst-case mobile users at Poisson–Voronoi vertices with three equidistant nearest BSs, PPP mod...
#
# Conversation 996:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100): The summary accurately reflects the paper’s aims, methods, and findings. It correctly states that Hipparcos parallaxes and proper motions (with published radial velocities where...
#
# Conversation 997:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s topic (SN interpretation of the XRF 030723 bump) and methodology (LTE radiation-hydrodynamics with gray gamma-ray transport; carbon...
#
# Conversation 998:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s scope and findings: testing adiabatic matter creation (with creation rate proportional to Hn) as a driver of cosmic acceleration, d...
#
# Conversation 999:
#   Judgment: Yes
#   Explanation preview: Faithfulness (98/100):
# - The summary accurately reflects the paper’s core content. It correctly introduces the ISIPP scenario arising from the running QCD coupling as momentum transfer decreases, desc...
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total evaluated: 1000
# Yes: 991 (99.1%)
# No: 9 (0.9%)
# Unknown: 0 (0.0%)

# %%
# Save results to JSONL file
import json

# Create filename with baseline_eval in it
output_filename = f"/Users/ryanarman/code/lab/arxiv_abstract/data/eval_gpt5_test.jsonl"

# Write results to JSONL file
with open(output_filename, 'w', encoding='utf-8') as f:
    for idx, result, prompt in gpt5_results:
        output_data = {
            'index': idx,
            'judgment': result['judgment'],
            'explanation': result['explanation'],
            'evaluation_prompt': prompt
        }
        f.write(json.dumps(output_data, ensure_ascii=False) + '\n')

print(f"Saved {len(gpt5_results)} results to {output_filename}")
# Out:
# Saved 1000 results to /Users/ryanarman/code/lab/arxiv_abstract/data/eval_gpt5_test.jsonl

# %% [markdown]
# # Run inference on the base model

# %%
train_instruct_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_instruct.jsonl"
val_instruct_path =   "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_val_instruct.jsonl"
test_instruct_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_test_instruct.jsonl"
# train_distilled_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_abstract_train_gpt5mini_think2.jsonl"
train_instruct_conversations = load_conversations(train_instruct_path)
val_instruct_conversations = load_conversations(val_instruct_path)
test_instruct_conversations = load_conversations(test_instruct_path)

# %%
train_instruct_conversations[0]
# Out:
# [{'role': 'system',
#   'content': "You are an expert academic abstract writer. Your task is to create a high-quality abstract for an arXiv paper based on the paper content and judge evaluation feedback.\n\nThe judge evaluates abstracts based on five dimensions:\n1. Faithfulness: The abstract must accurately reflect the paper's content without hallucination\n2. Coverage: The abstract must include the essential aspects (main problem, approach, and key results)\n3. Clarity: The abstract must be understandable and readable\n4. Conciseness: The abstract must be focused and not verbose\n5. Coherence: The abstract must be logically structured and flow naturally\n\nWhen creating the abstract:\n- Read the paper content carefully\n- Pay attention to the judge's feedback on what makes a good abstract\n- Ensure your abstract meets all five evaluation criteria\n- Write a concise, clear, and coherent summary that accurately covers the paper's main contributions\n- Focus on the main problem, approach, and key results\n\nYour response should be the abstract only, without any additional commentary or explanation."},
#  {'role': 'user',
#   'content': 'Paper Content:\nadditive models @xcite provide an important family of models for semiparametric regression or classification . some reasons for the success of additive models are their increased flexibility when compared to linear or generalized linear models and their increased interpretability when compared to fully nonparametric models . \n it is well - known that good estimators in additive models are in general less prone to the curse of high dimensionality than good estimators in fully nonparametric models . \n many examples of such estimators belong to the large class of regularized kernel based methods over a reproducing kernel hilbert space @xmath0 , see e.g. @xcite . in the last years \n many interesting results on learning rates of regularized kernel based models for additive models have been published when the focus is on sparsity and when the classical least squares loss function is used , see e.g. @xcite , @xcite , @xcite , @xcite , @xcite , @xcite and the references therein . of course , the least squares loss function is differentiable and has many nice mathematical properties , but it is only locally lipschitz continuous and therefore regularized kernel based methods based on this loss function typically suffer on bad statistical robustness properties , even if the kernel is bounded . \n this is in sharp contrast to kernel methods based on a lipschitz continuous loss function and on a bounded loss function , where results on upper bounds for the maxbias bias and on a bounded influence function are known , see e.g. @xcite for the general case and @xcite for additive models . \n therefore , we will here consider the case of regularized kernel based methods based on a general convex and lipschitz continuous loss function , on a general kernel , and on the classical regularizing term @xmath1 for some @xmath2 which is a smoothness penalty but not a sparsity penalty , see e.g. @xcite . \n such regularized kernel based methods are now often called support vector machines ( svms ) , although the notation was historically used for such methods based on the special hinge loss function and for special kernels only , we refer to @xcite .    in this paper we address the open question , whether an svm with an additive kernel can provide a substantially better learning rate in high dimensions than an svm with a general kernel , say a classical gaussian rbf kernel , if the assumption of an additive model is satisfied . \n our leading example covers learning rates for quantile regression based on the lipschitz continuous but non - differentiable pinball loss function , which is also called check function in the literature , see e.g. @xcite and @xcite for parametric quantile regression and @xcite , @xcite , and @xcite for kernel based quantile regression . \n we will not address the question how to check whether the assumption of an additive model is satisfied because this would be a topic of a paper of its own . \n of course , a practical approach might be to fit both models and compare their risks evaluated for test data . \n for the same reason we will also not cover sparsity . \n consistency of support vector machines generated by additive kernels for additive models was considered in @xcite . in this paper \n we establish learning rates for these algorithms . \n let us recall the framework with a complete separable metric space @xmath3 as the input space and a closed subset @xmath4 of @xmath5 as the output space . \n a borel probability measure @xmath6 on @xmath7 is used to model the learning problem and an independent and identically distributed sample @xmath8 is drawn according to @xmath6 for learning . \n a loss function @xmath9 is used to measure the quality of a prediction function @xmath10 by the local error @xmath11 . \n _ throughout the paper we assume that @xmath12 is measurable , @xmath13 , convex with respect to the third variable , and uniformly lipschitz continuous satisfying @xmath14 with a fini ...
#  {'role': 'assistant',
#   'content': 'additive models play an important role in semiparametric statistics . \n this paper gives learning rates for regularized kernel based methods for additive models . \n these learning rates compare favourably in particular in high dimensions to recent results on optimal learning rates for purely nonparametric regularized kernel based quantile regression using the gaussian radial basis function kernel , provided the assumption of an additive model is valid . \n additionally , a concrete example is presented to show that a gaussian function depending only on one variable lies in a reproducing kernel hilbert space generated by an additive gaussian kernel , but does not belong to the reproducing kernel hilbert space generated by the multivariate gaussian kernel of the same variance .    * \n key words and phrases . * additive model , kernel , quantile regression , semiparametric , rate of convergence , support vector machine .'}]

# %%
test_instruct_conversations[0]
# Out:
# [{'role': 'system',
#   'content': "You are an expert academic abstract writer. Your task is to create a high-quality abstract for an arXiv paper based on the paper content and judge evaluation feedback.\n\nThe judge evaluates abstracts based on five dimensions:\n1. Faithfulness: The abstract must accurately reflect the paper's content without hallucination\n2. Coverage: The abstract must include the essential aspects (main problem, approach, and key results)\n3. Clarity: The abstract must be understandable and readable\n4. Conciseness: The abstract must be focused and not verbose\n5. Coherence: The abstract must be logically structured and flow naturally\n\nWhen creating the abstract:\n- Read the paper content carefully\n- Pay attention to the judge's feedback on what makes a good abstract\n- Ensure your abstract meets all five evaluation criteria\n- Write a concise, clear, and coherent summary that accurately covers the paper's main contributions\n- Focus on the main problem, approach, and key results\n\nYour response should be the abstract only, without any additional commentary or explanation."},
#  {'role': 'user',
#   'content': 'Paper Content:\nas a common quantum phenomenon , the tunneling through a potential barrier plays a very important role in the microscopic world and has been studied extensively since the birth of quantum mechanics . \n one of the earliest applications of quantum tunneling is the explanation of @xmath0 decays in atomic nuclei . \n the quantum tunneling effect governs also many other nuclear processes such as fission and fusion . \n in particular , a lot of new features are revealed in sub - barrier fusion reactions which are closely connected with the tunneling phenomena  @xcite .    for most of the potential barriers , the penetrability can not be calculated analytically  @xcite . among those potentials for which analytical solutions can be obtained , \n the parabolic potential  @xcite is the mostly used in the study of nuclear fusion . by approximating the coulomb barrier to a parabola \n , wong derived an analytic expression for the fusion cross section  @xcite which is widely adopted today in the study of heavy ion reactions ( see , e.g. , recent refs . \n the parabolic approximation works remarkably well both for the penetrability and for the fusion cross section at energies around or above the coulomb barrier  @xcite . \n apparently the parabolic approximation breaks down at energies much smaller than the barrier height due to the long - range coulomb interaction . \n one may calculate the penetration probability numerically by using the path integral method or the wkb approximation . \n however , it is highly desirable to have an analytical expression for the barrier penetrability when one introduces an energy - dependent one - dimensional potential barrier  @xcite or barrier distribution functions  @xcite .    in the present work \n , we derived a new barrier penetration formula based on the wkb approximation . \n the influence of the long coulomb tail in the barrier potential is taken into accout properly . \n therefore this formula is especially applicable to the barrier penetration with penetration energy much lower than the coulomb barrier .    as a first attempt and a test study \n , we apply this new formula to evaluate @xmath0 decay half - lives of atomic nuclei . for the @xmath0 decay , \n the penetrability is usually calculated with the wkb approach  @xcite , in other words , integrating numerically the wave number within two turning points at which the interaction potential is equal to the @xmath1-value of the @xmath0 decay . \n we will show that the present analytical formula reproduces the experimental results very well , especially for spherical nuclei . \n the paper is organized as follows . in sec . \n [ sec : formalism ] we present the new barrier penetration formula . \n the validity of the new formula is investigated and its application to @xmath0 decays are given in sec . \n [ sec : results ] . finally in sec . \n [ sec : summary ] we summarize our work . in the appendix , \n the detailed derivation of the new penetration formula is given . \n when the penetration energy is well below the coulomb barrier , the barrier penetrability formula derived from the wkb approximation reads , @xmath2 ,   \\label{eq : wkb}\\ ] ] where the potential usually consists of three parts , the nuclear , the coulomb , and the centrifugal potentials , @xmath3 @xmath4 and @xmath5 are the inner and outer turning points determined by the relation @xmath6 .    by approximating @xmath7 to a parabola with the height @xmath8 and the width @xmath9 , eq . \n ( [ eq : wkb ] ) is reduced as @xmath10 ,   \\label{eq : hw}\\ ] ] which has been widely used in the study of heavy ion reactions .    because of the long - range coulomb interaction , the coulomb barrier given in eq . \n ( [ eq : potential ] ) has a long tail and is asymmetric . \n thus for the penetration well below the barrier , the parabolic approximation is not valid . \n we may divide the potential barrier into two parts at the barrier position @xmath11 . \n ...

# %% [markdown]
# How to run inference on the cluster
#
# From the arxiv_abstract root directory:
#
# Option 1: Basic usage (uses defaults)
#   cd scripts
#   ./submit_inference_rsync.sh
#
# Option 2: Custom input file
#   cd scripts
#   ./submit_inference_rsync.sh ../data/arxiv_summarization_test_instruct.jsonl
#
# Option 3: Full specification
#   cd scripts
#   ./submit_inference_rsync.sh \
#     ../data/arxiv_summarization_test_instruct.jsonl \
#     ../configs/4b_instruct_vllm_infer.yaml \
#     qwen3_4b_test
#
# Option 4: With trained LoRA adapter
#   cd scripts
#   ./submit_inference_rsync.sh \
#     ../data/arxiv_summarization_test_instruct.jsonl \
#     ../configs/4b_instruct_vllm_infer.yaml \
#     output_name \
#     path/to/adapter/checkpoint \
#     ryan@exun
#
# Defaults:
#   - Input: data/arxiv_summarization_test_instruct.jsonl
#   - Config: configs/4b_instruct_vllm_infer.yaml
#   - Output name: output
#   - Cluster: ryan@exun
#
# The script will:
#   1. Copy files to the cluster using rsync
#   2. Submit a SLURM job for inference
#   3. Output will be saved to: data/output_<job_id>.jsonl on the cluster
#
# To check job status:
#   ssh ryan@exun 'squeue -u ryan'
#
# To view logs:
#   ssh ryan@exun 'tail -f /home/ryan/code/oumi/lab/arxiv_abstract/logs/arxiv_abstract_inference_qwen3_4b_*.log'
#
# To download results:
#   scp ryan@exun:/home/ryan/code/oumi/lab/arxiv_abstract/data/output_*.jsonl ./data/

# %%
base_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/qwen3_4b_test_2795.jsonl"
# train_distilled_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_abstract_train_gpt5mini_think2.jsonl"
base_qwen3_4b_test_conversations = load_conversations(base_qwen3_4b_test_path)

# %%
base_qwen3_4b_test_conversations_eval = [conv[1:] for conv in base_qwen3_4b_test_conversations]

# %%
conv = base_qwen3_4b_test_conversations_eval[0]
# Out:
# [{'content': 'Paper Content:\nas a common quantum phenomenon , the tunneling through a potential barrier plays a very important role in the microscopic world and has been studied extensively since the birth of quantum mechanics . \n one of the earliest applications of quantum tunneling is the explanation of @xmath0 decays in atomic nuclei . \n the quantum tunneling effect governs also many other nuclear processes such as fission and fusion . \n in particular , a lot of new features are revealed in sub - barrier fusion reactions which are closely connected with the tunneling phenomena  @xcite .    for most of the potential barriers , the penetrability can not be calculated analytically  @xcite . among those potentials for which analytical solutions can be obtained , \n the parabolic potential  @xcite is the mostly used in the study of nuclear fusion . by approximating the coulomb barrier to a parabola \n , wong derived an analytic expression for the fusion cross section  @xcite which is widely adopted today in the study of heavy ion reactions ( see , e.g. , recent refs . \n the parabolic approximation works remarkably well both for the penetrability and for the fusion cross section at energies around or above the coulomb barrier  @xcite . \n apparently the parabolic approximation breaks down at energies much smaller than the barrier height due to the long - range coulomb interaction . \n one may calculate the penetration probability numerically by using the path integral method or the wkb approximation . \n however , it is highly desirable to have an analytical expression for the barrier penetrability when one introduces an energy - dependent one - dimensional potential barrier  @xcite or barrier distribution functions  @xcite .    in the present work \n , we derived a new barrier penetration formula based on the wkb approximation . \n the influence of the long coulomb tail in the barrier potential is taken into accout properly . \n therefore this formula is especially applicable to the barrier penetration with penetration energy much lower than the coulomb barrier .    as a first attempt and a test study \n , we apply this new formula to evaluate @xmath0 decay half - lives of atomic nuclei . for the @xmath0 decay , \n the penetrability is usually calculated with the wkb approach  @xcite , in other words , integrating numerically the wave number within two turning points at which the interaction potential is equal to the @xmath1-value of the @xmath0 decay . \n we will show that the present analytical formula reproduces the experimental results very well , especially for spherical nuclei . \n the paper is organized as follows . in sec . \n [ sec : formalism ] we present the new barrier penetration formula . \n the validity of the new formula is investigated and its application to @xmath0 decays are given in sec . \n [ sec : results ] . finally in sec . \n [ sec : summary ] we summarize our work . in the appendix , \n the detailed derivation of the new penetration formula is given . \n when the penetration energy is well below the coulomb barrier , the barrier penetrability formula derived from the wkb approximation reads , @xmath2 ,   \\label{eq : wkb}\\ ] ] where the potential usually consists of three parts , the nuclear , the coulomb , and the centrifugal potentials , @xmath3 @xmath4 and @xmath5 are the inner and outer turning points determined by the relation @xmath6 .    by approximating @xmath7 to a parabola with the height @xmath8 and the width @xmath9 , eq . \n ( [ eq : wkb ] ) is reduced as @xmath10 ,   \\label{eq : hw}\\ ] ] which has been widely used in the study of heavy ion reactions .    because of the long - range coulomb interaction , the coulomb barrier given in eq . \n ( [ eq : potential ] ) has a long tail and is asymmetric . \n thus for the penetration well below the barrier , the parabolic approximation is not valid . \n we may divide the potential barrier into two parts at the barrier position @xmath11 . \n ...
#   'role': 'user'},
#  {'content': '**Abstract**\n\nQuantum tunneling through potential barriers is a fundamental phenomenon in nuclear physics, particularly in processes such as alpha decay. While the parabolic approximation has long been used to calculate barrier penetrability, it fails at low energies—much below the Coulomb barrier—due to the long-range nature of the Coulomb interaction. In this work, we derive a new analytical formula for barrier penetrability based on the WKB approximation that properly accounts for the Coulomb tail in the potential. By dividing the potential into inner and outer regions and applying a Woods-Saxon form to the nuclear part, we obtain a closed-form expression that accurately describes the penetration probability at energies well below the barrier. We apply this formula to calculate alpha decay half-lives for 344 nuclei using realistic nuclear and Coulomb potentials. For spherical and even-even nuclei, our results show excellent agreement with experimental data, with a root-mean-square deviation of 0.34. The new formula reproduces the WKB results well and significantly improves upon the parabolic approximation in the low-energy regime. It is especially useful for systems where energy-dependent potentials or barrier distributions are involved, offering a practical analytical tool for studying sub-barrier tunneling phenomena.',
#   'role': 'assistant'}]

# %%
result, evaluation_prompt = evaluate_summary(conv, model="gpt-5")
print(f"Judgment: {result['judgment']}")
print(f"\nExplanation:\n{result['explanation']}")

# %%
# Batch evaluation for the first 10 conversations

base_results, base_errors = evaluate_summaries_batch(
    # base_qwen3_4b_test_conversations_eval[:10],
    base_qwen3_4b_test_conversations_eval,
    model="gpt-5",
    temperature=1.0,
    max_workers=1000,  # Adjust based on your API rate limits
    show_progress=True
)

# Display results
print("\n" + "="*80)
print("BATCH EVALUATION RESULTS")
print("="*80)

for idx, result, prompt in base_results:
    print(f"\nConversation {idx}:")
    print(f"  Judgment: {result['judgment']}")
    # Optionally show a snippet of the explanation
    explanation_preview = result['explanation'][:200] + "..." if len(result['explanation']) > 200 else result['explanation']
    print(f"  Explanation preview: {explanation_preview}")

if base_errors:
    print(f"\nErrors encountered: {len(base_errors)}")
    for idx, error in base_errors:
        print(f"  Conversation {idx}: {error}")

# Summary statistics
judgments = [result['judgment'] for _, result, _ in base_results]
yes_count = judgments.count('Yes')
no_count = judgments.count('No')
unknown_count = judgments.count('Unknown')

print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Total evaluated: {len(base_results)}")
print(f"Yes: {yes_count} ({yes_count/len(base_results)*100:.1f}%)")
print(f"No: {no_count} ({no_count/len(base_results)*100:.1f}%)")
print(f"Unknown: {unknown_count} ({unknown_count/len(base_results)*100:.1f}%)")
# Out:
# Evaluating 1000 conversations with 1000 workers...
#   Completed 1/1000
#   Completed 2/1000
#   Completed 3/1000
#   Completed 4/1000
#   Completed 5/1000
#   Completed 6/1000
#   Completed 7/1000
#   Completed 8/1000
#   Completed 9/1000
#   Completed 10/1000
#   Completed 11/1000
#   Completed 12/1000
#   Completed 13/1000
#   Completed 14/1000
#   Completed 15/1000
#   Completed 16/1000
#   Completed 17/1000
#   Completed 18/1000
#   Completed 19/1000
#   Completed 20/1000
#   Completed 21/1000
#   Completed 22/1000
#   Completed 23/1000
#   Completed 24/1000
#   Completed 25/1000
#   Completed 26/1000
#   Completed 27/1000
#   Completed 28/1000
#   Completed 29/1000
#   Completed 30/1000
#   Completed 31/1000
#   Completed 32/1000
#   Completed 33/1000
#   Completed 34/1000
#   Completed 35/1000
#   Completed 36/1000
#   Completed 37/1000
#   Completed 38/1000
#   Completed 39/1000
#   Completed 40/1000
#   Completed 41/1000
#   Completed 883/1000
#   Completed 884/1000
#   Completed 885/1000
#   Completed 886/1000
#   Completed 887/1000
#   Completed 888/1000
#   Completed 889/1000
#   Completed 890/1000
#   Completed 891/1000
#   Completed 892/1000
#   Completed 893/1000
#   Completed 894/1000
#   Completed 895/1000
#   Completed 896/1000
#   Completed 897/1000
#   Completed 898/1000
#   Completed 899/1000
#   Completed 900/1000
#   Completed 901/1000
#   Completed 902/1000
#   Completed 903/1000
#   Completed 904/1000
#   Completed 905/1000
#   Completed 906/1000
#   Completed 907/1000
#   Completed 908/1000
#   Completed 909/1000
#   Completed 910/1000
#   Completed 911/1000
#   Completed 912/1000
#   Completed 913/1000
#   Completed 914/1000
#   Completed 915/1000
#   Completed 916/1000
#   Completed 917/1000
#   Completed 918/1000
#   Completed 919/1000
#   Completed 920/1000
#   Completed 921/1000
#   Completed 922/1000
#   Completed 923/1000
#   Completed 924/1000
#   Completed 925/1000
#   Completed 926/1000
#   Completed 927/1000
#   Completed 928/1000
#   Completed 929/1000
#   Completed 930/1000
#   Completed 931/1000
#   Completed 932/1000
#   Completed 933/1000
#   Completed 934/1000
#   Completed 935/1000
#   Completed 936/1000
#   Completed 937/1000
#   Completed 938/1000
#   Completed 939/1000
#   Completed 940/1000
#   Completed 941/1000
#   Completed 942/1000
#   Completed 943/1000
#   Completed 944/1000
#   Completed 945/1000
#   Completed 946/1000
#   Completed 947/1000
#   Completed 948/1000
#   Completed 949/1000
#   Completed 950/1000
#   Completed 951/1000
#   Completed 952/1000
#   Completed 953/1000
#   Completed 954/1000
#   Completed 955/1000
#   Completed 956/1000
#   Completed 957/1000
#   Completed 958/1000
#   Completed 959/1000
#   Completed 960/1000
#   Completed 961/1000
#   Completed 962/1000
#   Completed 963/1000
#   Completed 964/1000
#   Completed 965/1000
#   Completed 966/1000
#   Completed 967/1000
#   Completed 968/1000
#   Completed 969/1000
#   Completed 970/1000
#   Completed 971/1000
#   Completed 972/1000
#   Completed 973/1000
#   Completed 974/1000
#   Completed 975/1000
#   Completed 976/1000
#   Completed 977/1000
#   Completed 978/1000
#   Completed 979/1000
#   Completed 980/1000
#   Completed 981/1000
#   Completed 982/1000
#   Completed 983/1000
#   Completed 984/1000
#   Completed 985/1000
#   Completed 986/1000
#   Completed 987/1000
#   Completed 988/1000
#   Completed 989/1000
#   Completed 990/1000
#   Completed 991/1000
#   Completed 992/1000
#   Completed 993/1000
#   Completed 994/1000
#   Completed 995/1000
#   Completed 996/1000
#   Completed 997/1000
#   Completed 998/1000
#   Completed 999/1000
#   Completed 1000/1000
#
# ✓ Completed: 1000 successful, 0 errors
#
# ================================================================================
# BATCH EVALUATION RESULTS
# ================================================================================
#
# Conversation 0:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: it presents a new WKB-based analytical penetration formula that accounts for the long-range Coulomb tail, describes dividi...
#
# Conversation 1:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100): The summary accurately describes the problem setting (efficient HMC integrators), the methods compared (leap-frog, force-gradient, nested/multirate, and an adapted nested force-...
#
# Conversation 2:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly identifies two methods: (1) algebraic relations between products of propagators (using linear dependence amon...
#
# Conversation 3:
#   Judgment: Yes
#   Explanation preview: Faithfulness (84/100):
# - Strengths: The summary accurately describes the paper’s goal (mitigating sensitivity loss in blind searches for continuous gravitational waves), the proposed frequency Hough a...
#
# Conversation 4:
#   Judgment: No
#   Explanation preview: Faithfulness (52/100):
# - The summary introduces specific numerical claims that are not supported by the provided text. The paper uses placeholders (@xmath) for key mass values, but the summary states ...
#
# Conversation 5:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately captures the paper’s core topics: SSAs in dijet azimuthal correlations at RHIC, the role of TMDs and the Sivers effect, process dependence du...
#
# Conversation 6:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains notable inaccuracies and misattributions relative to the paper. It claims large deviation results for the time to the most recent common ancestor (MRCA), ...
#
# Conversation 7:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly identifies the paper’s goal (quantifying four-particle entanglement via the von Neumann entropy of a reduced three-particle subsystem), the ph...
#
# Conversation 8:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary largely aligns with the paper’s scope: PBH constraints on inflation, breakdown of the Stewart–Lyth formula near the end of inflation, use of a modified flow analys...
#
# Conversation 9:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 85
# - Strengths: Accurately identifies FMI’s purpose, the dual planning/execution architecture, wind/drift constraints, need to consider entire flight series, external constraints...
#
# Conversation 10:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains factual inaccuracies. It calls the D configuration a “two-level” system, whereas the paper clearly treats the D configuration as a three-level system (gro...
#
# Conversation 11:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a significant inaccuracy: it claims “an upper bound of about 90 GeV on the light top squark mass,” whereas the paper sets an upper bound of about 180 GeV ...
#
# Conversation 12:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly describes the problem setting (integer multiplication), cites relevant algorithms (Karatsuba, Toom-Cook, Schönhage–Strassen, Fürer), notes hig...
#
# Conversation 13:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported and likely incorrect specifics: it claims the differential flux falls as E^-2 and that the spectrum is nearly featureless from 10^15 to 10^1...
#
# Conversation 14:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately explains microlensing, caustic-induced anomalies, sensitivity to low-mass planets (including terrestrial masses), and emphasizes that no clea...
#
# Conversation 15:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately states the paper’s goal (estimating the Milky Way circular velocity at the Sun’s radius), the dataset (18 masers with 6D phase-space data), the modeling...
#
# Conversation 16:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple factual inaccuracies:
#   - It claims the measured channel is d + p → d + π+ + π−, whereas the paper studies the isoscalar double-pionic fusion pn ...
#
# Conversation 17:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary accurately conveys the paper’s core ideas: the limitations of linear wave functions for strong correlation, the role of stenciling, the nonlocality of H...
#
# Conversation 18:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains two key inaccuracies. It claims the simulations “reproduce the observed metallicity distribution,” whereas the paper repeatedly states the simulated distr...
#
# Conversation 19:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on semi-infinite non-Hermitian systems without PT symmetry, the dynamic balance between a non-Hermitian cluster and a semi-in...
#
# Conversation 20:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s aim (deriving the VFT law), method (quantum mechanical transition-rate arguments using activation entropy), and core modeling (clos...
#
# Conversation 21:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s core content: a rank-three tensor model reinterpreted as dynamical commutative, nonassociative fuzzy spaces; Gaussian classical bac...
#
# Conversation 22:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately captures the paper’s motivation (cosmological constant and coincidence problems), the proposed mechanism (decaying dark matter producing a sc...
#
# Conversation 23:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 55)
# - The summary introduces “X(5568)” as an input resonance for fitting the LECs and as a partner state. The paper text does not mention X(5568); rather, it indicates that the re...
#
# Conversation 24:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic and contributions: using classical interference to realize truncated Fourier, Gauss, Kummer, and exponential sums for factori...
#
# Conversation 25:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s setting (universal PAC learning over total recursive concepts and partial recursive hypotheses), the existence of a computable lear...
#
# Conversation 26:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s content: first detection of [C i] emission from a protoplanetary disk (DM Tau), observations toward DM Tau, LKCa 15, TW Hya, and tw...
#
# Conversation 27:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported and likely incorrect specifics. It states ZZ Ceti stars have effective temperatures of ~5000–7000 K and pulsation periods of ~100–1000 s; th...
#
# Conversation 28:
#   Judgment: Yes
#   Explanation preview: Faithfulness (87/100):
# - Strengths: The summary accurately reflects the paper’s aims (constraining the substellar IMF via star-to–brown-dwarf ratios across nearby clusters), methods (compiling extinct...
#
# Conversation 29:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on curvature effects (linear chain vs. bent ring) in Rashba SO-coupled, multi-terminal systems using a tight-binding and Gree...
#
# Conversation 30:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on a qubit undergoing pure dephasing via coupling to a thermal bosonic bath, the use of a partial p-representation to obtain ...
#
# Conversation 31:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary misrepresents key quantitative results by changing units. The paper’s measurements are in physical units (e.g., nanometers), with 1 wavelength ≈ 650 nm on th...
#
# Conversation 32:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary generally captures the paper’s themes: pulse-wise GRB correlations, an empirical pulse model (Band+Norris+LK96) implemented in XSPEC, evidence for a two...
#
# Conversation 33:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content: it states the unified derivation of MFDRs at NESS using the Agarwal formalism; covers both Langevin and discrete master eq...
#
# Conversation 34:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly identifies the paper’s goal (study of chiral symmetry restoration at finite temperature), the method (composite operator formalism with an eff...
#
# Conversation 35:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s goals, setup, and main findings: linking zero-frequency current noise to Coulomb correlations and entanglement in a double quantum ...
#
# Conversation 36:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic, object of study (the Nessie IRDC), observational approach (MOPRA millimeter molecular line mapping), main observational find...
#
# Conversation 37:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces incorrect claims. It states that the paper finds “new FQHE states at ν = 1/3 and ν = 2/5 … absent in GaAs,” but the paper explicitly notes that in the n...
#
# Conversation 38:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - The summary correctly states that the paper studies molecular motor transport via lattice and continuum models, and that unbinding enhances longitudinal diffusion while reduci...
#
# Conversation 39:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s goals, methodology, and key findings: improving PVDF modeling using the halo approach, deriving velocity distributions via Abel inv...
#
# Conversation 40:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 88/100):
# - The summary accurately describes the paper’s main constructions: Maxwell solutions in the Einstein universe aligned with Hopf fibration fibres; their conformal interpre...
#
# Conversation 41:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: a thermomechanical Ginzburg–Landau model for SMAs that couples an order parameter, strain, and temperature, includes a heat ...
#
# Conversation 42:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - Strengths: The summary accurately captures the core claims: (i) the Isham–Storey solution (with the Isham–Salam–Strathdee-type potential) does not yield a regular black hole e...
#
# Conversation 43:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 58/100)
# - The summary contains at least one significant factual error: it states that the mass-loss rate inferred from Hγ emission is overestimated by a factor of ~200, whereas th...
#
# Conversation 44:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 86/100):
# - The summary accurately captures the paper’s focus on using present-day kinematics and spatial distributions to constrain the formation of multiple populations in globul...
#
# Conversation 45:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately conveys the core ideas: singular Laplacian growth as “maximally nonunique,” the notion of “fragility” via singularity splitting, the role of ...
#
# Conversation 46:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45)
# - The summary introduces specific numerical values that are not present in the provided text and are likely incorrect or fabricated:
#   - Energy threshold is stated as > 10^18 ...
#
# Conversation 47:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - Major error: The summary repeatedly states the work is in “four-dimensional N=0 supersymmetry,” which is incorrect. The paper clearly concerns N=2 supersymmetry in four dimens...
#
# Conversation 48:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and contributions: initial focus on two-sample GOF tests, iterative development driven by experimental use cases (notably Gea...
#
# Conversation 49:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on coherent backscattering (CBS) from two harmonically trapped atoms and how atomic motion (recoil and Doppler effects) affec...
#
# Conversation 50:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and unsupported specifics:
#   - It states a 25 μm pixel size, which is not given in the paper; the paper references a specific hybrid ...
#
# Conversation 51:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains at least one incorrect claim: it states that the block entanglement entropy “diverges,” whereas the paper reports that it attains a maximum at the pseudo-...
#
# Conversation 52:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the three-part structure of the paper: low-energy two-nucleon EFT and its relation to realistic potentials, the chiral bag/Cheshire Cat perspec...
#
# Conversation 53:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly describes the topic (supra-arcade downflows as indirect evidence of magnetic reconnection), the instruments used (AIA/SDO and STEREO), the use...
#
# Conversation 54:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 60)
# - Strengths: Most statements align with the paper, including the emphasis on elliptic flow consistent with ideal hydrodynamics, constituent quark scaling, the observation of r...
#
# Conversation 55:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and introduces ratios not supported by the paper. The paper discusses p/π and K/π ratios (pT-dependent and integrated), but the summa...
#
# Conversation 56:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reports the key finding: two quiescent filament eruptions rotated counterclockwise despite right-handed post-eruption arcades. It correctly notes the si...
#
# Conversation 57:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly identifies the study’s scope (TPP on SWCNTs and graphene), methods (vdW-DF with SIESTA), number of CNT species (42), key qualitative findings ...
#
# Conversation 58:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope, methods, and findings: a 30-month global coronal simulation using a coupled flux-transport/magnetofrictional model; emergenc...
#
# Conversation 59:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on SMQC without nonlocal measurements, the reduction to secure two-party computation of nl-CNOT, and the reduction of secure ...
#
# Conversation 60:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# - The summary accurately reflects the paper’s focus on the single-site entanglement entropy at the Mott transition in the half-filled Hubbard model in infinite dimensions.
# - It ...
#
# Conversation 61:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary introduces specific galaxy names (NGC 5194 and NGC 5195) that are not given in the paper; the mention of M51 in the paper refers to prior work, not the targets in ...
#
# Conversation 62:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - Strengths: The summary accurately reflects the paper’s topic (non-ergodicity in Coulomb glass), methodology (three-stage construction of low-energy states using local search, ...
#
# Conversation 63:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core contributions: introducing an environmental payoff threshold to spatial PD with unconditional strategies, exploring two update...
#
# Conversation 64:
#   Judgment: Yes
#   Explanation preview: Faithfulness (87/100):
# - The summary accurately reflects the paper’s core ideas: deriving the Wilson-line geometry for integrated and TMD PDFs and the soft factor directly from QCD via gauge rotations...
#
# Conversation 65:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately captures the paper’s core: a simple electrostatic model for the voltage profile along molecular wires, modeled as a cylinder between planar electrodes, ...
#
# Conversation 66:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s scope: constructing new exact, spherically symmetric, static solutions to the Einstein–Maxwell equations in curvature coordinates b...
#
# Conversation 67:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary accurately captures many core elements: the study combines planet–planet and planetesimal scattering via N-body simulations, uses two ensembles (high- and low-mass...
#
# Conversation 68:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately captures the paper’s focus on determining form factors for a heavy-baryon semileptonic decay using LCSR, the use of two interpolating current...
#
# Conversation 69:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Strengths: The summary accurately reflects the paper’s focus on leveraging the SOHO/MDI–Debrecen Sunspot Data (SDD) to study sunspot group internals (polarity separation, lead...
#
# Conversation 70:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately reflects the paper’s objectives, data, and main findings: a two-epoch HST differential proper-motion analysis (7.25-year baseline), alignment...
#
# Conversation 71:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a notable inaccuracy about the phase relation of the stable continuous-wave (cw) background. The paper’s modulationally stable cw is the “pi-type,” where ...
#
# Conversation 72:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a key factual error about the Loschmidt echo. The paper states that in finite systems the nonzero bandwidth of the m-string leads to the long-time average...
#
# Conversation 73:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately reflects the core of the paper: nova decay phases governed by optically thick winds driven by an iron-line opacity peak; strong dependence of...
#
# Conversation 74:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s focus on skyrmion motion in nanowires driven by longitudinal and transverse spin waves, the use of micromagnetic simulations, and t...
#
# Conversation 75:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported or incorrect specifics. It cites electron-photon scattering as part of the relaxation-time calculation, but the paper discusses electron-ele...
#
# Conversation 76:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core arguments: parallels between massive-star nebulae and PNe; limitations of interacting-winds and merger scenarios; the case for...
#
# Conversation 77:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly captures the use of Globus (GSI, GridFTP, job submission), the two-level file catalog with a central PHENIX catalog and local Magda at SUNYSB,...
#
# Conversation 78:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains notable inaccuracies:
#   - It repeatedly refers to SrRuO3, whereas the paper is about the bilayer ruthenate Sr3Ru2O7 (Sr-327). This is a substantive ...
#
# Conversation 79:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on multi-post re-entrant cavities, modeling posts as coupled harmonic oscillators with gaps as capacitors and posts as induct...
#
# Conversation 80:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies and unsupported claims. It introduces a specific critical interaction range “~0.4 nm,” which is not given in the paper; the paper ref...
#
# Conversation 81:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several unsupported or incorrect claims relative to the paper.
#   - It describes SDSS imaging as “deep,” whereas the paper explicitly emphasizes SDSS is sh...
#
# Conversation 82:
#   Judgment: Yes
#   Explanation preview: Faithfulness (score: 90/100):
# - The summary accurately reflects the paper’s scope: comparing high-NA focused-beam illumination to plane-wave (PW) excitation for spherical metal nanoparticles using a m...
#
# Conversation 83:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately describes the paper’s core focus on delocalizing transitions in multidimensional BECs in optical lattices and the role of unstable gap-Townes solitons a...
#
# Conversation 84:
#   Judgment: No
#   Explanation preview: Faithfulness (62/100):
# - Strengths: The summary correctly identifies the paper’s focus (integrability of 1D Bose/Fermi gases with large effective range), the use of a two-channel Hamiltonian model (HT...
#
# Conversation 85:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains two notable inaccuracies. First, it describes the theory as N=1 supersymmetric, whereas the paper clearly focuses on the non-anticommutative N=1/2 supersy...
#
# Conversation 86:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s focus on replacing EpicFlow’s sparse-to-dense interpolation step with a fully convolutional network that uses edges, layer-wise sup...
#
# Conversation 87:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary incorrectly states the main quantitative result: it claims the minimal complexity for n columns is n−1. The paper’s argument (via doubling at each inductive step a...
#
# Conversation 88:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - Strengths: The summary correctly identifies the main problem (quadratic divergences/hierarchy problem), the core approach (imposing Ward–Takahashi identities and enforcing tad...
#
# Conversation 89:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies relative to the paper. It states that prior models “fail to reproduce observed velocity gradients and pillar morphologies,” but the p...
#
# Conversation 90:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s main claims: the use of time-integrated observables in closed quantum systems, the construction of a non-Hermitian deformed Hamilto...
#
# Conversation 91:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on high-frequency p-modes in neutron star envelopes, the use of a plane-parallel approximation with relativistic context, inc...
#
# Conversation 92:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains significant numerical inaccuracies not supported by the paper text. It reports an emergence rate of 2–4 × 10^-3 Mx/h, whereas the paper’s notation (“2–4@x...
#
# Conversation 93:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately captures the paper’s main contribution: a distinct, lensing-only shear–ellipticity anti-correlation arising from galaxy–galaxy lensing, even without tid...
#
# Conversation 94:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains a key inaccuracy: it describes STIRAP as a “resonance-free pathway,” whereas the paper explicitly states that adiabatic techniques require a resonance bet...
#
# Conversation 95:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a key inaccuracy: it states that “the EGT model predicts a light-speed anisotropy of amplitude twice that of the CMB dipole.” In the paper, EGT predicts t...
#
# Conversation 96:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary is largely aligned with the paper’s content (context of SNR–molecular cloud interactions, CTB 109’s thermal X-ray lobe, identification of three CO clouds, location...
#
# Conversation 97:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly states the problem (scattering properties of ground-state Mg), the use of four potentials (RKR, IPA, a prior theoretical potential, and a new ...
#
# Conversation 98:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s main points: gas inflow is driven by gravitational (bar) torques rather than viscous torques; CMC growth alone is insufficient to e...
#
# Conversation 99:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary captures most core claims accurately (two error sources; higher frame rates worsen position-uncertainty-induced velocity errors; acceleration errors shrink with hi...
#
# Conversation 100:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several unsupported or incorrect factual claims relative to the paper text.
#   - It places the dip in the tangential velocity distribution between −10 and ...
#
# Conversation 101:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains several factual inaccuracies relative to the paper:
#   - It repeatedly refers to Fe II, whereas the paper clearly focuses on the Fe VI/Fe VII ionizat...
#
# Conversation 102:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains significant inaccuracies. The paper states that models cannot reproduce the large radius of HD 209458b (the first transiting hot Jupiter), whereas the sum...
#
# ...
#
# Conversation 940:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states the problem (phase diagram of 4He on graphene), the method (large-scale QMC/worm algorithm in the gran...
#
# Conversation 941:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces incorrect or unsupported numerical claims. The paper’s best estimate for the lensing galaxy G1’s velocity dispersion is not stated explicitly in plain n...
#
# Conversation 942:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces specific FP slope values (“a ~ 1.35” and “b ~ 1.50”) that are not present in the provided text and are likely inconsistent with typical FP formulations ...
#
# Conversation 943:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary largely reflects the paper’s content but introduces a significant inaccuracy: it claims the authors “demonstrate the existence of closed timelike and null causal c...
#
# Conversation 944:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100): The summary contains several factual inaccuracies and misinterpretations. It incorrectly states the white dwarf contributes ~1.7% at 4500 Å and ~0.6% at 6500 Å; the paper report...
#
# Conversation 945:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains several inaccuracies:
#   - It states “for main-sequence stars, the 29.4-minute precision reaches below 30 ppm,” which contradicts the paper. At 29.4 ...
#
# Conversation 946:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies relative to the paper. It claims “we find a strong correlation between absorption equivalent width and disk inclination,” whereas the...
#
# Conversation 947:
#   Judgment: Yes
#   Explanation preview: Faithfulness (84/100):
# - Strengths: The summary accurately captures the paper’s central thesis (causal backreaction as an alternative to dark energy), the motivation (fine-tuning and coincidence probl...
#
# Conversation 948:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on the prevalent but ad hoc practice of combining systematic and random uncertainties in quadrature, especially the issues ar...
#
# Conversation 949:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - The summary accurately captures the paper’s focus on automated coronal loop detection using the 2D wavelet transform modulus maxima (WTMM) method, its multiscale and direction...
#
# Conversation 950:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately presents the paper’s goal (predicting the mass–Lyα forest flux correlation), the approach (HPM simulations calibrated against hydrodynamic ru...
#
# Conversation 951:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s goals, methods, and findings. It correctly critiques the simplistic incoherent sum of non-commuting error channels, introduces the ...
#
# Conversation 952:
#   Judgment: Yes
#   Explanation preview: Faithfulness (87/100):
# - The summary accurately captures the problem (electron-cloud effects in the LHC and their impacts), the lack of direct in-situ diagnostics, the proposed benchmarking approach (...
#
# Conversation 953:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains at least two factual inaccuracies. It states that interaction lists are generated at intervals of Δt = 3, misreading the paper’s symbolic interval (@xmath...
#
# Conversation 954:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately reflects the paper’s focus on inhomogeneous (striped) superconductivity in cuprates, the role of magnetic inhomogeneities that locally break ...
#
# Conversation 955:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on muon-induced spallation neutrons as a key background in underground experiments, the Aberdeen Tunnel setup (611 m.w.e.), t...
#
# Conversation 956:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and findings: Bragg spectroscopy of 1D interacting bosons, comparison with a finite-temperature Bethe-ansatz-based Lieb–Linig...
#
# Conversation 957:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a key factual error: it states that heavier nuclei like iron produce “deeper, more extended showers.” The paper explicitly shows that heavier primaries le...
#
# Conversation 958:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly identifies the problem (geometric distortion in HST/ACS), the observational approach (dithered star clusters 47 Tuc and NGC 6681), the iterati...
#
# Conversation 959:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly states the motivation (improving metallicity coverage of Padova94 SEMs for SFH studies), the core interpolation procedure (phase subdivision, ...
#
# Conversation 960:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the problem (2D viscous flow around a flapping foil, fixed vs free), method (LBM with immersed/moving boundaries), geometry (semicircle...
#
# Conversation 961:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains notable inaccuracies:
#   - It states the analysis uses MDI data “from solar cycle 21 to cycle 22,” whereas the paper uses 24 MDI data sets from May 1...
#
# Conversation 962:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 58)
# - Strengths: The summary correctly identifies the main goal (realizing a QSH state in graphene without magnetic fields), the approach (DFT with van der Waals corrections on gr...
#
# Conversation 963:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s topic, setup, and key findings: first-principles simulations of parahydrogen confined in spherical nanocavities; comparison of weak...
#
# Conversation 964:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains at least two factual inaccuracies:
#   - It groups “neutral species (e.g., Li, Be)” together. In the paper, Be is analyzed via Be II (ionized), and the repo...
#
# Conversation 965:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces unsupported specifics: “analysis of 19 days in March 2016 (from 06:00 to 18:00)” is not in the paper. The paper states it considers all days in March 20...
#
# Conversation 966:
#   Judgment: Yes
#   Explanation preview: Faithfulness (86/100):
# - The summary accurately reflects the paper’s scope and methods: thermalization in two-species ultracold gases in box and harmonic traps; use of coupled Boltzmann equations; inc...
#
# Conversation 967:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 30/100)
# - The summary introduces incorrect and unsupported facts. It labels the studied state as “f2s(1235),” which is not mentioned in the paper and is inconsistent with the cont...
#
# Conversation 968:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately captures the paper’s central themes: the debate between clustered versus hierarchical star formation; the emphasis on spatial/temporal correl...
#
# Conversation 969:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s focus on the Einstein–Vlasov system with Bianchi I symmetry, the small-data assumptions (small anisotropy and bounded momenta), and...
#
# Conversation 970:
#   Judgment: Yes
#   Explanation preview: Faithfulness (93/100):
# - The summary accurately reflects the paper’s content: it describes a BEC in a high-finesse cavity with an intracavity optical lattice, the optomechanical coupling modifying the...
#
# Conversation 971:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on modeling the decay of article page views, its analogy to physical relaxation/aging, and the use of a modified stretched ex...
#
# Conversation 972:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on sound-mediated, long-range interactions between dark solitons in inhomogeneous Bose–Einstein condensates, caused by axial ...
#
# Conversation 973:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 82
# - Strengths: The summary accurately conveys the paper’s core problem (approximating slow/attracting invariant manifolds), the on-the-fly “steady AIM” approach using vanishing ...
#
# Conversation 974:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s topic, framework, and main findings: use of the Maxwell–Weyl covariant formalism; numerical integration of Friedmann and Klein–Gord...
#
# Conversation 975:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s scope: the tension between dark-matter-only predictions and observable galaxy properties, the central role of ISM physics and sub-g...
#
# Conversation 976:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary is largely faithful to the paper’s topic, methods, and qualitative conclusions, but it introduces incorrect numerical values by misreading placeholders. Specifical...
#
# Conversation 977:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s core ideas: a metric-independent definition of conformal invariance via measure line bundles and invariance under changes of the co...
#
# Conversation 978:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several factual inaccuracies. The paper studies the B_c meson (a bound state of b and c quarks), not the Xi_cb baryon/meson as stated.
# - It incorrectly cl...
#
# Conversation 979:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Strengths: The summary accurately captures the paper’s scope (2D Fermi superfluids across the BCS–BEC crossover), the use of beyond-mean-field Gaussian fluctuations with zero-...
#
# Conversation 980:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the paper’s goals and approach: expressing anomalous Hall conductivity in terms of local atomic-like orbitals, showing equivalence to B...
#
# Conversation 981:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary introduces unsupported and likely incorrect numerical claims:
#   - It states that observed GeV photons imply a minimal upstream magnetic field of ~100–200 G. ...
#
# Conversation 982:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary accurately states the study uses 21 cm HI absorption toward ~25 directions selected based on prior Ca II/Na I absorption, uses the VLA with 44″ and 4″ beams, targe...
#
# Conversation 983:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on attribute reduction via a dependence space induced by matroids and the use of closure operators to define a congruence rel...
#
# Conversation 984:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s focus: testing the Compton downscattering model for broad iron Kα lines against observational constraints in MCG–6-30-15 and NGC 35...
#
# Conversation 985:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that cat3d-wind combines a geometrically thin dusty disk with a hollow polar outflow launched near the...
#
# Conversation 986:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a key inversion of the paper’s stated causal relationship: the paper says that k_T-factorization for DIS emerges as a consequence of rapidity factorizatio...
#
# Conversation 987:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary correctly identifies the problem (measuring electron effective mass vs. QW width in CdTe/(Cd,Mn)Te), the method (ODCR/ODR), the sample structure (four wells of 30,...
#
# Conversation 988:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces inaccuracies by conflating different results. It states a predicted impact probability of 0.33% with the “highest Palermo Scale value,” which reflects e...
#
# Conversation 989:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: indirect study of ultra-high-energy cosmic rays via air showers, the dependence on hadronic interaction models, and the know...
#
# Conversation 990:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately captures the paper’s main contributions: extending spectrogram-based ship wake analysis to finite-depth channels, modeling a ship as a Gaussian pressure...
#
# Conversation 991:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately reflects the paper’s topic (predicting 2016 U.S. election outcomes from Twitter), data collection (371,264 tweets from Dec 16, 2015–Feb 29, 2...
#
# Conversation 992:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly identifies the problem (2D Turing patterns in a boundary-fed CDIMA system), the realistic LRE model, use of a pseudospectral method with paral...
#
# Conversation 993:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s scope and methods: a numerical study of hypothetical Uranus Trojans in the outer solar system, using Newtonian N-body integrations ...
#
# Conversation 994:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains a significant inaccuracy: it claims agreement with experimental measurements of the χc1 and χc2 mesons, which are charmonium (heavy-heavy) states. The pap...
#
# Conversation 995:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately captures the paper’s core setting and contributions: modeling base stations with a PPP, analyzing worst-case users at Voronoi vertices under ...
#
# Conversation 996:
#   Judgment: Yes
#   Explanation preview: Faithfulness (94/100):
# - The summary accurately reflects the paper’s goals, methods, and findings. It correctly states the debate (PMS vs. ZAMS), the use of Hipparcos parallaxes to derive distances an...
#
# Conversation 997:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - Accurate: The summary correctly identifies the object (XRF 030723), the suspected SN Ic association due to an optical bump, the modeling framework (LTE radiation hydrodynamics...
#
# Conversation 998:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s goal (testing adiabatic matter creation as a driver of cosmic acceleration), the datasets used (186 SNe Ia, H(z) from differential ...
#
# Conversation 999:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100): The summary closely reflects the paper’s content: it introduces the ISIPP scenario driven by the running coupling, explains the decreasing momentum transfer leading to stronger ...
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total evaluated: 1000
# Yes: 497 (49.7%)
# No: 503 (50.3%)
# Unknown: 0 (0.0%)

# %%
# Save results to JSONL file
import json

# Create filename with baseline_eval in it
output_filename = f"/Users/ryanarman/code/lab/arxiv_abstract/data/baseline_eval_qwen3_4b_test.jsonl"

# Write results to JSONL file
with open(output_filename, 'w', encoding='utf-8') as f:
    for idx, result, prompt in results:
        output_data = {
            'index': idx,
            'judgment': result['judgment'],
            'explanation': result['explanation'],
            'evaluation_prompt': prompt
        }
        f.write(json.dumps(output_data, ensure_ascii=False) + '\n')

print(f"Saved {len(results)} results to {output_filename}")
# Out:
# Saved 1000 results to /Users/ryanarman/code/lab/arxiv_abstract/data/baseline_eval_qwen3_4b_test.jsonl

# %% [markdown]
# score of basemodel: 49.7%

# %% [markdown]
# # Training

# %% [markdown]
# train_instruct_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_instruct.jsonl"
# val_instruct_path =   "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_val_instruct.jsonl"
#
# ./submit_training_rsync.sh \
#   data/arxiv_summarization_train_instruct.jsonl \
#   data/arxiv_summarization_val_instruct.jsonl \
#   configs/qwen4b_train_lora.yaml \
#   my_custom_output_name \
#   ryan@exun \
#   arxiv-abstract-qwen3-4b \
#   my-team
#
# # Trained on gpt-5 distilled on 1k train, 1k validation
#    /home/ryan/code/oumi/lab/arxiv_abstract/output/arxiv_abstract_qwen3_4b_gpt5_lora_2807

# %%
gen_train_path = "/Users/ryanarman/code/lab/arxiv_abstract/data/arxiv_summarization_train_instruct_article_gpt5.jsonl"


cd /Users/ryanarman/code/lab/arxiv_abstract/scripts
./submit_training_rsync.sh

# %% [markdown]
# #Eval trained model

# %%
cd /Users/ryanarman/code/lab/arxiv_abstract/scripts

./submit_inference_rsync.sh \
  data/arxiv_summarization_test_instruct.jsonl \
  configs/4b_instruct_vllm_infer_checkpoint.yaml \
  fine_tuned_results \
  output/arxiv_abstract_qwen3_4b_lora_2800


./submit_inference_rsync.sh \
  data/arxiv_summarization_test_instruct.jsonl \
  configs/4b_instruct_vllm_infer_checkpoint.yaml \
  fine_tuned_gpt5_distilled_results \
  output/arxiv_abstract_qwen3_4b_gpt5_lora_2808

  ./submit_inference_rsync.sh \
  data/arxiv_summarization_test_instruct.jsonl \
  configs/4b_instruct_vllm_infer_checkpoint.yaml \
  fine_tuned_gpt5_distilled_article_results \
  output/arxiv_abstract_qwen3_4b_gpt5_article_lora_fixed_2820

./submit_inference_rsync.sh \
  data/arxiv_summarization_test_instruct.jsonl \
  configs/4b_instruct_vllm_infer_checkpoint.yaml \
  fine_tuned_gpt5_distilled_article_results_v2 \
  arxiv_abstract_qwen3_4b_gpt5_article_lora_fixed_v2_2826

  ./submit_inference_rsync.sh ... output/arxiv_abstract_qwen3_4b_gpt5_article_lora_fixed_v2_2826/checkpoint-400

# %% [markdown]
# # Run judge

# %%
# tuned_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_results_2801.jsonl"
# tuned_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_gpt5_distilled_results_2809.jsonl"
# tuned_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_gpt5_distilled_article_results_2821.jsonl"
tuned_qwen3_4b_test_path =  "/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_gpt5_distilled_article_results_v2_2829.jsonl"
tuned_qwen3_4b_test_conversations = load_conversations(tuned_qwen3_4b_test_path)

# %%
display_message(tuned_qwen3_4b_test_conversations[5], role='assistant')
# Out:
# ================================================================================
# Role: ASSISTANT
# Characters: 1,213 | Words: 181 | Lines: 1
# ================================================================================
# <pre style="white-space: pre-wrap; word-wrap: break-word; font-family: monospace; background-color: #f5f5f5; color: #000000; padding: 10px; border-radius: 5px; line-height: 1.5;">Single-transverse-spin asymmetries (SSAs) in dijet correlations at RHIC are
# considered, making use of the recent computation of the process-dependent
# strangeness and non-strangeness trace contributions to the correlators. We find
# the accurate results at the full partonal level in the collinear-regime for dual
# spin dependence. We explicitly compare our findings with original proposals,
# taking into account new data-derived sivers functions for single-spin
# asymmetries, and some values from the literature. In addition, we analyze a
# related asymmetry which can currently be measured, and we find that the sign and
# magnitude in this case are close to those for the full weight. Both predictions
# are derived based on known particle physics principles, using the life-cycle of
# independent particle states, complete in the light-cone longitudinal frame, and
# accounts the dependence on transverse momentum of certain spin-dependent
# functions in the final state and initial state kinematic inversions. The results
# show the importance of the appropriate mass spectrum of state final states, and
# point to a range of new corrections to the hard scattering functional form in
# the t-D that up to now have not been explored.</pre>

# %%
fine_tuned_results, fine_tuned_errors = evaluate_summaries_batch(
    tuned_qwen3_4b_test_conversations,
    model="gpt-5",
    temperature=1.0,
    max_workers=1000,  # Adjust based on your API rate limits
    show_progress=True
)

# Display results
print("\n" + "="*80)
print("BATCH EVALUATION RESULTS")
print("="*80)

for idx, result, prompt in fine_tuned_results:
    print(f"\nConversation {idx}:")
    print(f"  Judgment: {result['judgment']}")
    # Optionally show a snippet of the explanation
    explanation_preview = result['explanation'][:200] + "..." if len(result['explanation']) > 200 else result['explanation']
    print(f"  Explanation preview: {explanation_preview}")

if fine_tuned_errors:
    print(f"\nErrors encountered: {len(fine_tuned_errors)}")
    for idx, error in fine_tuned_errors:
        print(f"  Conversation {idx}: {error}")

# Summary statistics
judgments = [result['judgment'] for _, result, _ in fine_tuned_results]
yes_count = judgments.count('Yes')
no_count = judgments.count('No')
unknown_count = judgments.count('Unknown')

print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Total evaluated: {len(fine_tuned_results)}")
print(f"Yes: {yes_count} ({yes_count/len(fine_tuned_results)*100:.1f}%)")
print(f"No: {no_count} ({no_count/len(fine_tuned_results)*100:.1f}%)")
print(f"Unknown: {unknown_count} ({unknown_count/len(fine_tuned_results)*100:.1f}%)")
# Out:
# Evaluating 1000 conversations with 1000 workers...
#   Completed 1/1000
#   Completed 2/1000
#   Completed 3/1000
#   Completed 4/1000
#   Completed 5/1000
#   Completed 6/1000
#   Completed 7/1000
#   Completed 8/1000
#   Completed 9/1000
#   Completed 10/1000
#   Completed 11/1000
#   Completed 12/1000
#   Completed 13/1000
#   Completed 14/1000
#   Completed 15/1000
#   Completed 16/1000
#   Completed 17/1000
#   Completed 18/1000
#   Completed 19/1000
#   Completed 20/1000
#   Completed 21/1000
#   Completed 22/1000
#   Completed 23/1000
#   Completed 24/1000
#   Completed 25/1000
#   Completed 26/1000
#   Completed 27/1000
#   Completed 28/1000
#   Completed 29/1000
#   Completed 30/1000
#   Completed 31/1000
#   Completed 32/1000
#   Completed 33/1000
#   Completed 34/1000
#   Completed 35/1000
#   Completed 36/1000
#   Completed 37/1000
#   Completed 38/1000
#   Completed 39/1000
#   Completed 40/1000
#   Completed 41/1000
#   Completed 42/1000
#   Completed 43/1000
#   Completed 44/1000
#   Completed 45/1000
#   Completed 46/1000
#   Completed 47/1000
#   Completed 48/1000
#   Completed 49/1000
#   Completed 50/1000
#   Completed 51/1000
#   Completed 52/1000
#   Completed 53/1000
#   Completed 54/1000
#   Completed 55/1000
#   Completed 56/1000
#   Completed 57/1000
#   Completed 58/1000
#   Completed 59/1000
#   Completed 60/1000
#   Completed 61/1000
#   Completed 62/1000
#   Completed 63/1000
#   Completed 64/1000
#   Completed 65/1000
#   Completed 66/1000
#   Completed 67/1000
#   Completed 68/1000
#   Completed 69/1000
#   Completed 70/1000
#   Completed 71/1000
#   Completed 72/1000
#   Completed 73/1000
#   Completed 74/1000
#   Completed 75/1000
#   Completed 76/1000
#   Completed 77/1000
#   Completed 78/1000
#   Completed 79/1000
#   Completed 80/1000
#   Completed 81/1000
#   Completed 82/1000
#   Completed 83/1000
#   Completed 84/1000
#   Completed 85/1000
#   Completed 86/1000
#   Completed 87/1000
#   Completed 88/1000
#   Completed 89/1000
#   Completed 90/1000
#   Completed 91/1000
#   Completed 92/1000
#   Completed 93/1000
#   Completed 94/1000
#   Completed 95/1000
#   Completed 96/1000
#   Completed 97/1000
#   Completed 98/1000
#   Completed 99/1000
#   Completed 100/1000
#   Completed 101/1000
#   Completed 102/1000
#   Completed 103/1000
#   Completed 104/1000
#   Completed 105/1000
#   Completed 106/1000
#   Completed 107/1000
#   Completed 108/1000
#   Completed 109/1000
#   Completed 110/1000
#   Completed 111/1000
#   Completed 112/1000
#   Completed 113/1000
#   Completed 114/1000
#   Completed 115/1000
#   Completed 116/1000
#   Completed 117/1000
#   Completed 118/1000
#   Completed 119/1000
#   Completed 120/1000
#   Completed 121/1000
#   Completed 122/1000
#   Completed 123/1000
#   Completed 124/1000
#   Completed 125/1000
#   Completed 126/1000
#   Completed 127/1000
#   Completed 128/1000
#   Completed 129/1000
#   Completed 130/1000
#   Completed 131/1000
#   Completed 132/1000
#   Completed 133/1000
#   Completed 134/1000
#   Completed 135/1000
#   Completed 136/1000
#   Completed 137/1000
#   Completed 558/1000
#   Completed 559/1000
#   Completed 560/1000
#   Completed 561/1000
#   Completed 562/1000
#   Completed 563/1000
#   Completed 564/1000
#   Completed 565/1000
#   Completed 566/1000
#   Completed 567/1000
#   Completed 568/1000
#   Completed 569/1000
#   Completed 570/1000
#   Completed 571/1000
#   Completed 572/1000
#   Completed 573/1000
#   Completed 574/1000
#   Completed 575/1000
#   Completed 576/1000
#   Completed 577/1000
#   Completed 578/1000
#   Completed 579/1000
#   Completed 580/1000
#   Completed 581/1000
#   Completed 582/1000
#   Completed 583/1000
#   Completed 584/1000
#   Completed 585/1000
#   Completed 586/1000
#   Completed 587/1000
#   Completed 588/1000
#   Completed 589/1000
#   Completed 590/1000
#   Completed 591/1000
#   Completed 592/1000
#   Completed 593/1000
#   Completed 594/1000
#   Completed 595/1000
#   Completed 596/1000
#   Completed 597/1000
#   Completed 598/1000
#   Completed 599/1000
#   Completed 600/1000
#   Completed 601/1000
#   Completed 602/1000
#   Completed 603/1000
#   Completed 604/1000
#   Completed 605/1000
#   Completed 606/1000
#   Completed 607/1000
#   Completed 608/1000
#   Completed 609/1000
#   Completed 610/1000
#   Completed 611/1000
#   Completed 612/1000
#   Completed 613/1000
#   Completed 614/1000
#   Completed 615/1000
#   Completed 616/1000
#   Completed 617/1000
#   Completed 618/1000
#   Completed 619/1000
#   Completed 620/1000
#   Completed 621/1000
#   Completed 622/1000
#   Completed 623/1000
#   Completed 624/1000
#   Completed 625/1000
#   Completed 626/1000
#   Completed 627/1000
#   Completed 628/1000
#   Completed 629/1000
#   Completed 630/1000
#   Completed 631/1000
#   Completed 632/1000
#   Completed 633/1000
#   Completed 634/1000
#   Completed 635/1000
#   Completed 636/1000
#   Completed 637/1000
#   Completed 638/1000
#   Completed 639/1000
#   Completed 640/1000
#   Completed 641/1000
#   Completed 642/1000
#   Completed 643/1000
#   Completed 644/1000
#   Completed 645/1000
#   Completed 646/1000
#   Completed 647/1000
#   Completed 648/1000
#   Completed 649/1000
#   Completed 650/1000
#   Completed 651/1000
#   Completed 652/1000
#   Completed 653/1000
#   Completed 654/1000
#   Completed 655/1000
#   Completed 656/1000
#   Completed 657/1000
#   Completed 658/1000
#   Completed 659/1000
#   Completed 660/1000
#   Completed 661/1000
#   Completed 662/1000
#   Completed 663/1000
#   Completed 664/1000
#   Completed 665/1000
#   Completed 666/1000
#   Completed 667/1000
#   Completed 668/1000
#   Completed 669/1000
#   Completed 670/1000
#   Completed 671/1000
#   Completed 672/1000
#   Completed 673/1000
#   Completed 674/1000
#   Completed 675/1000
#   Completed 676/1000
#   Completed 677/1000
#   Completed 678/1000
#   Completed 679/1000
#   Completed 680/1000
#   Completed 681/1000
#   Completed 682/1000
#   Completed 683/1000
#   Completed 684/1000
#   Completed 685/1000
#   Completed 686/1000
#   Completed 687/1000
#   Completed 688/1000
#   Completed 689/1000
#   Completed 690/1000
#   Completed 691/1000
#   Completed 692/1000
#   Completed 693/1000
#   Completed 694/1000
#   Completed 695/1000
#   Completed 696/1000
#   Completed 697/1000
#   Completed 698/1000
#   Completed 699/1000
#   Completed 700/1000
#   Completed 701/1000
#   Completed 702/1000
#   Completed 703/1000
#   Completed 704/1000
#   Completed 705/1000
#   Completed 706/1000
#   Completed 707/1000
#   Completed 708/1000
#   Completed 709/1000
#   Completed 710/1000
#   Completed 711/1000
#   Completed 712/1000
#   Completed 713/1000
#   Completed 714/1000
#   Completed 715/1000
#   Completed 716/1000
#   Completed 717/1000
#   Completed 718/1000
#   Completed 719/1000
#   Completed 720/1000
#   Completed 721/1000
#   Completed 722/1000
#   Completed 723/1000
#   Completed 724/1000
#   Completed 725/1000
#   Completed 726/1000
#   Completed 727/1000
#   Completed 728/1000
#   Completed 729/1000
#   Completed 730/1000
#   Completed 731/1000
#   Completed 732/1000
#   Completed 733/1000
#   Completed 734/1000
#   Completed 735/1000
#   Completed 736/1000
#   Completed 737/1000
#   Completed 738/1000
#   Completed 739/1000
#   Completed 740/1000
#   Completed 741/1000
#   Completed 742/1000
#   Completed 743/1000
#   Completed 744/1000
#   Completed 745/1000
#   Completed 746/1000
#   Completed 747/1000
#   Completed 748/1000
#   Completed 749/1000
#   Completed 750/1000
#   Completed 751/1000
#   Completed 752/1000
#   Completed 753/1000
#   Completed 754/1000
#   Completed 755/1000
#   Completed 756/1000
#   Completed 757/1000
#   Completed 758/1000
#   Completed 759/1000
#   Completed 760/1000
#   Completed 761/1000
#   Completed 762/1000
#   Completed 763/1000
#   Completed 764/1000
#   Completed 765/1000
#   Completed 766/1000
#   Completed 767/1000
#   Completed 768/1000
#   Completed 769/1000
#   Completed 770/1000
#   Completed 771/1000
#   Completed 772/1000
#   Completed 773/1000
#   Completed 774/1000
#   Completed 775/1000
#   Completed 776/1000
#   Completed 777/1000
#   Completed 778/1000
#   Completed 779/1000
#   Completed 780/1000
#   Completed 781/1000
#   Completed 782/1000
#   Completed 783/1000
#   Completed 784/1000
#   Completed 785/1000
#   Completed 786/1000
#   Completed 787/1000
#   Completed 788/1000
#   Completed 789/1000
#   Completed 790/1000
#   Completed 791/1000
#   Completed 792/1000
#   Completed 793/1000
#   Completed 794/1000
#   Completed 795/1000
#   Completed 796/1000
#   Completed 797/1000
#   Completed 798/1000
#   Completed 799/1000
#   Completed 800/1000
#   Completed 801/1000
#   Completed 802/1000
#   Completed 803/1000
#   Completed 804/1000
#   Completed 805/1000
#   Completed 806/1000
#   Completed 807/1000
#   Completed 808/1000
#   Completed 809/1000
#   Completed 810/1000
#   Completed 811/1000
#   Completed 812/1000
#   Completed 813/1000
#   Completed 814/1000
#   Completed 815/1000
#   Completed 816/1000
#   Completed 817/1000
#   Completed 818/1000
#   Completed 819/1000
#   Completed 820/1000
#   Completed 821/1000
#   Completed 822/1000
#   Completed 823/1000
#   Completed 824/1000
#   Completed 825/1000
#   Completed 826/1000
#   Completed 827/1000
#   Completed 828/1000
#   Completed 829/1000
#   Completed 830/1000
#   Completed 831/1000
#   Completed 832/1000
#   Completed 833/1000
#   Completed 834/1000
#   Completed 835/1000
#   Completed 836/1000
#   Completed 837/1000
#   Completed 838/1000
#   Completed 979/1000
#   Completed 980/1000
#   Completed 981/1000
#   Completed 982/1000
#   Completed 983/1000
#   Completed 984/1000
#   Completed 985/1000
#   Completed 986/1000
#   Completed 987/1000
#   Completed 988/1000
#   Completed 989/1000
#   Completed 990/1000
#   Completed 991/1000
#   Completed 992/1000
#   Completed 993/1000
#   Completed 994/1000
#   Completed 995/1000
#   Completed 996/1000
#   Completed 997/1000
#   Completed 998/1000
#   Completed 999/1000
#   Completed 1000/1000
#
# ✓ Completed: 1000 successful, 0 errors
#
# ================================================================================
# BATCH EVALUATION RESULTS
# ================================================================================
#
# Conversation 0:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s focus: deriving a new analytical WKB-based barrier penetration formula that accounts for the long-range Coulomb tail, showing the p...
#
# Conversation 1:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s focus on improving HMC time integration for lattice field theory via force-gradient and nested multirate schemes, tested on the 2D ...
#
# Conversation 2:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary misattributes some results and introduces unsupported claims. It implies that the first method yields functional equations “including hypergeometric ones” for one-...
#
# Conversation 3:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains several inaccuracies relative to the paper.
#   - It states that the “direct differential” method avoids summing over frequency bins, whereas the paper exp...
#
# Conversation 4:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple incorrect and hallucinated claims.
# - It repeatedly includes Type Ia supernovae, whereas the paper exclusively reviews core-collapse supernovae (C...
#
# Conversation 5:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple hallucinations and inaccuracies. The paper does not discuss “process-dependent strangeness and non-strangeness trace contributions,” “dual spin d...
#
# Conversation 6:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the paper studies large deviations for Kingman’s coalescent, builds on LLNs, proves an LDP with an explicit piecewise rate function (vi...
#
# Conversation 7:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - Strengths: The summary accurately states the paper’s aim (measuring four-particle entanglement via the von Neumann entropy of a reduced three-particle system and SSI), the phy...
#
# Conversation 8:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately states the paper’s focus on constraining inflation models via primordial black hole (PBH) overproduction and the limitations of the Stewart–Lyth formula...
#
# Conversation 9:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100): The summary contains a significant factual error about wind drift: the paper states typical drift angles exceed about 3° and the worst cases approach 30°, whereas the summary cl...
#
# Conversation 10:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies and unsupported claims. The paper emphasizes that cooperative effects “sensitively depend on how the meta-stable level is populated,”...
#
# Conversation 11:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100): The summary contains several inaccuracies and hallucinations. It incorrectly claims predictions “including for the tau mass,” which is not discussed in the paper. It misidentifi...
#
# Conversation 12:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several unsupported or incorrect claims. It asserts “simulations demonstrate” performance and gives a concrete claim (“for inputs of size less than 10 bit...
#
# Conversation 13:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary introduces specific numerical values that are not supported by the provided text: it narrows the “nearly featureless” range to 10^17–10^20 eV (the paper states ten...
#
# Conversation 14:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: Correctly states that microlensing probes exoplanets around common (M-dwarf) lenses, that planetary systems break the symmetry of single-lens light curves, that mod...
#
# Conversation 15:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - The summary captures the main thrust of the paper, but it includes notable inaccuracies:
#   - It misassigns the components of the mean peculiar velocity: the paper states a lag...
#
# Conversation 16:
#   Judgment: No
#   Explanation preview: Faithfulness (20/100):
# - The summary contains multiple incorrect and unsupported statements. It claims the resonance was observed in the π⁻p total cross section, whereas the paper concerns the isoscal...
#
# Conversation 17:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces or exaggerates claims not supported by the paper. It states “perfect agreement with higher-level ab initio results,” whereas the paper reports “close ag...
#
# Conversation 18:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several inaccuracies and unsupported claims. It asserts that the simulations “reproduce the star formation histories” and “remarkably reproduce the galaxy...
#
# Conversation 19:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately captures the paper’s focus on semi-infinite, non-PT-symmetric non-Hermitian systems and the mechanism of balance between a non-Hermitian cluster and a l...
#
# Conversation 20:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains inaccuracies relative to the paper. Most notably, it states “for the open strings, the activation energy decreases with distance from the boundary,” which...
#
# Conversation 21:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Mostly accurate and grounded in the provided text. It correctly states the reinterpretation of the rank-3 tensor model as dynamical fuzzy spaces, the existence of Gaussian cla...
#
# Conversation 22:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately presents the paper’s main proposal: a decaying dark matter (DDM) scenario in which a small fraction of the decay product forms a scalar field...
#
# Conversation 23:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies and unsupported claims. It mentions “three-quark systems,” whereas the paper studies hadronic molecules involving heavy mesons and do...
#
# Conversation 24:
#   Judgment: Yes
#   Explanation preview: Faithfulness (96/100):
# - The summary accurately reflects the paper’s focus on classical, interference-based factorization using truncated Fourier, Gauss, Kummer, and exponential sums derived from supe...
#
# Conversation 25:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary captures most core claims, but it introduces a significant inaccuracy about the main negative result. It states that for any computable learning algorithm and any ...
#
# Conversation 26:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains multiple factual inaccuracies. It states a velocity resolution of 78 km s^-1, whereas the 78 km s^-1 figure refers to total velocity coverage; the channel...
#
# Conversation 27:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains factual inaccuracies and a hallucinated entity. It claims a “deep optical survey using the William Herschel Telescope,” whereas the paper states the deep ...
#
# Conversation 28:
#   Judgment: No
#   Explanation preview: Faithfulness (0/100):
# - The summary bears little relation to the paper. It introduces entirely new topics (UV variability mapping, telluric calibration, H-alpha perturbations, occulting companions, “f...
#
# Conversation 29:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100): The summary contains a key inaccuracy: it states that Rashba spin-orbit coupling breaks time-reversal symmetry. The paper explicitly notes that with only spin-orbit coupling, ti...
#
# Conversation 30:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Strengths: The summary accurately identifies the problem (system–environment correlations during pure dephasing of a qubit), the model (qubit coupled non-dissipatively to a th...
#
# Conversation 31:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100): The summary contains significant inaccuracies. It repeatedly uses micrometers (µm) for error magnitudes that, in the paper, are given in units corresponding to nanometers (the t...
#
# Conversation 32:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 50/100)
# - The summary contains several inaccuracies and hallucinations:
#   - It invents specific statistics (“Pearson coefficient of 0.93 and a chance probability of less than 0.00...
#
# Conversation 33:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s core content: a unified derivation of MFDRs at NESS using the Agarwal formalism; equivalence across formulations; the velocity-form...
#
# Conversation 34:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces a specific numerical critical temperature “T_c = 172 MeV,” which is not present in the provided paper text (placeholders like @xmath2, @xmath134, etc. i...
#
# Conversation 35:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary includes unsupported and incorrect statements. Phrases like “only subtle structural tuning can yield a separability around the bounds” and “direct extraction of th...
#
# Conversation 36:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported or incorrect details. It claims “the first millimeter molecular line mapping,” whereas the paper only states that the authors report molecul...
#
# Conversation 37:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary captures several correct elements: SU(4) symmetry in graphene’s Landau levels, use of composite fermion (CF) theory generalized to SU(4), combination with exact di...
#
# Conversation 38:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly identifies the study of molecular motors performing biased walks along filaments with stochastic unbinding/rebinding, modeled via lattice mast...
#
# Conversation 39:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies relative to the paper. It states the method uses the “Jeans equation,” whereas the paper explicitly uses the Jeans theorem and derive...
#
# Conversation 40:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Mostly accurate: it correctly states the setting (Maxwell in the Einstein universe with positive cosmological constant), the conformal reinterpretation in Minkowski space with...
#
# Conversation 41:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope: a thermomechanical Ginzburg–Landau phase-field model for SMAs, introducing a new free energy and a tailored relaxation param...
#
# Conversation 42:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on bigravity with two metrics, the analysis of the Isham–Storey solution’s horizon regularity, and the introduction of a more...
#
# Conversation 43:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces several incorrect or unsupported claims. Examples:
#   - It states a clump mass range of 10^-8–10^-6 M⊙, which is not given in the paper; the paper discus...
#
# Conversation 44:
#   Judgment: Yes
#   Explanation preview: Faithfulness (75/100): The summary largely reflects the paper’s content: it correctly emphasizes phase-space mixing and mass segregation, the outer-region preservation of initial conditions, the consi...
#
# Conversation 45:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - The summary accurately mentions singular Laplacian growth as “fragile” with maximally nonunique behavior and connects the paper’s thesis to Burgers’ equation and turbulence. H...
#
# Conversation 46:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains factual inaccuracies and likely hallucinations. It states the analysis concerns events “above 1000 TeV,” which is orders of magnitude below the ultra-high...
#
# Conversation 47:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100): The summary captures several core facts accurately: the paper formulates the vector–tensor multiplet in 4D N=2 (denoted @xmath0) supersymmetry using a central-charge-extended su...
#
# Conversation 48:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s scope and content: the toolkit’s original purpose (distribution comparison), iterative development driven by use cases, initial two...
#
# Conversation 49:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary correctly states the setting (two trapped atoms, coherent backscattering, two-way interferometer), the quantities analyzed (visibility, distinguishabili...
#
# Conversation 50:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several unsupported or incorrect claims:
#   - It states a “100 μm pixel size,” whereas the paper text (with placeholders) does not specify that value; CMS ...
#
# Conversation 51:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several factual inaccuracies. It asserts a fixed connectivity κ = 2, but the paper only denotes a fixed connectivity as k (xmath2) without specifying a nu...
#
# Conversation 52:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100): The summary largely reflects the paper’s three-part structure: low-energy two-nucleon EFT (with chiral/Weinberg-like counting and its link to realistic potentials), the Cheshire...
#
# Conversation 53:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary correctly captures the paper’s focus on supra-arcade downflows as indirect evidence of magnetic reconnection, the use of AIA (and running-difference, he...
#
# Conversation 54:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains notable inaccuracies. It states that "Non-triggered two-particle correlations show a clear baryon enhancement in the ridge structure," but the paper’s non...
#
# Conversation 55:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary introduces several ratios and particles not supported by the paper text, e.g., K^0_S/π^0 and K̄^0_S/π^0 (π^0 is not discussed), and “Λ/Λ̄/p” (the paper discusses h...
#
# Conversation 56:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - The summary includes some inaccuracies and additions not supported by the paper. It incorrectly links the observed EUV brightenings at filament endpoints to evidence for neutr...
#
# Conversation 57:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary includes inaccurate and unsupported details. It states that adsorption induces p-doping of graphene, whereas the paper indicates charge transfer from TPP to graphe...
#
# Conversation 58:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary incorrectly defines current helicity as H = B × J (a cross product). The paper defines current helicity density as a scalar involving B and J (B · J or equivalentl...
#
# Conversation 59:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - The summary accurately reflects the paper’s main focus: SMQC without nonlocal measurements, reduction to nl-CNOT, construction via bit commitment in the passive model, analysi...
#
# Conversation 60:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly identifies the paper’s focus (single-site entanglement entropy S at the Mott transition in the infinite-dimensional Hubbard model), the method...
#
# Conversation 61:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces incorrect and unsupported details. It names the galaxies as NGC 2403 and NGC 2404, which are not specified in the provided text (the paper leaves the ga...
#
# Conversation 62:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100): The summary contains a significant factual error. It states that the non-ergodicity quotient “for realistic times exceeds the equilibrium value by orders of magnitude.” In the p...
#
# Conversation 63:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary misstates key aspects of the model’s update rules. In the basic model, agents copy the most successful neighbor (MSN) by default, and only with some probability ad...
#
# Conversation 64:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains inaccuracies relative to the paper. It claims the authors “derive the TMD factorization theorem in the Drell–Yan case,” whereas the paper explicitly state...
#
# Conversation 65:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains key inaccuracies. It states the model assumes “local charge neutrality,” whereas the paper explicitly criticizes that assumption and instead imposes bound...
#
# Conversation 66:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains several inaccuracies and unsupported claims:
#   - It introduces “variational procedures,” which the paper does not use. The method is direct: specify...
#
# Conversation 67:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies relative to the paper:
#   - It describes “three-body simulations,” whereas the study models three planets plus a 1000-body planetesima...
#
# Conversation 68:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary introduces incorrect and unsupported claims. It asserts the “final result is the decay constant of the -type current,” whereas the paper computes semileptonic form...
#
# Conversation 69:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary accurately notes key elements such as the limitations of GPR/DPD (daily cadence, lack of polarity), the use of the hourly SOHO/MDI–Debrecen SDD, the sam...
#
# Conversation 70:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several incorrect or unsupported claims. It identifies the object as IRAS 03197-6107; the paper concerns the Egg Nebula (CRL 2688) at ~420 pc, and the giv...
#
# Conversation 71:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately describes the three-wave planar waveguide model with quadratic nonlinearity and a Bragg grating, including linear coupling of the two FF components via ...
#
# Conversation 72:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic (quench from a domain-wall state in the integrable XXZ chain), methods (algebraic Bethe ansatz, explicit overlap formulas), a...
#
# Conversation 73:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several unsupported or incorrect statements. It introduces a specific mass-growth rate of 6 × 10−8 M⊙ yr−1 that is not given in the paper text (the paper ...
#
# Conversation 74:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on skyrmion motion driven by magnonic spin-transfer torque in nanowires for both longitudinal and transverse spin-wave drivin...
#
# Conversation 75:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces inaccuracies and contradictions relative to the paper. The paper ultimately argues that in the ultra-strong, collision-dominated, quantizing regime all ...
#
# Conversation 76:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Largely accurate to the paper’s content: it correctly highlights the prevalence of bipolar morphologies in massive-star nebulae and PNe, the limitations of interacting-wind mo...
#
# Conversation 77:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - Strengths: The summary accurately reflects the paper’s core content: PHENIX’s distributed environment; the two-level file catalog (central at BNL and local Magda instances); u...
#
# Conversation 78:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains several factual inaccuracies relative to the paper. It misidentifies the material as SrRuO3 instead of the bilayer ruthenate Sr3Ru2O7 that motivates the s...
#
# Conversation 79:
#   Judgment: Yes
#   Explanation preview: Faithfulness (0-100): 92
# - The summary accurately reflects the paper’s content: multi-post re-entrant cavities as a generalization of one-post designs; posts modeled as lumped harmonic oscillators wit...
#
# Conversation 80:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100): The summary contains several inaccuracies and hallucinations. It misclassifies carbon nanotubes as “spherical hollow nanoparticles,” whereas the paper focuses on spherical shell...
#
# Conversation 81:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains several unsupported or incorrect claims relative to the paper.
#   - It states SDSS has “six filters,” whereas the paper uses five filters (ugriz) and only ...
#
# Conversation 82:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary introduces a hallucinated element: “related to GW calculations,” which is not in the paper. The paper uses generalized Mie theory and a multipole expansion; there ...
#
# Conversation 83:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains incorrect and unsupported claims. It states that “in one dimension localization is only possible below critical atom number,” which contradicts the paper’...
#
# Conversation 84:
#   Judgment: No
#   Explanation preview: Faithfulness (65/100):
# - Strengths: The summary correctly identifies the main topic (integrability of 1D Bose/Fermi gases with large effective range), the focus on the three-body problem, the use of a...
#
# Conversation 85:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary misstates a key point about the modification to the theory. The paper explains that the modification of kinetic terms is introduced so that the SU(N) and U(1) chir...
#
# Conversation 86:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains at least one unsupported/incorrect claim. It states “As no optical flow method currently uses lateral dependencies,” which is not asserted in the paper. T...
#
# Conversation 87:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains major inaccuracies. The paper proves that the minimal complexity depends on the number of columns (specifically, the minimal number of passes grows expone...
#
# Conversation 88:
#   Judgment: Yes
#   Explanation preview: Faithfulness (80/100):
# - Strengths: The summary correctly identifies the hierarchy problem from quadratic divergences, the top-condensation/composite Higgs context, the paper’s use of Ward–Takahashi i...
#
# Conversation 89:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies relative to the paper. The study focuses on the instability of an accelerating ionization front (IF), not a photodissociation region ...
#
# Conversation 90:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# The summary contains a critical factual error by reversing which static phase corresponds to broken vs. unbroken PT symmetry. The paper states that the static disordered (parama...
#
# Conversation 91:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s topic (high-frequency, high-l p-modes in neutron star envelopes), methodology (relativistic Cowling, plane-parallel treatment, loca...
#
# Conversation 92:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: The summary correctly states the paper’s central claim that a coherent pre-existing flux tube is not required for active region formation and that magneto-convectio...
#
# Conversation 93:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies and unsupported additions. It claims the galaxy–galaxy lensing contribution “dominates” the cosmic shear signal at 1 arcmin for NFW l...
#
# Conversation 94:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately captures the paper’s main aims (spatial STIRAP in waveguides/atom chips), the modeling approach (idealized resonant three-guide system, handling longitu...
#
# Conversation 95:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100): The summary largely reflects the paper’s aims, setup, theoretical framing (EGT based on Tangherlini–Selleri), linkage to the CMBR rest frame, and the claimed observation of an a...
#
# Conversation 96:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains two significant inaccuracies. First, it states “All three CO clouds … appear to lie in the foreground,” whereas the paper concludes that only the northern...
#
# Conversation 97:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains a critical factual error: it reports the s-wave scattering length as -1.4(5) nm, whereas the paper finds a positive value of +1.4(5) nm (26(10) a0). It al...
#
# Conversation 98:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s main claims: gas on the leading side of the bar, bar gravity torques driving inflow, formation of a central mass concentration (CMC...
#
# Conversation 99:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s scope and key claims: two primary PTV velocity error sources (acceleration vs. position uncertainty), their opposite dependencies o...
#
# Conversation 100:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary introduces specific numerical results that are not present in the provided paper text, which uses placeholders (e.g., “@xmath18–@xmath19” for the dip location, “@x...
#
# Conversation 101:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45)
# - The summary contains several factual inaccuracies:
#   - The FUSE spectral coverage is stated as 910–1180 nm; the paper specifies 910–1180 Å (≈91–118 nm). This is a significan...
#
# Conversation 102:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces incorrect or nonsensical identifiers (e.g., “2020h,” “2043,” “2020”), which do not correspond to the paper’s planets (HD 209458b and OGLE-TR-56b).
# - It...
#
# Conversation 103:
# ...
#
# Conversation 940:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies not supported by the paper:
#   - It describes graphene as a “quantized two-dimensional honeycomb lattice,” whereas the paper explicitl...
#
# Conversation 941:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary includes several inaccuracies and hallucinations. It claims “two alternative formulae for calculating the redshift” depend on the velocity dispersion, whereas the ...
#
# Conversation 942:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported or incorrect details. It specifies a redshift range “z = 0.49–0.647,” whereas the paper only clearly states up to z = 0.647 for the Kormendy...
#
# Conversation 943:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - Strengths: The summary accurately states that the paper presents a vacuum, cylindrically symmetric plane wave spacetime with a periodic coordinate that admits closed null geod...
#
# Conversation 944:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately captures the main findings: identification of broad Balmer absorptions attributed to the white dwarf atmosphere, WD temperature range (18,000...
#
# Conversation 945:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100): The summary contains several inaccuracies and unsupported claims. It introduces “KCID magnitudes,” which is not used in the paper (the correct term is KIC/Kepler magnitude). It ...
#
# Conversation 946:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary accurately states the paper’s shift from line counting to probing galactic structure/ionization/kinematics, the central question of which galactic compo...
#
# Conversation 947:
#   Judgment: No
#   Explanation preview: Faithfulness (64/100):
# - Mostly accurate, but it introduces a specific, unsupported claim: “This causal updating accumulates from the single most dominant source at large distance: the galaxy scale.” ...
#
# Conversation 948:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on propagating uncertainties in physics, with emphasis on systematic effects and a Bayesian framework based on degrees of bel...
#
# Conversation 949:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - Strengths: Accurately states the problem (automated coronal loop detection in EUV images), the core method (2D WTMM with derivative-of-Gaussian wavelets, multiscale edge track...
#
# Conversation 950:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary incorrectly states that the correlation is with “mass in dark matter halos,” whereas the paper analyzes the mass density field (total mass) smoothed in redshift sp...
#
# Conversation 951:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - The summary accurately reflects the paper’s core content: modeling a qubit’s interaction with a zero-bandwidth noisy environment, deriving time-dependent Kraus decompositions,...
#
# Conversation 952:
#   Judgment: No
#   Explanation preview: Faithfulness (68/100):
# - Strengths: The summary correctly states the central idea of benchmarking vacuum pressure increases against ecloud simulations to infer two surface parameters (maximum secondar...
#
# Conversation 953:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies. It states the system uses “direct memory addressing,” while the paper’s key enabler is an indirect memory addressing unit on the FPG...
#
# Conversation 954:
#   Judgment: Yes
#   Explanation preview: Faithfulness (86/100):
# - The summary accurately reflects the paper’s focus on inhomogeneous superconductivity in cuprates, stripe phases, and the role of locally broken spin-rotational symmetry in pai...
#
# Conversation 955:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s topic, setting, and apparatus: studying muon-induced spallation neutrons at 611 m.w.e. in the Aberdeen Tunnel using a plastic-scint...
#
# Conversation 956:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s focus on probing the dynamical structure factor of strongly interacting 1D Bose gases via Bragg spectroscopy, using Bethe ansatz-ba...
#
# Conversation 957:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100):
# - The summary accurately reflects the paper’s focus on extensive air showers, the challenge of reconstructing primary energy and mass due to fluctuations, and the use of simulat...
#
# Conversation 958:
#   Judgment: No
#   Explanation preview: Faithfulness (50/100):
# - The summary contains several inaccuracies. It states that the UV PSF elongation is 0.01", whereas the paper reports ~0.1". It also claims that the IDC tables “now distinguish ...
#
# Conversation 959:
#   Judgment: Yes
#   Explanation preview: Faithfulness: 82/100
# - Strengths: Accurately captures the paper’s motivation (SCM needs dense SEM grids, Padova94’s coarse metallicity grid), the core interpolation strategy (phase subdivision; linear...
#
# Conversation 960:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100):
# - The summary contains several inaccuracies and hallucinations:
#   - It claims the flapping is “triggered by hydrodynamic forces,” whereas the paper explicitly imposes the flappi...
#
# Conversation 961:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary contains several inaccuracies. It claims the analysis used “midsatellite data during cycle 22,” whereas the paper uses SOHO/MDI data from 1996–2001 (solar cycle 23...
#
# Conversation 962:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100): The summary accurately reflects the paper’s scope and findings: DFT with van der Waals corrections is used to study graphene/WS2 and graphene/WSe2 heterostructures; proximity en...
#
# Conversation 963:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces several incorrect or unsubstantiated claims. It states “over 10^6 Monte Carlo simulations,” a number not mentioned in the paper. It describes the cavity...
#
# Conversation 964:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary includes several unsupported or incorrect numerical details and statements not present in the provided text. Examples: specific temperatures for the “emergent flux...
#
# Conversation 965:
#   Judgment: No
#   Explanation preview: - Faithfulness (45/100): The summary introduces several unsupported specifics and claims. The paper does not report a “580×580 pixel region,” “3,510 images,” or a time window of “02:00–23:00”; the ori...
#
# Conversation 966:
#   Judgment: No
#   Explanation preview: Faithfulness (58/100):
# - Strengths: The summary correctly states the paper’s focus on thermalization in binary ultracold mixtures, the use of coupled Boltzmann equations, inclusion of all partial wave...
#
# Conversation 967:
#   Judgment: No
#   Explanation preview: Faithfulness (15/100):
# - The summary contains multiple factual inaccuracies. It misidentifies the target meson as the scalar a0(980), whereas the paper studies the strange tensor meson (commonly K2*(1...
#
# Conversation 968:
#   Judgment: No
#   Explanation preview: Faithfulness (40/100):
# - The summary introduces several claims not supported by the paper. Examples include “table-top spatial scales,” “subgrid models,” and the assertion that “the stellar mass funct...
#
# Conversation 969:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Strengths: The summary correctly identifies the setting (Einstein–Vlasov with Bianchi I symmetry, collisionless matter, 3+1 decomposition), the link to the Einstein–dust limit...
#
# Conversation 970:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains a key inaccuracy: it states that the cavity is “coherently driven by a pump resonant with the BEC transition |0> → |1>.” The paper explicitly assumes larg...
#
# Conversation 971:
#   Judgment: Yes
#   Explanation preview: Faithfulness (90/100): The summary accurately reflects the paper’s core content: it identifies the focus on decay of article page views, rejects power-law behavior, emphasizes nonexponential decay mod...
#
# Conversation 972:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s core claims: dark solitons in inhomogeneous traps interact via sound over long distances; energy can be exchanged without direct co...
#
# Conversation 973:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary misstates the core construction of the “steady AIM.” In the paper, the steady AIM is computed by making the fast components of the time derivative (or chord) zero ...
#
# Conversation 974:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies and minor hallucinations. It incorrectly states that the gravitational-wave amplitude is determined by the inflationary Hubble rate a...
#
# Conversation 975:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100): The summary accurately reflects the paper’s scope and key points: it highlights the over-massive central spheroid problem, the observed low baryon fraction, the AMR vs. SPH comp...
#
# Conversation 976:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary introduces incorrect and unsupported details. It claims SGR bursts have photon energy ~2 keV; the paper does not provide a numeric value, and “soft gamma-ray...
#
# Conversation 977:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - Mostly accurate: it correctly states the paper’s central idea of defining conformal invariance via measure line bundles, independent of a metric, and that invariance correspon...
#
# Conversation 978:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary largely reflects the paper’s scope (OZI-suppressed decays of the B_c meson in perturbative QCD, one-loop calculations, use of light-cone distribution amplitudes, n...
#
# Conversation 979:
#   Judgment: Yes
#   Explanation preview: Faithfulness (78/100):
# - Mostly accurate: captures the 2D BCS-BEC crossover focus, the beyond-mean-field Gaussian-fluctuation approach with zero-point energy regularization, agreement with Makhalov et...
#
# Conversation 980:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100):
# - The summary accurately reflects the paper’s focus on the anomalous Hall effect (AHE), the limitations of velocity-only transport formulations, the alternative formulation usin...
#
# Conversation 981:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary includes several inaccuracies and hallucinations:
#   - It states the maximal synchrotron photon energy in the fluid frame is ~10 MeV in an ISM, whereas the paper de...
#
# Conversation 982:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100): The summary contains several unsupported or incorrect claims. It converts the angular separations to degrees (e.g., “within 30°–40°” and “within 10°–5°”), whereas the paper clea...
#
# Conversation 983:
#   Judgment: Yes
#   Explanation preview: Faithfulness (95/100):
# - The summary accurately reflects the paper’s content. It correctly states that a dependence space is constructed from a matroid via a congruence relation defined using closure ...
#
# Conversation 984:
#   Judgment: Yes
#   Explanation preview: Faithfulness (82/100):
# - The summary accurately presents the central debate (disk-origin vs Compton downscattering), the specific models tested (Misra & Kembhavi; Misra & Sutaria), the key constraints...
#
# Conversation 985:
#   Judgment: Yes
#   Explanation preview: Faithfulness (85/100): The summary accurately reflects the paper’s core content: it introduces the CAT3D-wind radiative transfer model combining a clumpy thin disk with a hollow polar outflow; highlig...
#
# Conversation 986:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies. It claims the work “considers the high-energy OPE at two-loop level,” whereas the paper develops the NLO (one-loop order in the fact...
#
# Conversation 987:
#   Judgment: No
#   Explanation preview: Faithfulness (25/100):
# - The summary contains several factual inaccuracies and hallucinations. It incorrectly states that the measured effective masses “increased from 6.45 to 7.25 m₀”; those numbers ...
#
# Conversation 988:
#   Judgment: No
#   Explanation preview: Faithfulness (30/100): The summary contains multiple unsupported or incorrect claims. It invents specific numerical values not present in the provided text, such as an “18% impact probability” and a P...
#
# Conversation 989:
#   Judgment: Yes
#   Explanation preview: Faithfulness (92/100):
# - The summary accurately reflects the paper’s topic (UHECR air-shower simulations), the dependence on hadronic interaction models, and the motivation due to model uncertainties....
#
# Conversation 990:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100): The summary accurately reflects the paper’s core content: extending spectrogram-based time–frequency analysis of ship wakes to finite-depth channels; distinguishing subcritical ...
#
# Conversation 991:
#   Judgment: No
#   Explanation preview: Faithfulness (60/100):
# - Strengths: The summary correctly states the study’s goal (sentiment analysis for the 2016 U.S. election using Naive Bayes per candidate), data collection details (371,264 twee...
#
# Conversation 992:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces unsupported or incorrect claims. Examples:
#   - “transverse orientation of the organic bottom layer” is not mentioned in the paper and appears fabricated...
#
# Conversation 993:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary contains several inaccuracies and likely hallucinated details. It claims integration times “up to 1.4 Gyrs” and extends three orbits to “4.5 Glyr,” whereas the pap...
#
# Conversation 994:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains notable inaccuracies. It states that “our methodology, using the conventional 1-body Dirac equation, agrees very well with experimental results,” whereas ...
#
# Conversation 995:
#   Judgment: Yes
#   Explanation preview: Faithfulness (88/100):
# - Strengths: The summary accurately reflects the paper’s core content: it studies worst-case mobile users located at Voronoi vertices in a PPP-modeled downlink cellular network,...
#
# Conversation 996:
#   Judgment: No
#   Explanation preview: Faithfulness (35/100):
# - The summary contains several inaccuracies and hallucinations not supported by the paper. Examples:
#   - It claims “all 15 stars … lie on the H-R diagram as post-T Tauri stars,”...
#
# Conversation 997:
#   Judgment: No
#   Explanation preview: Faithfulness (55/100):
# - The summary contains several inaccuracies relative to the paper. It claims the fit “constrains” the redshift, whereas the paper explores three assumed redshifts (0.3, 0.6, 0.8...
#
# Conversation 998:
#   Judgment: No
#   Explanation preview: Faithfulness (45/100):
# - The summary introduces specific numerical constraints (“ω_m ≳ 0.1” and “ε ≳ 0.04” at 68% confidence) that are not supported by the provided paper text, which gives only symbol...
#
# Conversation 999:
#   Judgment: No
#   Explanation preview: Faithfulness (Score: 45/100)
# - The summary contains several inaccuracies and unsupported details:
#   - Introduces a specific fixed value α_s ≈ 0.3, which is not given in the paper.
#   - States “isotopic...
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total evaluated: 1000
# Yes: 301 (30.1%)
# No: 699 (69.9%)
# Unknown: 0 (0.0%)

# %%
# Save results to JSONL file
import json

# Create filename with baseline_eval in it
output_filename = f"/Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_eval_qwen3_4b_test_gpt5_instruct_article_lora_fixed_v2.jsonl"

# Write results to JSONL file
with open(output_filename, 'w', encoding='utf-8') as f:
    for idx, result, prompt in fine_tuned_results:
        output_data = {
            'index': idx,
            'judgment': result['judgment'],
            'explanation': result['explanation'],
            'evaluation_prompt': prompt
        }
        f.write(json.dumps(output_data, ensure_ascii=False) + '\n')

print(f"Saved {len(fine_tuned_results)} results to {output_filename}")
# Out:
# Saved 1000 results to /Users/ryanarman/code/lab/arxiv_abstract/data/fine_tuned_eval_qwen3_4b_test_gpt5_instruct_article_lora_fixed_v2.jsonl

# %% [markdown]
# ## score finetuned: 7%
