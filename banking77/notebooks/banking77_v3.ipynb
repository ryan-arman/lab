# %%
from utils import measure_accuracy, read_jsonl

# %% [markdown]
# # Run inference on base model

# %% [markdown]
# ./submit_inference_rsync.sh data/banking77_test_v3.jsonl configs/4b_instruct_vllm_infer.yaml baseline_results_v3 ryan@exun

# %%
inference_file = '/Users/ryanarman/code/lab/banking77/notebooks/data/baseline_results_v3_3026.jsonl'
inference_data = read_jsonl(inference_file)
accuracy, correct, total, errors, incorrect_list = measure_accuracy(inference_data)
# Out:
# idx: 323, gt_label: 4, inference_class_label: 4, content: 4
#
#
# The user is asking about automatic top-up functionality, which directly matches intent ID 4: automatic_top_up. The query expresses a need for financial support due to running out of money, which is a common reason for requesting auto-top-up. This is distinct from other intents like top-up limits (60), top-up by card (62), or balance issues (5).
# idx: 332, gt_label: 4, inference_class_label: 4, content: 4
#
#
# The query "Is there an auto top-up option?" is asking about an automatic top-up feature, which directly corresponds to the intent "automatic_top_up" with ID 4. This is distinct from other top-up-related intents like "top_up_by_card_charge" or "top_up_limits", as it specifically refers to an automated, recurring top-up process.
# idx: 335, gt_label: 4, inference_class_label: 4, content: 4
#
#
# ...

# %%
improved_train_path = "/Users/ryanarman/code/lab/banking77/notebooks/data/banking77_train_v3.jsonl"
improved_train_data = read_jsonl(improved_train_path)
# Out:
# min: 0, max: 76

# %% [markdown]
# # Train the model

# %% [markdown]
# ./submit_training_rsync.sh \
# data/banking77_train_v3.jsonl \
# data/banking77_val_v3.jsonl \
# configs/qwen4b_train_lora.yaml \
# my_training_v3 \
# ryan@exun

# %% [markdown]
# ## Run inference with LoRA adapter
# changed lora config to :
#
#  num_train_epochs: 2 (from 1)
#  learning_rate: 3.0e-06 (from 5.0e-06)
#
# peft:
#   lora_r: 128
#   lora_alpha: 256
#   lora_dropout: 0.05
#   lora_target_modules:
#     - q_proj
#     - k_proj
#     - v_proj
#     - o_proj
#     - gate_proj
#     - up_proj
#     - down_proj
#
#
# cd notebooks/scripts
# ./submit_inference_rsync.sh \
#     data/banking77_test_v3.jsonl \
#     configs/4b_instruct_vllm_infer.yaml \
#     system_prompt_v2_lora_results \
#     output/my_training_v3_3020 \
#     ryan@exun

# %% [markdown]
# /home/ryan/code/oumi/lab/banking77/notebooks/output/my_training_v3_3020

# %% [markdown]
# # Run inference on trained model checkpoint

# %% [markdown]
# ## Run inference with LoRA adapter
#
# Lora config:
#
# peft:
#   lora_r: 64
#   lora_alpha: 128
#   lora_target_modules:
#   - q_proj
#   - k_proj
#   - v_proj
#   - o_proj
#   - gate_proj
#   - up_proj
#   - down_proj
#
#
# cd notebooks/scripts
# ./submit_inference_rsync.sh \
#     data/banking77_test.jsonl \
#     configs/4b_instruct_vllm_infer.yaml \
#     system_prompt_v2_improved_train_results \
#     output/my_training_3014 \
#     ryan@exun

# %%
inference_file = '/Users/ryanarman/code/lab/banking77/notebooks/data/system_prompt_v2_lora_results_3024.jsonl'
inference_data = read_jsonl(inference_file)
accuracy, correct, total, errors, incorrect_list = measure_accuracy(inference_data)
# Out:
# Accuracy: 89.42% (2754/3080)

# %%
inference_data[0]
# Out:
# {'conversation_id': 'ce832281-15cb-5817-8617-9e2e5a8f093d',
# ...
