# %%
from utils import read_jsonl, measure_accuracy
from oumi.core.types.conversation import Conversation, Message, Role

test_file = '/Users/ryanarman/code/lab/banking77/notebooks/data/banking77_test_v2_1.jsonl'
test_data = read_jsonl(test_file)
test_data[0]

def create_conversations(data):
    # Create conversations from test_data
    # Each item in test_data has messages with system and user roles
    openai_conversations = []
    for item in data:
        messages = item['messages']
        # Extract system prompt and user query
        system_content = messages[0]['content']  # System prompt
        user_content = messages[1]['content']     # User query
        
        # Create Conversation object with system and user messages
        conversation = Conversation(
            messages=[
                Message(role=Role.SYSTEM, content=system_content),
                Message(role=Role.USER, content=user_content),
            ]
        )
        openai_conversations.append(conversation)
    return openai_conversations

# %%
# Run inference with OpenAI GPT-4o-mini on the test set
# Uses the same system prompt as the local model
from oumi.core.configs import InferenceConfig, ModelParams, GenerationParams
from oumi.core.configs.inference_engine_type import InferenceEngineType
from oumi.builders.inference_engines import build_inference_engine
import os

# Check if OpenAI API key is set
if not os.getenv("OPENAI_API_KEY"):
    print("⚠️  WARNING: OPENAI_API_KEY environment variable not set!")
    print("   Set it with: export OPENAI_API_KEY=your_key_here")
else:
    print("✓ OPENAI_API_KEY is set")

# Create inference config for OpenAI GPT-4o-mini
from oumi.core.configs.params.remote_params import RemoteParams

openai_config = InferenceConfig(
    model=ModelParams(
        model_name="gpt-5-mini",  # OpenAI model name (fixed from gpt-5-mini)
    ),
    generation=GenerationParams(
        max_new_tokens=2048,  # Increased to avoid truncation (model may add reasoning despite prompt)
        temperature=1.0,  # GPT-4o-mini only supports 1.0 (default), cannot use 0.0
        use_sampling=True,  # Sampling is required when temperature > 0
    ),
    engine=InferenceEngineType.OPENAI,
    remote_params=RemoteParams(
        num_workers=1000,  # Set to requests per minute (RPM) limit
        politeness_policy=60.0,  # 60 seconds (most APIs have per-minute limits)
        use_adaptive_concurrency=True,  # Automatically adjust concurrency based on error rate
    ),
)

print("OpenAI inference config created")

# Build the OpenAI inference engine
openai_engine = build_inference_engine(
    engine_type=openai_config.engine or InferenceEngineType.OPENAI,
    model_params=openai_config.model,
    remote_params=openai_config.remote_params,
)


openai_conversations = create_conversations(test_data)
print(f"Created {len(openai_conversations)} conversations from test_data")

# Run inference with OpenAI
print(f"Running OpenAI inference on {len(openai_conversations)} conversations...")
openai_responses = openai_engine.infer(
    input=openai_conversations,
    inference_config=openai_config,
)

print(f"Received {len(openai_responses)} responses from OpenAI")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# ✓ OPENAI_API_KEY is set
# OpenAI inference config created
# Created 3080 conversations from test_data
# Running OpenAI inference on 3080 conversations...
# [2025-11-21 12:11:47,271][oumi][rank0][pid:99860][MainThread][WARNING]][base_inference_engine.py:409] OpenAIInferenceEngine does not support use_sampling. Received value: use_sampling=True. This parameter will be ignored.
# 100%|██████████| 3080/3080 [03:13<00:00, 15.90it/s]
# Received 3080 responses from OpenAI

# %%
openai_conversations[0]
# Out:
# SYSTEM: You are a banking intent classifier. You must classify a user’s query into exactly one of 77 banking intents.
# Your output MUST be a single integer ID from 0 to 76, with no words, no punctuation, no explanation.
#
# Each intent has:
# - a unique numeric ID
# - a short descriptive name
# - a natural-language description explaining what the label represents
#
# Choose the ID that best matches the user’s intent.
#
# ---------------------------------------
# INTENT CATALOG (ID → description)
# ---------------------------------------
#
# 0: activate_my_card — User wants to activate a new physical card for the first time.
# 1: age_limit — User asks about minimum age or age restrictions for using the service.
# 2: apple_pay_or_google_pay — Questions about using Apple Pay / Google Pay / mobile wallets.
# 3: atm_support — Asking which ATMs can be used, ATM network availability, or compatibility.
# 4: automatic_top_up — Questions about automatic / scheduled top-ups, enabling or disabling them.
# 5: balance_not_updated_after_bank_transfer — Bank transfer completed but balance has not updated.
# 6: balance_not_updated_after_cheque_or_cash_deposit — Cash/cheque deposit completed but balance unchanged.
# 7: beneficiary_not_allowed — User cannot add a beneficiary or certain recipient is blocked.
# 8: cancel_transfer — User wants to cancel a bank transfer that is processing.
# 9: card_about_to_expire — Card is close to expiration; user asks what to do.
# 10: card_acceptance — Merchant or terminal won’t accept the card.
# 11: card_arrival — User asking about *their specific card* that has not arrived yet.
# 12: card_delivery_estimate — General questions about delivery timeframes or delivery options.
# 13: card_linking — Linking or relinking a card in the app; reconnecting a found card.
# 14: card_not_working — Card fails at terminals; general functionality issues.
# 15: card_payment_fee_charged — Fee charged during a card payment (e.g., extra card fee).
# 16: card_payment_not_recognised — User sees a card payment they do not recognize.
# 17: card_payment_wrong_exchange_rate — Wrong FX rate used in a **card** payment.
# 18: card_swallowed — ATM ate the user’s card.
# 19: cash_withdrawal_charge — Extra charge for cash withdrawal.
# 20: cash_withdrawal_not_recognised — Cash withdrawal shown that user did not perform.
# 21: change_pin — User wants to change their PIN to a new one.
# 22: compromised_card — Card security compromised; suspected fraud.
# 23: contactless_not_working — Tap-to-pay/contactless feature not functioning.
# 24: country_support — Asking which countries are supported or available.
# 25: declined_card_payment — A card payment was declined/rejected.
# 26: declined_cash_withdrawal — ATM cash withdrawal declined.
# 27: declined_transfer — Bank transfer declined/rejected.
# 28: direct_debit_payment_not_recognised — Unknown direct debit on statement.
# 29: disposable_card_limits — Limits or restrictions on disposable / virtual single-use cards.
# 30: edit_personal_details — Changing personal info (address, name, etc).
# 31: exchange_charge — Charge applied for currency exchange.
# 32: exchange_rate — Asking about current/general exchange rates.
# 33: exchange_via_app — How to exchange currencies inside the app.
# 34: extra_charge_on_statement — Unexpected extra charge not necessarily tied to card fees.
# 35: failed_transfer — Transfer failed to send.
# 36: fiat_currency_support — Asking which fiat currencies are supported.
# 37: get_disposable_virtual_card — How to obtain a disposable/temporary virtual card.
# 38: get_physical_card — User wants to obtain a physical card.
# 39: getting_spare_card — Requesting an additional/spare card.
# 40: getting_virtual_card — Asking how to get a virtual card.
# 41: lost_or_stolen_card — Reporting a lost or stolen card.
# 42: lost_or_stolen_phone — Reporting a lost or stolen phone (and related account concerns).
# 43: order_physical_card — Ordering a physical card (initial order).
# 44: passcode_forgotten — User forgot the app passcode.
# 45: pending_card_payment — Card payment stuck in pending.
# 46: pending_cash_withdrawal — Cash withdrawal stuck in pending.
# 47: pending_top_up — Top-up stuck in pending.
# 48: pending_transfer — Transfer stuck in pending.
# 49: pin_blocked — PIN has been blocked/locked due to too many attempts.
# 50: receiving_money — User expects incoming money and has questions about it.
# 51: refund_not_showing_up — Refund expected but not showing in account.
# 52: request_refund — User explicitly wants to request a refund.
# 53: reverted_card_payment — A card payment was reverted/rolled back.
# 54: supported_cards_and_currencies — Asking which cards/currencies are supported.
# 55: terminate_account — User wants to close or terminate their account.
# 56: top_up_by_bank_transfer_charge — Fee for top-up by bank transfer.
# 57: top_up_by_card_charge — Fee for topping up by card.
# 58: top_up_by_cash_or_cheque — Questions on top-up via cash/cheque.
# 59: top_up_failed — Top-up attempt failed.
# 60: top_up_limits — Asking about top-up limits.
# 61: top_up_reverted — Top-up was reverted/rolled back.
# 62: topping_up_by_card — How to top up using a card.
# 63: transaction_charged_twice — Duplicate charge on statement.
# 64: transfer_fee_charged — Transfer fee charged unexpectedly.
# 65: transfer_into_account — Receiving money into account / deposit questions.
# 66: transfer_not_received_by_recipient — Recipient hasn’t received the transfer.
# 67: transfer_timing — How long transfers take.
# 68: unable_to_verify_identity — User attempted to verify but failed.
# 69: verify_my_identity — User wants to complete verification.
# 70: verify_source_of_funds — Verification of income/source of funds.
# 71: verify_top_up — Verification required for a top-up.
# 72: virtual_card_not_working — Virtual card doesn’t work.
# 73: visa_or_mastercard — Asking about card networks (Visa vs Mastercard).
# 74: why_verify_identity — Asking why verification is needed.
# 75: wrong_amount_of_cash_received — Wrong cash dispensed by ATM.
# 76: wrong_exchange_rate_for_cash_withdrawal — Wrong FX rate applied in a **cash withdrawal**.
# ---------------------------------------
# IMPORTANT FEW-SHOT DISAMBIGUATION EXAMPLES
# ---------------------------------------
#
# EXAMPLES TO HELP DISTINGUISH SIMILAR INTENTS:
#
# 1. card_arrival (ID 11) vs card_delivery_estimate (ID 12):
#    card_arrival = asking about YOUR specific card that hasn't arrived yet (tracking, status)
#    card_delivery_estimate = asking about general delivery timeframes/how long it takes
#    - Query: "Could you send me and up date on the arrival of my card?" → 11
#    - Query: "My card was supposed to arrive, but hasn't?" → 11
#    - Query: "I have not received my card and it's been a week, what do I do?" → 11
#    - Query: "can you express my card to me?" → 12
#    - Query: "Can I choose the day it's delivered?" → 12
#    - Query: "i need to add express delivery if that's an option" → 12
#
# 2. card_linking (ID 13) vs activate_my_card (ID 0) vs lost_or_stolen_card (ID 41):
#    card_linking = reconnecting a card you found/retrieved
#    activate_my_card = activating a NEW card for first time
#    lost_or_stolen_card = reporting a card as lost/stolen
#    - Query: "Okay, I found my card, can I put it back in the app?" → 13
#    - Query: "I want to reactivate my card, I thought I had lost it but I found it." → 13
#    - Query: "What do I need to do for the card activation?" → 0
#    - Query: "Tell me what I need to do to activate my card." → 0
#    - Query: "I left my card at a restaurant and now its missing." → 41
#    - Query: "Who can I speak with regarding a lost card?" → 41
#
# 3. pin_blocked (ID 49) vs change_pin (ID 21):
#    pin_blocked = PIN is locked/blocked, need to unlock
#    change_pin = want to change PIN to a new one
#    - Query: "How many times can I enter a wrong PIN before it is blocked?" → 49
#    - Query: "I entered in the wrong PIN.  Please help me unlock my account." → 49
#    - Query: "Where do I need to go to change my PIN?" → 21
#    - Query: "I really need to know how to change my pin." → 21
#
# 4. pending_cash_withdrawal (ID 46) vs declined_cash_withdrawal (ID 26) vs cash_withdrawal_not_recognised (ID 20):
#    pending_cash_withdrawal = withdrawal is processing/pending
#    declined_cash_withdrawal = withdrawal was rejected/declined
#    cash_withdrawal_not_recognised = withdrawal not showing in account
#    - Query: "I tried to get cash at some ATM in the city centre earlier but the machine declined my card. I've seen it still shows up as pending in my account. Please cancel it immediately as I definitely have not received that money!" → 46
#    - Query: "I attempted to get cash in the ATM but it was not authorized" → 26
#    - Query: "My app says I withdraw money from my account from an ATM." → 20
#
# 5. verify_my_identity (ID 69) vs why_verify_identity (ID 74) vs unable_to_verify_identity (ID 68):
#    verify_my_identity = want to verify/complete verification
#    why_verify_identity = asking why verification is needed
#    unable_to_verify_identity = having trouble completing verification
#    - Query: "If I'm getting my identity verified, what all do I need?" → 69
#    - Query: "I do not feel comfortable verifying my identity." → 74
#    - Query: "My identity wasn't verified" → 68
#
# 6. card_payment_wrong_exchange_rate (ID 17) vs wrong_exchange_rate_for_cash_withdrawal (ID 76) vs exchange_rate (ID 32):
#    card_payment_wrong_exchange_rate = wrong rate used for CARD payment
#    wrong_exchange_rate_for_cash_withdrawal = wrong rate used for CASH withdrawal
#    exchange_rate = asking about current/general exchange rates
#    - Query: "I seem to have been charged to much for my holiday purchases, the exchange rate is wrong." → 17
#    - Query: "The exchange rate for foreign ATM currency is wrong." → 76
#    - Query: "How did you guys get your exchange rate?" → 32
#
# 7. extra_charge_on_statement (ID 34) vs card_payment_fee_charged (ID 15):
#    extra_charge_on_statement = unexpected charge on statement
#    card_payment_fee_charged = fee charged for card payment
#    - Query: "I was overcharged one extra pound!" → 34
#    - Query: "There was an extra fee when I paid with my card, why was i charged this extra fee?" → 15
#
# 8. getting_virtual_card (ID 40):
#    - Query: "Where do I have access to a virtual card?" → 40
#    - Query: "How can I receive a virtual card?" → 40
#
#
# CRITICAL INSTRUCTIONS:
# 1. Choose exactly one integer ID (0-76).
# 2. Reply with ONLY that number. No words, no reasoning, no punctuation.
# Examples: 0, 1, 42.
#
# Remember: Respond with ONLY the numeric ID, nothing else.
# USER: How do I locate my card?

# %%
teacher_results_path = '/Users/ryanarman/code/lab/banking77/notebooks/data/teacher_results_v2_1_sytem_prompt.jsonl'
import json

# Save responses as conversation format
with open(teacher_results_path, "w", encoding='utf-8') as f:
    for response in openai_responses:
        # Convert Conversation object to dict and save
        f.write(json.dumps(response.to_dict(), ensure_ascii=False) + "\n")

print(f"Saved {len(openai_responses)} conversations to {teacher_results_path}")
# Out:
# Saved 3080 conversations to /Users/ryanarman/code/lab/banking77/notebooks/data/teacher_results_v2_1_sytem_prompt.jsonl

# %%
# Combine responses with metadata for accuracy measurement
inference_data = []
for response, original_item in zip(openai_responses, test_data):
    response_dict = response.to_dict()
    inference_data.append({
        'messages': response_dict['messages'],
        'metadata': original_item['metadata']
    })

accuracy, correct, total, errors, incorrect_list = measure_accuracy(inference_data)
# Out:
# Accuracy: 80.29% (2473/3080)

# %% [markdown]
# ## Basic prompt

# %%
test_basic_file = '/Users/ryanarman/code/lab/banking77/notebooks/data/banking77_test_basic_v2_1.jsonl'
test_basic_data = read_jsonl(test_basic_file)

openai_conversations_basic = create_conversations(test_basic_data)
print(f"Created {len(openai_conversations_basic)} conversations from test_data")

# Run inference with OpenAI
print(f"Running OpenAI inference on {len(openai_conversations_basic)} conversations...")
openai_responses_basic = openai_engine.infer(
    input=openai_conversations_basic,
    inference_config=openai_config,
)

print(f"Received {len(openai_responses_basic)} responses from OpenAI")
# Out:
# Created 3080 conversations from test_data
# Running OpenAI inference on 3080 conversations...
# [2025-11-21 12:16:37,450][oumi][rank0][pid:99860][MainThread][WARNING]][base_inference_engine.py:409] OpenAIInferenceEngine does not support use_sampling. Received value: use_sampling=True. This parameter will be ignored.
#  97%|█████████▋| 2993/3080 [01:24<01:27,  1.01s/it]
# [2025-11-21 12:18:40,628][oumi][rank0][pid:99860][ThreadPoolExecutor-3082_0][WARNING]][adaptive_concurrency_controller.py:237] Entering warmup state, but concurrency is already at maximum value. Consider raising the max concurrency.
# 100%|██████████| 3080/3080 [02:14<00:00, 22.89it/s]
# Received 3080 responses from OpenAI

# %%
teacher_results_path_basic = '/Users/ryanarman/code/lab/banking77/notebooks/data/teacher_results_v2_1_basic_prompt.jsonl'
# Save responses as conversation format
with open(teacher_results_path_basic, "w", encoding='utf-8') as f:
    for response in openai_responses_basic:
        # Convert Conversation object to dict and save
        f.write(json.dumps(response.to_dict(), ensure_ascii=False) + "\n")

# %%
# Combine responses with metadata for accuracy measurement
inference_data_basic = []
for response, original_item in zip(openai_responses_basic, test_basic_data):
    response_dict = response.to_dict()
    inference_data_basic.append({
        'messages': response_dict['messages'],
        'metadata': original_item['metadata']
    })

accuracy_basic, correct_basic, total_basic, errors_basic, incorrect_list_basic = measure_accuracy(inference_data_basic)
# Out:
# Accuracy: 79.84% (2459/3080)
